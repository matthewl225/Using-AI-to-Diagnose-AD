# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#import congitive assessment spreadsheet
#path = "./Data/matthewl225_7_15_2019_16_11_22.csv"
path = input('Path to cognitive assesment csv: ')
header = ['ADRC_ADRCCLINICALDATA ID', 'dx1']

#dfcolumns = pd.read_csv(path, nrows = 1)
df = pd.read_csv(path, header = None, skiprows = 1, usecols = [0,8], names = header)

#df = pd.read_csv(path, names=header, index_col=False)
# Out:
# Path to cognitive assesment csv: ./Data/matthewl225_7_15_2019_16_11_22.csv

# %%
df.shape
# Out:
# (6224, 2)

# %%
df[:3]
# Out:
#       ADRC_ADRCCLINICALDATA ID                 dx1
# 0  OAS30001_ClinicalData_d0000  Cognitively normal
# 1  OAS30001_ClinicalData_d0339  Cognitively normal
# 2  OAS30001_ClinicalData_d0722  Cognitively normal

# %%
df.dx1.unique()
# Out:
# array(['Cognitively normal', 'uncertain dementia',
#        'Unc: ques. Impairment', 'AD dem w/depresss- not contribut',
#        'AD Dementia', 'AD dem distrubed social- with',
#        'AD dem w/CVD contribut', 'Non AD dem- Other primary',
#        'AD dem visuospatial- with', 'AD dem visuospatial- prior',
#        'AD dem Language dysf after', '.',
#        'uncertain- possible NON AD dem', 'Vascular Demt- primary',
#        'AD dem w/PDI after AD dem not contrib', '0.5 in memory only',
#        'Incipient Non-AD dem', 'AD dem distrubed social- prior',
#        'Frontotemporal demt. prim', 'AD dem distrubed social- after',
#        'AD dem w/PDI after AD dem contribut',
#        'uncertain  possible NON AD dem',
#        'AD dem w/depresss  not contribut',
#        'AD dem w/oth (list B) contribut', 'DLBD- primary',
#        'Incipient demt PTP', 'Dementia/PD- primary',
#        'AD dem w/depresss- contribut', 'Unc: impair reversible',
#        'AD dem w/oth (list B) not contrib', 'AD dem w/CVD not contrib',
#        'AD dem Language dysf prior', 'AD dem Language dysf with', 'DAT',
#        'Vascular Demt  primary', 'DLBD- secondary',
#        'AD dem w/oth unusual features', 'ProAph w/o dement',
#        'AD dem cannot be primary', 'Vascular Demt- secondary',
#        'No dementia', 'AD dem w/oth unusual feat/subs demt',
#        'AD dem w/depresss  contribut', 'DLBD, primary', nan,
#        'AD dem visuospatial, after', 'DAT w/depresss not contribut',
#        'AD dem w/oth unusual features/demt on',
#        'AD dem w/Frontal lobe/demt at onset',
#        'AD dem/FLD prior to AD dem', 'AD dem w/depresss, not contribut'],
#       dtype=object)

# %%
df.dx1.isna().sum()
# Out:
# 2

# %%
import re

subject_regex = re.compile("OAS(?P<order>[0-9]+)")
subjects = [subject_regex.search(r).group(1) for r in df["ADRC_ADRCCLINICALDATA ID"]]
#print(subjects)
df['Subject'] = pd.Series(subjects, index=df.index)

date_regex = re.compile("d(?P<order>[0-9]+)")
dates = [date_regex.search(r).group(1) for r in df["ADRC_ADRCCLINICALDATA ID"]]
df['Date'] = pd.Series(list(map(int,dates)), index=df.index)

# %%
df[:15]
# Out:
#        ADRC_ADRCCLINICALDATA ID                 dx1 Subject  Date
# 0   OAS30001_ClinicalData_d0000  Cognitively normal   30001     0
# 1   OAS30001_ClinicalData_d0339  Cognitively normal   30001   339
# 2   OAS30001_ClinicalData_d0722  Cognitively normal   30001   722
# 3   OAS30001_ClinicalData_d1106  Cognitively normal   30001  1106
# 4   OAS30001_ClinicalData_d1456  Cognitively normal   30001  1456
# 5   OAS30001_ClinicalData_d1894  Cognitively normal   30001  1894
# 6   OAS30001_ClinicalData_d2181  Cognitively normal   30001  2181
# 7   OAS30001_ClinicalData_d2699  Cognitively normal   30001  2699
# 8   OAS30001_ClinicalData_d3025  Cognitively normal   30001  3025
# 9   OAS30001_ClinicalData_d3332  Cognitively normal   30001  3332
# 10  OAS30001_ClinicalData_d3675  Cognitively normal   30001  3675
# 11  OAS30001_ClinicalData_d3977  Cognitively normal   30001  3977
# 12  OAS30002_ClinicalData_d0000  Cognitively normal   30002     0
# 13  OAS30002_ClinicalData_d0751  Cognitively normal   30002   751
# 14  OAS30002_ClinicalData_d1169  Cognitively normal   30002  1169

# %%
import scipy.misc, numpy, shutil, os, nibabel
import sys, getopt
import zipfile, os

# %%
#unzip nii package
package_path = input('Path to nii zip: ')
with zipfile.ZipFile(package_path, "r") as zip_ref:
    zip_ref.extractall("./Data/Nii")
# Out:
# Path to nii zip: ./Data/matthewl225-20190723_172030.zip

# %%
import gzip

#unzip individual run nii pakcages
nii_package_path = "./Data/Nii"
output_path = "./Data/Nii2"

if not os.path.exists(output_path):
    os.makedirs(output_path)
    print("Created ouput directory: " + output_path)

for root, directories, filenames in os.walk(nii_package_path):
    for filename in filenames:
        run_package = os.path.join(root, filename)
        with gzip.open(run_package, 'rb') as s_file, open(os.path.join(output_path, filename[:-3]), 'wb') as d_file:
            shutil.copyfileobj(s_file, d_file, 65536)
            #shutil.move(d_file, output_path)
# Out:
# Created ouput directory: ./Data/Nii2

# %%
shutil.rmtree("./Data/Nii")

# %%
#convert nii to png (borrowed from nii2png.py)
outputfile = "./Data/Images"
rotate_angle = int(input('Enter rotate angle (0 90 180 270): '))

if not (rotate_angle == 0 or rotate_angle == 90 or rotate_angle == 180 or rotate_angle == 270):
    print('You must enter a value that is either 90, 180, or 270. Quitting...')
    sys.exit()

data_path = "./Data/Nii2"
for root, directories, filenames in os.walk(data_path):
    for filename in filenames:
        if "T2" in filename or "echo" in filename:
            print(filename)
            continue
        
        nii_path = os.path.join(root, filename)
        image_array = nibabel.load(nii_path).get_data()
        print("Input file is ", nii_path)
        #print(len(image_array.shape))

        if len(image_array.shape) == 3:
            # set 4d array dimension values
            nx, ny, nz = image_array.shape

            if not os.path.exists(outputfile):
                os.makedirs(outputfile)
                print("Created ouput directory: " + outputfile)
            
            image_folder = os.path.join(outputfile, filename[:-8])
            
            if not os.path.exists(image_folder):
                os.makedirs(image_folder)
                print("Created ouput directory: " + image_folder)
            
            print('Reading NIfTI file...')

            total_slices = image_array.shape[2]

            slice_counter = 0
            # iterate through slices
            for current_slice in range(0, total_slices):
                # alternate slices
                if (slice_counter % 1) == 0:
                    # rotate or no rotate
                    if rotate_angle == 90 or rotate_angle == 180 or rotate_angle == 270:
                        if rotate_angle == 90:
                            data = numpy.rot90(image_array[:, :, current_slice])
                        elif ask_rotate_num == 180:
                            data = numpy.rot90(numpy.rot90(image_array[:, :, current_slice]))
                        elif ask_rotate_num == 270:
                            data = numpy.rot90(numpy.rot90(numpy.rot90(image_array[:, :, current_slice])))
                    else:
                        data = image_array[:, :, current_slice]

                    #alternate slices and save as png
                    if (slice_counter % 1) == 0:
                        #print('Saving image...')
                        image_name = nii_path[:-4] + "_z" + "{:0>3}".format(str(current_slice+1))+ ".png"
                        scipy.misc.imsave(image_name, data)
                        #print('Saved.')

                        #move images to folder
                        #print('Moving image...')
                        src = image_name
                        shutil.move(src, image_folder)
                        slice_counter += 1
                        #print('Moved.')

            print('Finished converting {}'.format(filename))
        else:
            print('Not a 3D Image. Please try again.')
# Out:
# Enter rotate angle (0 90 180 270): 90
# Input file is  ./Data/Nii2\sub-OAS30009_ses-d0148_run-01_T1w.nii
# Created ouput directory: ./Data/Images
# Created ouput directory: ./Data/Images\sub-OAS30009_ses-d0148_run-01
# Reading NIfTI file...
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
# Finished converting sub-OAS30009_ses-d0148_run-01_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS30009_ses-d0148_run-02_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS30009_ses-d0148_run-02
# Reading NIfTI file...
# Finished converting sub-OAS30009_ses-d0148_run-02_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS30009_ses-d1210_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS30009_ses-d1210
# Reading NIfTI file...
# Finished converting sub-OAS30009_ses-d1210_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS30009_ses-d2457_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS30009_ses-d2457
# Reading NIfTI file...
# Finished converting sub-OAS30009_ses-d2457_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS30019_ses-d0376_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS30019_ses-d0376
# Reading NIfTI file...
# Finished converting sub-OAS30019_ses-d0376_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS30029_ses-d0131_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS30029_ses-d0131
# Reading NIfTI file...
# Finished converting sub-OAS30029_ses-d0131_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS30029_ses-d0893_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS30029_ses-d0893
# Reading NIfTI file...
# Finished converting sub-OAS30029_ses-d0893_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS30039_ses-d0103_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS30039_ses-d0103
# Reading NIfTI file...
# Finished converting sub-OAS30039_ses-d0103_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS30049_ses-d0013_run-01_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS30049_ses-d0013_run-01
# Reading NIfTI file...
# Finished converting sub-OAS30049_ses-d0013_run-01_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS30049_ses-d0013_run-02_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS30049_ses-d0013_run-02
# Reading NIfTI file...
# Finished converting sub-OAS30049_ses-d0013_run-02_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS30049_ses-d1633_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS30049_ses-d1633
# Reading NIfTI file...
# Finished converting sub-OAS30049_ses-d1633_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS30059_ses-d0230_run-01_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS30059_ses-d0230_run-01
# Reading NIfTI file...
# Finished converting sub-OAS30059_ses-d0230_run-01_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS30059_ses-d0230_run-02_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS30059_ses-d0230_run-02
# Reading NIfTI file...
# Finished converting sub-OAS30059_ses-d0230_run-02_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS30059_ses-d0230_run-03_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS30059_ses-d0230_run-03
# Reading NIfTI file...
# Finished converting sub-OAS30059_ses-d0230_run-03_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS30059_ses-d0230_run-04_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS30059_ses-d0230_run-04
# Reading NIfTI file...
# Finished converting sub-OAS30059_ses-d0230_run-04_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS30059_ses-d1188_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS30059_ses-d1188
# Reading NIfTI file...
# Finished converting sub-OAS30059_ses-d1188_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS30079_ses-d0019_run-01_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS30079_ses-d0019_run-01
# Reading NIfTI file...
# Finished converting sub-OAS30079_ses-d0019_run-01_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS30079_ses-d0019_run-02_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS30079_ses-d0019_run-02
# Reading NIfTI file...
# Finished converting sub-OAS30079_ses-d0019_run-02_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS30079_ses-d1833_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS30079_ses-d1833
# Reading NIfTI file...
# Finished converting sub-OAS30079_ses-d1833_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS30079_ses-d2668_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS30079_ses-d2668
# Reading NIfTI file...
# Finished converting sub-OAS30079_ses-d2668_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS30089_ses-d0001_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS30089_ses-d0001
# Reading NIfTI file...
# Finished converting sub-OAS30089_ses-d0001_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS
run-01_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS30999_ses-d0153_run-02_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS30999_ses-d0153_run-02
# Reading NIfTI file...
# Finished converting sub-OAS30999_ses-d0153_run-02_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31009_ses-d0512_run-01_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31009_ses-d0512_run-01
# Reading NIfTI file...
# Finished converting sub-OAS31009_ses-d0512_run-01_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31009_ses-d0512_run-02_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31009_ses-d0512_run-02
# Reading NIfTI file...
# Finished converting sub-OAS31009_ses-d0512_run-02_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31009_ses-d1049_run-01_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31009_ses-d1049_run-01
# Reading NIfTI file...
# Finished converting sub-OAS31009_ses-d1049_run-01_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31009_ses-d1049_run-02_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31009_ses-d1049_run-02
# Reading NIfTI file...
# Finished converting sub-OAS31009_ses-d1049_run-02_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31009_ses-d2325_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31009_ses-d2325
# Reading NIfTI file...
# Finished converting sub-OAS31009_ses-d2325_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31009_ses-d3330_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31009_ses-d3330
# Reading NIfTI file...
# Finished converting sub-OAS31009_ses-d3330_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31009_ses-d3611_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31009_ses-d3611
# Reading NIfTI file...
# Finished converting sub-OAS31009_ses-d3611_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31019_ses-d0076_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31019_ses-d0076
# Reading NIfTI file...
# Finished converting sub-OAS31019_ses-d0076_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31019_ses-d1370_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31019_ses-d1370
# Reading NIfTI file...
# Finished converting sub-OAS31019_ses-d1370_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31029_ses-d2448_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31029_ses-d2448
# Reading NIfTI file...
# Finished converting sub-OAS31029_ses-d2448_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31039_ses-d0001_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31039_ses-d0001
# Reading NIfTI file...
# Finished converting sub-OAS31039_ses-d0001_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31039_ses-d1184_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31039_ses-d1184
# Reading NIfTI file...
# Finished converting sub-OAS31039_ses-d1184_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31049_ses-d0575_run-01_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31049_ses-d0575_run-01
# Reading NIfTI file...
# Finished converting sub-OAS31049_ses-d0575_run-01_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31049_ses-d0575_run-02_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31049_ses-d0575_run-02
# Reading NIfTI file...
# Finished converting sub-OAS31049_ses-d0575_run-02_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31049_ses-d0575_run-03_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31049_ses-d0575_run-03
# Reading NIfTI file...
# Finished converting sub-OAS31049_ses-d0575_run-03_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31049_ses-d0575_run-04_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31049_ses-d0575_run-04
# Reading NIfTI file...
# Finished converting sub-OAS31049_ses-d0575_run-04_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31049_ses-d1066_run-01_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31049_ses-d1066_run-01
# Reading NIfTI file...
# Finished converting sub-OAS31049_ses-d1066_run-01_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31049_ses-d1066_run-02_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31049_ses-d1066_run-02
# Reading NIfTI file...
# Finished converting sub-OAS31049_ses-d1066_run-02_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31049_ses-d1066_run-03_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31049_ses-d1066_run-03
# Reading NIfTI file...
# Finished converting sub-OAS31049_ses-d1066_run-03_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31059_ses-d1231_run-01_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31059_ses-d1231_run-01
# Reading NIfTI file...
# Finished converting sub-OAS31059_ses-d1231_run-01_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31059_ses-d1231_run-02_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31059_ses-d1231_run-02
# Reading NIfTI file...
# Finished converting sub-OAS31059_ses-d1231_run-02_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31059_ses-d3491_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31059_ses-d3491
# Reading NIfTI file...
# Finished converting sub-OAS31059_ses-d3491_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31069_ses-d0025_run-01_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31069_ses-d0025_run-01
# Reading NIfTI file...
# Finished converting sub-OAS31069_ses-d0025_run-01_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31069_ses-d0025_run-02_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31069_ses-d0025_run-02
# Reading NIfTI file...
# Finished converting sub-OAS31069_ses-d0025_run-02_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31089_ses-d0023_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31089_ses-d0023
# Reading NIfTI file...
# Finished converting sub-OAS31089_ses-d0023_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31099_ses-d0086_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31099_ses-d0086
# Reading NIfTI file...
# Finished converting sub-OAS31099_ses-d0086_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31099_ses-d0900_run-01_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31099_ses-d0900_run-01
# Reading NIfTI file...
# Finished converting sub-OAS31099_ses-d0900_run-01_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31099_ses-d0900_run-02_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31099_ses-d0900_run-02
# Reading NIfTI file...
# Finished converting sub-OAS31099_ses-d0900_run-02_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31099_ses-d3526_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31099_ses-d3526
# Reading NIfTI file...
# Finished converting sub-OAS31099_ses-d3526_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31109_ses-d0000_run-01_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31109_ses-d0000_run-01
# Reading NIfTI file...
# Finished converting sub-OAS31109_ses-d0000_run-01_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31109_ses-d0000_run-02_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31109_ses-d0000_run-02
# Reading NIfTI file...
# Finished converting sub-OAS31109_ses-d0000_run-02_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31109_ses-d0000_run-03_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31109_ses-d0000_run-03
# Reading NIfTI file...
# Finished converting sub-OAS31109_ses-d0000_run-03_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31119_ses-d0069_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31119_ses-d0069
# Reading NIfTI file...
# Finished converting sub-OAS31119_ses-d0069_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31119_ses-d1493_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31119_ses-d1493
# Reading NIfTI file...
# Finished converting sub-OAS31119_ses-d1493_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31129_ses-d0055_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31129_ses-d0055
# Reading NIfTI file...
# Finished converting sub-OAS31129_ses-d0055_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31139_ses-d0533_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31139_ses-d0533
# Reading NIfTI file...
# Finished converting sub-OAS31139_ses-d0533_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31139_ses-d1568_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31139_ses-d1568
# Reading NIfTI file...
# Finished converting sub-OAS31139_ses-d1568_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31149_ses-d0061_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31149_ses-d0061
# Reading NIfTI file...
# Finished converting sub-OAS31149_ses-d0061_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31159_ses-d0074_run-01_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31159_ses-d0074_run-01
# Reading NIfTI file...
# Finished converting sub-OAS31159_ses-d0074_run-01_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31159_ses-d0074_run-02_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31159_ses-d0074_run-02
# Reading NIfTI file...
# Finished converting sub-OAS31159_ses-d0074_run-02_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31159_ses-d1019_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31159_ses-d1019
# Reading NIfTI file...
# Finished converting sub-OAS31159_ses-d1019_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31159_ses-d1893_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31159_ses-d1893
# Reading NIfTI file...
# Finished converting sub-OAS31159_ses-d1893_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31169_ses-d0620_run-01_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31169_ses-d0620_run-01
# Reading NIfTI file...
# Finished converting sub-OAS31169_ses-d0620_run-01_T1w.nii
# Input file is  ./Data/Nii2\sub-OAS31169_ses-d0620_run-02_T1w.nii
# Created ouput directory: ./Data/Images\sub-OAS31169_ses-d0620_run-02
# Reading NIfTI file...
# Finished converting sub-OAS31169_ses-d0620_run-02_T1w.nii

# %%
runs_list = next(os.walk('./Data/Images'))[1]
#print(runs_list)
# Out:
# ['sub-OAS30009_ses-d0148_run-01', 'sub-OAS30009_ses-d0148_run-02', 'sub-OAS30009_ses-d1210', 'sub-OAS30009_ses-d2457', 'sub-OAS30019_ses-d0376', 'sub-OAS30029_ses-d0131', 'sub-OAS30029_ses-d0893', 'sub-OAS30039_ses-d0103', 'sub-OAS30049_ses-d0013_run-01', 'sub-OAS30049_ses-d0013_run-02', 'sub-OAS30049_ses-d1633', 'sub-OAS30059_ses-d0230_run-01', 'sub-OAS30059_ses-d0230_run-02', 'sub-OAS30059_ses-d0230_run-03', 'sub-OAS30059_ses-d0230_run-04', 'sub-OAS30059_ses-d1188', 'sub-OAS30079_ses-d0019_run-01', 'sub-OAS30079_ses-d0019_run-02', 'sub-OAS30079_ses-d1833', 'sub-OAS30079_ses-d2668', 'sub-OAS30089_ses-d0001', 'sub-OAS30099_ses-d0032', 'sub-OAS30109_ses-d0270', 'sub-OAS30109_ses-d0432_run-01', 'sub-OAS30109_ses-d0432_run-02', 'sub-OAS30109_ses-d0997_run-01', 'sub-OAS30109_ses-d0997_run-02', 'sub-OAS30109_ses-d2310', 'sub-OAS30109_ses-d2320', 'sub-OAS30119_ses-d1209_run-01', 'sub-OAS30119_ses-d1209_run-02', 'sub-OAS30119_ses-d1209_run-03', 'sub-OAS30119_ses-d2415_run-01', 'sub-OAS30119_ses-d2415_run-02', 'sub-OAS30119_ses-d3260_run-01', 'sub-OAS30119_ses-d3260_run-02', 'sub-OAS30119_ses-d3722', 'sub-OAS30129_ses-d0055', 'sub-OAS30139_ses-d0101', 'sub-OAS30139_ses-d1702', 'sub-OAS30149_ses-d0051', 'sub-OAS30149_ses-d1240', 'sub-OAS30159_ses-d0110', 'sub-OAS30169_ses-d0282_run-01', 'sub-OAS30169_ses-d0282_run-02', 'sub-OAS30179_ses-d0061', 'sub-OAS30189_ses-d0072', 'sub-OAS30199_ses-d0024', 'sub-OAS30209_ses-d0609_run-01', 'sub-OAS30209_ses-d0609_run-02', 'sub-OAS30209_ses-d1976', 'sub-OAS30219_ses-d0064', 'sub-OAS30219_ses-d1184', 'sub-OAS30229_ses-d0101', 'sub-OAS30239_ses-d0175_run-01', 'sub-OAS30239_ses-d0175_run-02', 'sub-OAS30249_ses-d0091_run-01', 'sub-OAS30249_ses-d0091_run-02', 'sub-OAS30249_ses-d0091_run-03', 'sub-OAS30249_ses-d0749', 'sub-OAS30249_ses-d1238_run-01', 'sub-OAS30249_ses-d1238_run-02', 'sub-OAS30249_ses-d1952_run-01', 'sub-OAS30249_ses-d1952_run-02', 'sub-OAS30249_ses-d3431', 'sub-OAS30249_ses-d4416', 'sub-OAS30259_ses-d0000_run-01', 'sub-OAS30259_ses-d0000_run-02', 'sub-OAS30259_ses-d0000_run-03', 'sub-OAS30259_ses-d0679_run-01', 'sub-OAS30259_ses-d0679_run-02', 'sub-OAS30259_ses-d0679_run-03', 'sub-OAS30269_ses-d0052_run-01', 'sub-OAS30269_ses-d0052_run-02', 'sub-OAS30279_ses-d0136', 'sub-OAS30289_ses-d0160', 'sub-OAS30299_ses-d0119_run-01', 'sub-OAS30299_ses-d0119_run-02', 'sub-OAS30309_ses-d0094', 'sub-OAS30319_ses-d0043_run-01', 'sub-OAS30319_ses-d0043_run-02', 'sub-OAS30329_ses-d0376', 'sub-OAS30339_ses-d0066_run-01', 'sub-OAS30339_ses-d0066_run-02', 'sub-OAS30349_ses-d0699_run-01', 'sub-OAS30349_ses-d0699_run-02', 'sub-OAS30349_ses-d3241', 'sub-OAS30359_ses-d0069_run-01', 'sub-OAS30359_ses-d0069_run-02', 'sub-OAS30369_ses-d2819_run-01', 'sub-OAS30369_ses-d2819_run-02', 'sub-OAS30369_ses-d2819_run-03', 'sub-OAS30369_ses-d4058_run-01', 'sub-OAS30369_ses-d4058_run-02', 'sub-OAS30369_ses-d4921', 'sub-OAS30369_ses-d5872', 'sub-OAS30369_ses-d5880', 'sub-OAS30369_ses-d6215', 'sub-OAS30369_ses-d6992', 'sub-OAS30379_ses-d1169_run-01', 'sub-OAS30379_ses-d1169_run-02', 'sub-OAS30379_ses-d1169_run-03', 'sub-OAS30379_ses-d2106_run-01', 'sub-OAS30379_ses-d2106_run-02', 'sub-OAS30399_ses-d0380_run-01', 'sub-OAS30399_ses-d0380_run-02', 'sub-OAS30399_ses-d1220_run-01', 'sub-OAS30399_ses-d1220_run-02', 'sub-OAS30399_ses-d2293', 'sub-OAS30419_ses-d0621_run-01', 'sub-OAS30419_ses-d0621_run-02', 'sub-OAS30419_ses-d1139_run-01', 'sub-OAS30419_ses-d1139_run-02', 'sub-OAS30419_ses-d2360', 'sub-OAS30419_ses-d3307', 'sub-OAS30429_ses-d0055', 'sub-OAS30449_ses-d0000_run-01', 'sub-OAS30449_ses-d0000_run-02', 'sub-OAS30449_ses-d0620_run-01', 'sub-OAS30449_ses-d0620_run-02', 'sub-OAS30449_ses-d2359', 'sub-OAS30449_ses-d2433', 'sub-OAS30459_ses-d0078_run-01', 'sub-OAS30459_ses-d0078_run-02', 'sub-OAS30459_ses-d0078_run-03', 'sub-OAS30459_ses-d0571_run-01', 'sub-OAS30459_ses-d0571_run-02', 'sub-OAS30459_ses-d0571_run-03', 'sub-OAS30469_ses-d0112', 'sub-OAS30479_ses-d0398_run-01', 'sub-OAS30479_ses-d0398_run-02', 'sub-OAS30479_ses-d ...

# %%
import math

AD_list = []

for run in runs_list:
    # if dx1 starts with AD then patient has AD
    # either 0 or 1
    # print(run)
    subject_regex = re.compile("OAS(?P<order>[0-9]+)")
    subject = subject_regex.search(run).group(1)
    
    date_regex = re.compile("d(?P<order>[0-9]+)")
    date = date_regex.search(run).group(1)
    
    #print(subject, date)
    
    subject_df = df.loc[df["Subject"] == subject]
    #print(subject_df)
    
    #label = min(list(map(int, subject_df['Date'])), key=lambda x:(int(date)-x))
    df_dates = subject_df['Date']
    #print(type(df_dates))
    
    if int(date) > df_dates.iloc[-1]:
        label_date = df_dates.iloc[-1]
    else:
        label_date = min(i for i in df_dates if i >= int(date))
    
    label = subject_df.loc[df['Date'] == label_date, 'dx1'].item()
    if type(label) == float:
        print(label)
        runs_list.remove(run)
        continue
    AD = 1 if label.startswith('AD') else 0
    AD_list.append(AD)
    
    #print(run, AD)

Labelsdf = pd.DataFrame()
#df = pd.DataFrame(columns=['Run', 'AD'])
Labelsdf['Run'] = pd.Series(runs_list)
Labelsdf['AD'] = pd.Series(AD_list)

# %%
print(label)
# Out:
# AD Dementia

# %%
Labelsdf
# Out:
#                                Run  AD
# 0    sub-OAS30009_ses-d0148_run-01   0
# 1    sub-OAS30009_ses-d0148_run-02   0
# 2           sub-OAS30009_ses-d1210   0
# 3           sub-OAS30009_ses-d2457   0
# 4           sub-OAS30019_ses-d0376   1
# 5           sub-OAS30029_ses-d0131   1
# 6           sub-OAS30029_ses-d0893   1
# 7           sub-OAS30039_ses-d0103   0
# 8    sub-OAS30049_ses-d0013_run-01   0
# 9    sub-OAS30049_ses-d0013_run-02   0
# 10          sub-OAS30049_ses-d1633   0
# 11   sub-OAS30059_ses-d0230_run-01   0
# 12   sub-OAS30059_ses-d0230_run-02   0
# 13   sub-OAS30059_ses-d0230_run-03   0
# 14   sub-OAS30059_ses-d0230_run-04   0
# 15          sub-OAS30059_ses-d1188   0
# 16   sub-OAS30079_ses-d0019_run-01   0
# 17   sub-OAS30079_ses-d0019_run-02   0
# 18          sub-OAS30079_ses-d1833   0
# 19          sub-OAS30079_ses-d2668   0
# 20          sub-OAS30089_ses-d0001   0
# 21          sub-OAS30099_ses-d0032   0
# 22          sub-OAS30109_ses-d0270   0
# 23   sub-OAS30109_ses-d0432_run-01   0
# 24   sub-OAS30109_ses-d0432_run-02   0
# 25   sub-OAS30109_ses-d0997_run-01   0
# 26   sub-OAS30109_ses-d0997_run-02   0
# 27          sub-OAS30109_ses-d2310   0
# 28          sub-OAS30109_ses-d2320   0
# 29   sub-OAS30119_ses-d1209_run-01   1
# ..                             ...  ..
# 300  sub-OAS31049_ses-d0575_run-03   1
# 301  sub-OAS31049_ses-d0575_run-04   1
# 302  sub-OAS31049_ses-d1066_run-01   1
# 303  sub-OAS31049_ses-d1066_run-02   1
# 304  sub-OAS31049_ses-d1066_run-03   1
# 305  sub-OAS31059_ses-d1231_run-01   0
# 306  sub-OAS31059_ses-d1231_run-02   0
# 307         sub-OAS31059_ses-d3491   0
# 308  sub-OAS31069_ses-d0025_run-01   0
# 309  sub-OAS31069_ses-d0025_run-02   0
# 310         sub-OAS31089_ses-d0023   0
# 311         sub-OAS31099_ses-d0086   0
# 312  sub-OAS31099_ses-d0900_run-01   0
# 313  sub-OAS31099_ses-d0900_run-02   0
# 314         sub-OAS31099_ses-d3526   0
# 315  sub-OAS31109_ses-d0000_run-01   1
# 316  sub-OAS31109_ses-d0000_run-02   1
# 317  sub-OAS31109_ses-d0000_run-03   1
# 318         sub-OAS31119_ses-d0069   0
# 319         sub-OAS31119_ses-d1493   0
# 320         sub-OAS31129_ses-d0055   1
# 321         sub-OAS31139_ses-d0533   1
# 322         sub-OAS31139_ses-d1568   1
# 323         sub-OAS31149_ses-d0061   0
# 324  sub-OAS31159_ses-d0074_run-01   0
# 325  sub-OAS31159_ses-d0074_run-02   0
# 326         sub-OAS31159_ses-d1019   0
# 327         sub-OAS31159_ses-d1893   0
# 328  sub-OAS31169_ses-d0620_run-01   1
# 329  sub-OAS31169_ses-d0620_run-02   1
#
# [330 rows x 2 columns]

# %%
Labelsdf.to_csv("./Data/Labels.csv")

# %%
Labelsdf.groupby("AD").size()
# Out:
# AD
# 0    269
# 1     61
# dtype: int64
