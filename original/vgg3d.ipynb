# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cv2
import os
import torchvision
from torchvision import datasets, models, transforms
from torch.utils.data import Dataset, DataLoader
import time
import copy
import sys
import torch.nn.init as init
print("PyTorch Version: ",torch.__version__)
print("Torchvision Version: ",torchvision.__version__)
# Out:
# PyTorch Version:  1.1.0
# Torchvision Version:  0.3.0

# %%
# CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
torch.backends.cudnn.benchmark = True
print(torch.cuda.get_device_name(0))
# Out:
# Tesla V100-SXM2-16GB

# %%
runs_list = next(os.walk('../Data/Images'))[1]

# %%
path = "../Data/Labels.csv"
header = ['Run','AD']
Labelsdf = pd.read_csv(path, names=header, usecols=[1,2], skiprows=1, index_col=False)

# %%
labels_dict = dict(zip(Labelsdf.Run, Labelsdf.AD))

# %%
import re

# process then save the 3d image ndarray as binary
# Images of 96, 96, 48 from 256, 176, 256

# Crop in the x and y direction (get center/hippocampi area)
# [80:176, 40:136, ]

img_dir = "../Data/Images"
dest_dir = "../Data/Processed"

if not os.path.exists(dest_dir):
    os.makedirs(dest_dir)
    print("Created ouput directory: " + dest_dir)

    depth_scale = 2

    imgs, labels = [], []

    for run in runs_list:
        run_dir = os.path.join(img_dir, run)
        run_imgs = []
        for filename in os.listdir(run_dir):
            img_slice = cv2.imread(os.path.join(run_dir, filename), cv2.IMREAD_GRAYSCALE)
            # if image is square? IF DO THIS, NEED TO ACCOUNT FOR CENTER OFF SET (176 X 240)
            if  img_slice is None or img_slice.shape[0] == img_slice.shape[1]:
                print(run)
                print('1')
                break
            img_num = int(filename[-7:-4])
            if (100 <= img_num < 196):
                img_slice = cv2.imread(os.path.join(run_dir, filename), cv2.IMREAD_GRAYSCALE)
                #img_slice = cv2.resize(img_slice, (0,0), fx=1/img_scale, fy=1/img_scale, interpolation=cv2.INTER_AREA)
                img_slice = img_slice[80:176,40:136]
                # normalize pixel intensity to range of 0 and 1
                img_slice = img_slice/256
                run_imgs.append(img_slice)

        if len(run_imgs) == 0 or len(run_imgs) != 96:
            print(run)
            print('2')
            continue

        temp_arr = np.array(run_imgs)

        final_slices = []

        for y in range(temp_arr.shape[2]):
            xz_pane = temp_arr[:, :, y]
            scaled_xz = cv2.resize(xz_pane, (0, 0), fy=1/depth_scale, fx=1, interpolation=cv2.INTER_AREA)
            final_slices.append(scaled_xz)

        if not len(final_slices[0]) == 48:
            print(run)
            print('3')
            continue

        final_slices = np.dstack(final_slices)
        final_slices = np.expand_dims(final_slices, axis=0)
        if run in labels_dict:
            # save as binary
            np.save(os.path.join(dest_dir, run), final_slices)
            imgs.append(run)
            labels.append(labels_dict[run])
        else:
            continue

    imgs = np.array(imgs)
    labels = np.array(labels)

    np.save(os.path.join(dest_dir, 'imgs'), imgs)
    np.save(os.path.join(dest_dir, 'labels'), labels)

            
else:
    imgs = np.load(os.path.join(dest_dir, 'imgs.npy'))
    labels = np.load(os.path.join(dest_dir, 'labels.npy'))

# %%
# Models to choose from
model_name = "vgg3d"

# Number of classes in the dataset
num_classes = 2

# Batch size for training (change depending on how much memory you have)
batch_size = 16

# Number of epochs to train for
num_epochs = 40

# %%
train_imgs, train_labels = [], []
val_imgs, val_labels = [], []
test_imgs, test_labels = [], []

for idx, ad in np.ndenumerate(labels):
    if (idx[0] % 10) < 6:
        train_imgs.append(imgs[idx[0]])
        train_labels.append(ad)
    if ((idx[0] % 10) >= 6) and ((idx[0] % 10) < 8):
        val_imgs.append(imgs[idx[0]])
        val_labels.append(ad)
    if ((idx[0] % 10) >= 8) and ((idx[0] % 10) <= 9):
        test_imgs.append(imgs[idx[0]])
        test_labels.append(ad)
        
train_imgs = np.array(train_imgs)
train_labels = np.array(train_labels)
val_imgs = np.array(val_imgs)
val_labels = np.array(val_labels)
test_imgs = np.array(test_imgs)
test_labels = np.array(test_labels)
        
ad_imgs, ad_labels = [], []

for idx, ad in np.ndenumerate(train_labels):
    if ad:
        ad_imgs.append(imgs[idx[0]])
        ad_labels.append(ad)

ad_imgs = np.array(ad_imgs)
ad_labels = np.array(ad_labels)

normal_ratio = train_imgs.shape[0] // ad_imgs.shape[0]
print("Normal ratio: " + str(normal_ratio))

train_imgs = np.concatenate((train_imgs, np.repeat(ad_imgs, normal_ratio - 1, axis=0)), axis=0)
train_labels = np.concatenate((train_labels, np.repeat(ad_labels, normal_ratio -1, axis=0)), axis=0)
# Out:
# Normal ratio: 7

# %%
class T1Dataset(Dataset):
    def __init__(self, data, target, transform=None):
        self.data = data
        self.target = torch.from_numpy(target).long()
        self.transform = transform

    def __getitem__(self, index):
        x = np.load(os.path.join(dest_dir, self.data[index]) + ".npy")
        x = torch.from_numpy(x).float()
        y = self.target[index]

        if self.transform:
            x = self.transform(x)

        return x, y

    def __len__(self):
        return len(self.data)

# %%
train_dataset = T1Dataset(train_imgs, train_labels)
val_dataset = T1Dataset(val_imgs, val_labels)
test_dataset = T1Dataset(test_imgs, test_labels)

image_datasets = {'train': train_dataset, 'val': val_dataset, 'test': test_dataset}
dataloaders_dict = {x: torch.utils.data.DataLoader(image_datasets[x], 
                                                   batch_size=batch_size,
                                                   pin_memory=True,
                                                   shuffle=True, num_workers=0) for x in ['train', 'val', 'test']}

# %%
class VGG3D(nn.Module):

    def __init__(self):
        super(VGG3D, self).__init__()
        
        self.features3d = nn.Sequential(
            nn.Conv3d(1, 64, kernel_size=3, padding=1),
            nn.BatchNorm3d(64),
            nn.ReLU(inplace=True),
            nn.Conv3d(64, 64, kernel_size=3, padding=1),
            nn.BatchNorm3d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool3d(kernel_size=(2, 2, 2)), #256
            
            nn.Conv3d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm3d(128),
            nn.ReLU(inplace=True),
            nn.Conv3d(128, 128, kernel_size=3, padding=1),
            nn.BatchNorm3d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool3d(kernel_size=(2, 2, 2)), #128
            
            nn.Conv3d(128, 256, kernel_size=3, padding=1),
            nn.BatchNorm3d(256),
            nn.ReLU(inplace=True),
            nn.Conv3d(256, 256, kernel_size=3, padding=1),
            nn.BatchNorm3d(256),
            nn.ReLU(inplace=True),
            nn.MaxPool3d(kernel_size=(2, 2, 2)), #64
            
            nn.Conv3d(256, 512, kernel_size=3, padding=1),
            nn.BatchNorm3d(512),
            nn.ReLU(inplace=True),
            nn.Conv3d(512, 512, kernel_size=3, padding=1),
            nn.BatchNorm3d(512),
            nn.ReLU(inplace=True),
            nn.MaxPool3d(kernel_size=(2, 2, 2)), #32
            
            nn.Conv3d(512, 512, kernel_size=3, padding=1),
            nn.BatchNorm3d(512),
            nn.ReLU(inplace=True),
            nn.Conv3d(512, 512, kernel_size=3, padding=1),
            nn.BatchNorm3d(512),
            nn.ReLU(inplace=True),
            nn.MaxPool3d(kernel_size=(2, 2, 2)), #16
        )
        
        self.avgpool = nn.AdaptiveAvgPool3d((1, 3, 3))
        
        self.classifier = nn.Sequential(
            nn.Linear(512 * 1 * 3 * 3, 4096),
            nn.ReLU(True),
            nn.Dropout(),
            nn.Linear(4096, 4096),
            nn.ReLU(True),
            nn.Dropout(),
            nn.Linear(4096, 2),
        )
         # Initialize weights
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
                m.bias.data.zero_()

    def forward(self, x):
        x = self.features3d(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# %%
def train_model(model, dataloaders, criterion, optimizer, num_epochs=25):
    since = time.time()

    val_acc_history = []

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0
            normal_corrects, ad_corrects = 0, 0
            normal_count, ad_count = 0, 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    # Get model outputs and calculate loss
                    # Special case for inception because in training it has an auxiliary output. In train
                    #   mode we calculate the loss by summing the final output and the auxiliary output
                    #   but in testing we only consider the final output.
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)

                    _, preds = torch.max(outputs, 1)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                correctness = preds == labels.data
                running_corrects += torch.sum(correctness)

                index = 0
                for condition in labels.data:
                    
                    if condition == 0:
                        if correctness[index] == 1:
                            normal_corrects += 1
                        normal_count += 1
                    if condition == 1:
                        if correctness[index] == 1:
                            ad_corrects += 1
                        ad_count += 1
                    index += 1
    
            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)
            epoch_normal_acc = normal_corrects / normal_count
            epoch_ad_acc = ad_corrects / ad_count

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))
            print('Normal Acc: {:.4f} AD Acc: {:.4f}'.format(epoch_normal_acc, epoch_ad_acc))
            print('Normal count: {} AD count: {}'.format(normal_count, ad_count))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc and abs(epoch_normal_acc - epoch_ad_acc) < 0.1:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
                print()
                print('New best_acc: {:.4f}'.format(best_acc))
            if phase == 'val':
                val_acc_history.append(epoch_acc)

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc (with true/false acc diff less than 10%): {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, val_acc_history

# %%
def initialize_model(model_name, num_classes):
    # Initialize these variables which will be set in this if statement. Each of these
    #   variables is model specific.
    model_ft = None
    input_size = []

    if model_name == "vgg3d":
        model_ft = VGG3D()
        num_ftrs = model_ft.classifier[6].in_features
        model_ft.classifier[6] = nn.Linear(num_ftrs,num_classes)
        input_size = (48, 96, 96)
        
    else:
        print("Invalid model name, exiting...")
        exit()

    return model_ft, input_size

# %%
scratch_model,_ = initialize_model(model_name, num_classes)
print(scratch_model)
scratch_model = scratch_model.to(device)
scratch_optimizer = optim.SGD(scratch_model.parameters(), lr=0.001, momentum=0.9)
scratch_criterion = nn.CrossEntropyLoss()
_,scratch_hist = train_model(scratch_model, dataloaders_dict, scratch_criterion, scratch_optimizer, num_epochs=num_epochs)
# Out:
# VGG3D(
#   (features3d): Sequential(
#     (0): Conv3d(1, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (4): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace)
#     (6): MaxPool3d(kernel_size=(2, 2, 2), stride=(2, 2, 2), padding=0, dilation=1, ceil_mode=False)
#     (7): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (8): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace)
#     (10): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (11): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace)
#     (13): MaxPool3d(kernel_size=(2, 2, 2), stride=(2, 2, 2), padding=0, dilation=1, ceil_mode=False)
#     (14): Conv3d(128, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (15): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU(inplace)
#     (17): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (18): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace)
#     (20): MaxPool3d(kernel_size=(2, 2, 2), stride=(2, 2, 2), padding=0, dilation=1, ceil_mode=False)
#     (21): Conv3d(256, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (22): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (23): ReLU(inplace)
#     (24): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (25): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (26): ReLU(inplace)
#     (27): MaxPool3d(kernel_size=(2, 2, 2), stride=(2, 2, 2), padding=0, dilation=1, ceil_mode=False)
#     (28): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (29): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (30): ReLU(inplace)
#     (31): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (32): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (33): ReLU(inplace)
#     (34): MaxPool3d(kernel_size=(2, 2, 2), stride=(2, 2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool3d(output_size=(1, 3, 3))
#   (classifier): Sequential(
#     (0): Linear(in_features=4608, out_features=4096, bias=True)
#     (1): ReLU(inplace)
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace)
#     (5): Dropout(p=0.5)
#     (6): Linear(in_features=4096, out_features=2, bias=True)
#   )
# )
# Epoch 0/39
# ----------
# train Loss: 0.7064 Acc: 0.5243
# Normal Acc: 0.4146 AD Acc: 0.6250
# Normal count: 1440 AD count: 1568
# val Loss: 0.7655 Acc: 0.3484
# Normal Acc: 0.2381 AD Acc: 0.9022
# Normal count: 462 AD count: 92
#
# Epoch 1/39
# ----------
# train Loss: 0.6952 Acc: 0.5595
# Normal Acc: 0.9160 AD Acc: 0.9994
# Normal count: 1440 AD count: 1568
# val Loss: 0.8310 Acc: 0.8087
# Normal Acc: 0.8745 AD Acc: 0.4783
# Normal count: 462 AD count: 92
#
# Epoch 34/39
# ----------
# train Loss: 0.1230 Acc: 0.9598
# Normal Acc: 0.9160 AD Acc: 1.0000
# Normal count: 1440 AD count: 1568
# val Loss: 0.8364 Acc: 0.8159
# Normal Acc: 0.8745 AD Acc: 0.5217
# Normal count: 462 AD count: 92
#
# Epoch 35/39
# ----------
# train Loss: 0.1207 Acc: 0.9598
# Normal Acc: 0.9160 AD Acc: 1.0000
# Normal count: 1440 AD count: 1568
# val Loss: 0.9890 Acc: 0.8123
# Normal Acc: 0.8723 AD Acc: 0.5109
# Normal count: 462 AD count: 92
#
# Epoch 36/39
# ----------
# train Loss: 0.1240 Acc: 0.9594
# Normal Acc: 0.9160 AD Acc: 0.9994
# Normal count: 1440 AD count: 1568
# val Loss: 0.9834 Acc: 0.8105
# Normal Acc: 0.8550 AD Acc: 0.5870
# Normal count: 462 AD count: 92
#
# Epoch 37/39
# ----------
# train Loss: 0.1235 Acc: 0.9594
# Normal Acc: 0.9153 AD Acc: 1.0000
# Normal count: 1440 AD count: 1568
# val Loss: 0.8300 Acc: 0.8051
# Normal Acc: 0.8788 AD Acc: 0.4348
# Normal count: 462 AD count: 92
#
# Epoch 38/39
# ----------
# train Loss: 0.1235 Acc: 0.9594
# Normal Acc: 0.9153 AD Acc: 1.0000
# Normal count: 1440 AD count: 1568
# val Loss: 0.9659 Acc: 0.8069
# Normal Acc: 0.8593 AD Acc: 0.5435
# Normal count: 462 AD count: 92
#
# Epoch 39/39
# ----------
# train Loss: 0.1200 Acc: 0.9594
# Normal Acc: 0.9153 AD Acc: 1.0000
# Normal count: 1440 AD count: 1568
# val Loss: 0.9095 Acc: 0.8105
# Normal Acc: 0.8680 AD Acc: 0.5217
# Normal count: 462 AD count: 92
#
# Training complete in 127m 22s
# Best val Acc (with true/false acc diff less than 10%): 0.787004

# %%
shist = []

from matplotlib.pyplot import figure
shist = [h.cpu().numpy() for h in scratch_hist]

figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

plt.title("Validation Accuracy vs. Number of Training Epochs")
plt.xlabel("Training Epochs")
plt.ylabel("Validation Accuracy")
plt.plot(range(1,num_epochs+1),shist,label="Scratch")
plt.ylim((0,1.))
plt.xticks(np.arange(1, num_epochs+1, 5.0))
plt.legend()
plt.show()

# %%
torch.save(scratch_model.state_dict(), "./vgg3d.pth")

model_ft = VGG3D()
num_ftrs = model_ft.classifier[6].in_features
model_ft.classifier[6] = nn.Linear(num_ftrs,num_classes)
input_size = (48, 96, 96)
scratch_model.load_state_dict(torch.load("./vgg3d.pth"))
scratch_model.eval()
scratch_model.to(device)

running_loss = 0.0
running_corrects = 0
normal_corrects, ad_corrects = 0, 0
normal_count, ad_count = 0, 0

for test_inputs, test_labels in test_dataset:
    test_inputs = test_inputs.unsqueeze(0)
    test_inputs = test_inputs.to(device)
    test_labels = test_labels.to(device)
    
    with torch.no_grad():
        test_outputs = scratch_model(test_inputs)
#         test_loss = scratch_criterion(test_outputs, test_labels)
        _, test_preds = torch.max(test_outputs, 1)
        test_preds = test_preds.squeeze(0)
        print(test_outputs)
        print(test_preds)
        print(test_labels)
        print()
        
        # statistics
#     running_loss += test_loss.item() * test_inputs.size(0)
    correctness = test_preds == test_labels
    running_corrects += torch.sum(correctness)

    if test_labels == 0:
        if correctness == 1:
            normal_corrects += 1
        normal_count += 1
    if test_labels == 1:
        if correctness == 1:
            ad_corrects += 1
        ad_count += 1
    
#     epoch_loss = running_loss / len(test_dataset.dataset)
epoch_acc = running_corrects.double() / len(test_dataset)
epoch_normal_acc = normal_corrects / normal_count
epoch_ad_acc = ad_corrects / ad_count

print('{} Acc: {:.4f}'.format('test', epoch_acc))
print('Normal Acc: {:.4f} AD Acc: {:.4f}'.format(epoch_normal_acc, epoch_ad_acc))
print('Normal count: {} AD count: {}'.format(normal_count, ad_count))
# Out:
# tensor([[ 3.7481, -3.8040]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 0.8528, -0.8981]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 2.9787, -3.0310]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 2.6518, -2.7043]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 4.8222, -4.8860]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 4.7557, -4.8267]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 1.0297, -1.0507]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 0.7460, -0.7951]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 2.1937, -2.2548]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 2.8655, -2.9183]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[-0.0761,  0.0354]], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 1.3551, -1.3880]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 1.2885, -1.3542]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 1.7643, -1.8168]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 0.1294, -0.1847]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 3.6574, -3.7111]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(1, device='cuda:0')
#
# tensor([[ 3.7331, -3.7853]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 4.5027, -4.5593]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[-0.5743,  0.5173]], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[-1.4341,  1.3877]], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
#
# tensor([[-0.0733,  0.0308]], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 0.3409, -0.3769]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 1.9522, -2.0058]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 2.1106, -2.1679]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 1.4752, -1.4993]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 1.5779, -1.6032]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 1.8082, -1.8667]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 1.6203, -1.6744]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 3.5069, -3.5590]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 4.1049, -4.1711]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[-0.1683,  0.1078]], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 2.1681, -2.2027]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[-1.2466,  1.1659]], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[-1.2581,  1.1677]], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[-1.3451,  1.2615]], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 3.0149, -3.0720]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[-1.4511,  1.3807]], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[-1.2577,  1.1886]], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[-0.8626,  0.8158]], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 1.9469, -1.9753]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 0.4758, -0.5087]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(1, device='cuda:0')
#
# tensor([[ 4.0363, -4.0803]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 1.3616, -1.3964]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 2.5814, -2.6290]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[-1.4857,  1.4217]], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
#
# tensor([[-1.3450,  1.2823]], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[-0.9445,  0.8935]], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 2.7814, -2.8353]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 1.7715, -1.7907]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[-0.6054,  0.5398]], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
#
# tensor([[ 1.8263, -1.8890]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 2.2209, -2.2791]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 2.3812, -2.4381]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 3.4018, -3.4754]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 0.8918, -0.9424]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 0.8608, -0.9278]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 3.9548, -4.0288]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 3.6841, -3.7473]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[-1.3069,  1.2246]], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[-1.2550,  1.1786]], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[-1.4122,  1.3195]], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[-1.3607,  1.2760]], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 1.4915, -1.5486]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 0.4415, -0.5010]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 1.6109, -1.6691]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 1.8665, -1.9347]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 2.5563, -2.6133]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 3.6871, -3.7570]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 2.8850, -2.9469]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 3.4391, -3.4988]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 2.5560, -2.6258]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 1.5636, -1.6126]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 0.5158, -0.5433]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 0.4662, -0.5124]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[-1.4112,  1.3375]], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[-1.1564,  1.0926]], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 2.8588, -2.9079]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[-0.7561,  0.6873]], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
#
# tensor([[-0.7943,  0.7122]], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 0.1572, -0.2114]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 2.7985, -2.8302]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 2.7467, -2.7828]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 1.7079, -1.7887]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 3.3858, -3.4465]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[-0.0668,  0.0074]], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 3.1483, -3.1721]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[-0.9190,  0.8485]], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 3.3890, -3.4322]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 0.3942, -0.4549]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 0.6830, -0.6984]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 0.1959, -0.2472]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[-0.3714,  0.3137]], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 2.1828, -2.2260]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 2.0571, -2.0874]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 3.4865, -3.5190]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 2.9028, -2.9416]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 2.3987, -2.4484]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 0.7435, -0.8251]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 3.2029, -3.2670]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 2.9033, -2.9678]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 1.5747, -1.6197]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 1.0124, -1.0762]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[-0.8906,  0.8423]], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
#
# tensor([[-1.0763,  1.0282]], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 3.3202, -3.3716]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 0.2038, -0.2543]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 2.7046, -2.7611]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 0.5844, -0.6097]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 0.7216, -0.7851]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 0.4859, -0.5493]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 3.2757, -3.3293]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 2.6985, -2.7511]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[-0.7213,  0.6665]], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[-1.0108,  0.9717]], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[-1.0522,  0.9795]], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[-0.6671,  0.6083]], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 0.1103, -0.1621]], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
# tensor([[ 3