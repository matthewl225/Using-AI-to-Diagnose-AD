# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cv2
import os
import torchvision
from torchvision import datasets, models, transforms
from torch.utils.data import Dataset, DataLoader
import time
import copy
print("PyTorch Version: ",torch.__version__)
print("Torchvision Version: ",torchvision.__version__)
# Out:
# PyTorch Version:  1.1.0
# Torchvision Version:  0.3.0

# %%
# CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
torch.backends.cudnn.benchmark = True
print(torch.cuda.get_device_name(0))
# Out:
# GeForce RTX 2060

# %%
runs_list = next(os.walk('./Data/Images'))[1]

# %%
path = "./Data/Labels.csv"
header = ['Run','AD']
Labelsdf = pd.read_csv(path, names=header, usecols=[1,2], skiprows=1, index_col=False)

# %%
labels_dict = dict(zip(Labelsdf.Run, Labelsdf.AD))

# %%
import re

# BASELINE RGB
img_dir = "./Data/Images"
low_bound = 100
high_bound = 200
img_scale = 1
depth_scale = 33

imgs, labels = [], []

for run in runs_list:
    run_dir = os.path.join(img_dir, run)
    run_imgs = []
    print(run_dir)
    for filename in os.listdir(run_dir):
        img_num = int(filename[-7:-4])
        if (100 <= img_num < 199):
            img_slice = cv2.imread(os.path.join(run_dir, filename), cv2.IMREAD_GRAYSCALE)
            img_slice = img_slice/256
            run_imgs.append(img_slice)

    temp_arr = np.array(run_imgs)
    
    if temp_arr.size == 0 or temp_arr.shape[1] != 256 or temp_arr.shape[2] != 176:
        continue

    # add black bars on the left/right
    temp_imgs = []
    for img_slice in temp_arr:
        final_slice = np.zeros([256,256])
        final_slice[:, 40:216] = img_slice
        temp_imgs.append(final_slice)
    
    temp_arr = np.array(temp_imgs)
    
    final_slices = []
    
    for y in range(temp_arr.shape[2]):
        xz_pane = temp_arr[:, :, y]
        scaled_xz = cv2.resize(xz_pane, (0, 0), fy=1/depth_scale, fx=1, interpolation=cv2.INTER_AREA)
        final_slices.append(scaled_xz)
    
    if not len(final_slices[0]) == 3:
        continue
    
    final_array = np.dstack(final_slices)
    # Doesn't exist in labels
    if run in labels_dict:
        imgs.append(final_array)
        labels.append(labels_dict[run])

imgs = np.array(imgs)
labels = np.array(labels)
# Out:
# ./Data/Images\sub-OAS30001_ses-d0129_run-01
# ./Data/Images\sub-OAS30001_ses-d0129_run-02
# ./Data/Images\sub-OAS30001_ses-d0757_run-01
# ./Data/Images\sub-OAS30001_ses-d0757_run-02
# ./Data/Images\sub-OAS30001_ses-d2430
# ./Data/Images\sub-OAS30001_ses-d3132
# ./Data/Images\sub-OAS30002_ses-d0371
# ./Data/Images\sub-OAS30002_ses-d0653_run-01
# ./Data/Images\sub-OAS30002_ses-d0653_run-02
# ./Data/Images\sub-OAS30002_ses-d2340_run-01
# ./Data/Images\sub-OAS30002_ses-d2340_run-02
# ./Data/Images\sub-OAS30002_ses-d2345
# ./Data/Images\sub-OAS30003_ses-d0558_run-01
# ./Data/Images\sub-OAS30003_ses-d0558_run-02
# ./Data/Images\sub-OAS30003_ses-d1631_run-01
# ./Data/Images\sub-OAS30003_ses-d1631_run-02
# ./Data/Images\sub-OAS30003_ses-d2669
# ./Data/Images\sub-OAS30003_ses-d2682
# ./Data/Images\sub-OAS30003_ses-d3320
# ./Data/Images\sub-OAS30003_ses-d3731
# ./Data/Images\sub-OAS30004_ses-d1101_run-01
# ./Data/Images\sub-OAS30004_ses-d1101_run-02
# ./Data/Images\sub-OAS30004_ses-d2229_run-01
# ./Data/Images\sub-OAS30004_ses-d2229_run-02
# ./Data/Images\sub-OAS30004_ses-d2232_run-01
# ./Data/Images\sub-OAS30004_ses-d2232_run-02
# ./Data/Images\sub-OAS30004_ses-d3457
# ./Data/Images\sub-OAS30005_ses-d0143
# ./Data/Images\sub-OAS30005_ses-d0581_run-01
# ./Data/Images\sub-OAS30005_ses-d0581_run-02
# ./Data/Images\sub-OAS30005_ses-d1274_run-01
# ./Data/Images\sub-OAS30005_ses-d1274_run-02
# ./Data/Images\sub-OAS30005_ses-d2377
# ./Data/Images\sub-OAS30005_ses-d2384
# ./Data/Images\sub-OAS30005_ses-d3453
# ./Data/Images\sub-OAS30006_ses-d0166
# ./Data/Images\sub-OAS30006_ses-d0373_run-01
# ./Data/Images\sub-OAS30006_ses-d0373_run-02
# ./Data/Images\sub-OAS30006_ses-d2341
# ./Data/Images\sub-OAS30006_ses-d2342
# ./Data/Images\sub-OAS30006_ses-d3386
# ./Data/Images\sub-OAS30007_ses-d0061_run-01
# ./Data/Images\sub-OAS30007_ses-d0061_run-02
# ./Data/Images\sub-OAS30007_ses-d1636
# ./Data/Images\sub-OAS30007_ses-d1641
# ./Data/Images\sub-OAS30007_ses-d1981
# ./Data/Images\sub-OAS30007_ses-d2722
# ./Data/Images\sub-OAS30008_ses-d0061_run-01
# ./Data/Images\sub-OAS30008_ses-d0061_run-02
# ./Data/Images\sub-OAS30008_ses-d1313
# ./Data/Images\sub-OAS30008_ses-d1327
# ./Data/Images\sub-OAS30008_ses-d2035
# ./Data/Images\sub-OAS30009_ses-d0148_run-01
# ./Data/Images\sub-OAS30009_ses-d0148_run-02
# ./Data/Images\sub-OAS30009_ses-d1210
# ./Data/Images\sub-OAS30009_ses-d2457
# ./Data/Images\sub-OAS30010_ses-d0068
# ./Data/Images\sub-OAS30011_ses-d0055
# ./Data/Images\sub-OAS30011_ses-d1671
# ./Data/Images\sub-OAS30012_ses-d0124_run-01
# ./Data/Images\sub-OAS30012_ses-d0124_run-02
# ./Data/Images\sub-OAS30012_ses-d0124_run-03
# ./Data/Images\sub-OAS30012_ses-d0581_run-01
# ./Data/Images\sub-OAS30012_ses-d0581_run-02
# ./Data/Images\sub-OAS30012_ses-d0581_run-03
# ./Data/Images\sub-OAS30013_ses-d0102
# ./Data/Images\sub-OAS30014_ses-d0196_run-01
# ./Data/Images\sub-OAS30014_ses-d0196_run-02
# ./Data/Images\sub-OAS30014_ses-d1176_run-01
# ./Data/Images\sub-OAS30014_ses-d1176_run-02
# ./Data/Images\sub-OAS30015_ses-d0116_run-01
# ./Data/Images\sub-OAS30015_ses-d0116_run-02
# ./Data/Images\sub-OAS30015_ses-d0788_run-01
# ./Data/Images\sub-OAS30015_ses-d0788_run-02
# ./Data/Images\sub-OAS30015_ses-d1374_run-01
# ./Data/Images\sub-OAS30015_ses-d1374_run-02
# ./Data/Images\sub-OAS30015_ses-d2004
# ./Data/Images\sub-OAS30016_ses-d0021
# ./Data/Images\sub-OAS30017_ses-d0054_run-01
# ./Data/Images\sub-OAS30017_ses-d0054_run-02
# ./Data/Images\sub-OAS30018_ses-d0070_run-01
# ./Data/Images\sub-OAS30018_ses-d0070_run-02
# ./Data/Images\sub-OAS30018_ses-d0893
# ./Data/Images\sub-OAS30019_ses-d0376
# ./Data/Images\sub-OAS30020_ses-d0092_run-01
# ./Data/Images\sub-OAS30020_ses-d0092_run-02
# ./Data/Images\sub-OAS30020_ses-d0092_run-03
# ./Data/Images\sub-OAS30020_ses-d0092_run-04
# ./Data/Images\sub-OAS30020_ses-d0911_run-01
# ./Data/Images\sub-OAS30020_ses-d0911_run-02
# ./Data/Images\sub-OAS30020_ses-d0911_run-03
# ./Data/Images\sub-OAS30021_ses-d0071
# ./Data/Images\sub-OAS30022_ses-d1324_run-01
# ./Data/Images\sub-OAS30022_ses-d1324_run-02
# ./Data/Images\sub-OAS30022_ses-d1324_run-03
# ./Data/Images\sub-OAS30024_ses-d0084
# ./Data/Images\sub-OAS30025_ses-d0210_run-01
# ./Data/Images\sub-OAS30025_ses-d0210_run-02
# ./Data/Images\sub-OAS30025_ses-d2298
# ./Data/Images\sub-OAS30026_ses-d0048
# ./Data/Images\sub-OAS30026_ses-d0129
# ./Data/Images\sub-OAS30026_ses-d0696
# ./Data/Images\sub-OAS30027_ses-d0433_run-01
# ./Data/Images\sub-OAS30027_ses-d0433_run-02
# ./Data/Images\sub-OAS30027_ses-d0433_run-03
# ./Data/Images\sub-OAS30027_ses-d1300_run-01
# ./Data/Images\sub-OAS30027_ses-d1300_run-02
# ./Data/Images\sub-OAS30027_ses-d2394
# ./Data/Images\sub-OAS30028_ses-d0043_run-01
# ./Data/Images\sub-OAS30028_ses-d0043_run-02
# ./Data/Images\sub-OAS30028_ses-d1260
# ./Data/Images\sub-OAS30028_ses-d1847
# ./Data/Images\sub-OAS30029_ses-d0131
# ./Data/Images\sub-OAS30029_ses-d0893
# ./Data/Images\sub-OAS30030_ses-d0170
# ./Data/Images\sub-OAS30031_ses-d0427_run-01
# ./Data/Images\sub-OAS30031_ses-d0427_run-02
# ./Data/Images\sub-OAS30032_ses-d0262_run-01
# ./Data/Images\sub-OAS30032_ses-d0262_run-02
# ./Data/Images\sub-OAS30032_ses-d0262_run-03
# ./Data/Images\sub-OAS30032_ses-d1661_run-01
# ./Data/Images\sub-OAS30032_ses-d1661_run-02
# ./Data/Images\sub-OAS30032_ses-d3499
# ./Data/Images\sub-OAS30033_ses-d0133_run-01
# ./Data/Images\sub-OAS30033_ses-d0133_run-02
# ./Data/Images\sub-OAS30033_ses-d1267
# ./Data/Images\sub-OAS30034_ses-d0044
# ./Data/Images\sub-OAS30035_ses-d2218_run-01
# ./Data/Images\sub-OAS30035_ses-d2218_run-02
# ./Data/Images\sub-OAS30035_ses-d3850
# ./Data/Images\sub-OAS30036_ses-d0059
# ./Data/Images\sub-OAS30037_ses-d0154
# ./Data/Images\sub-OAS30038_ses-d1214_run-01
# ./Data/Images\sub-OAS30038_ses-d1214_run-02
# ./Data/Images\sub-OAS30038_ses-d1214_run-03
# ./Data/Images\sub-OAS30038_ses-d2242_run-01
# ./Data/Images\sub-OAS30038_ses-d2242_run-02
# ./Data/Images\sub-OAS30038_ses-d3376
# ./Data/Images\sub-OAS30038_ses-d4495
# ./Data/Images\sub-OAS30039_ses-d0103
# ./Data/Images\sub-OAS30040_ses-d2899_run-01
# ./Data/Images\sub-OAS30040_ses-d2899_run-02
# ./Data/Images\sub-OAS30040_ses-d2899_run-03
# ./Data/Images\sub-OAS30040_ses-d4230_run-01
# ./Data/Images\sub-OAS30040_ses-d4230_run-02
# ./Data/Images\sub-OAS30040_ses-d5108
# ./Data/Images\sub-OAS30041_ses-d6548_run-01
# ./Data/Images\sub-OAS30041_ses-d6548_run-02
# ./Data/Images\sub-OAS30041_ses-d6548_run-03
# ./Data/Images\sub-OAS30041_ses-d6548_run-04
# ./Data/Images\sub-OAS30041_ses-d6548_run-05
# ./Data/Images\sub-OAS30042_ses-d0067
# ./Data/Images\sub-OAS30043_ses-d0145
# ./Data/Images\sub-OAS30044_ses-d0054
# ./Data/Images\sub-OAS30044_ses-d0061_run-01
# ./Data/Images\sub-OAS30044_ses-d0061_run-02
# ./Data/Images\sub-OAS30044_ses-d1319
# ./Data/Images\sub-OAS30046_ses-d0072_run-01
# ./Data/Images\sub-OAS30046_ses-d0072_run-02
# ./Data/Images\sub-OAS30046_ses-d0848
# ./Data/Images\sub-OAS30046_ses-d1968
# ./Data/Images\sub-OAS30048_ses-d0983_run-01
# ./Data/Images\sub-OAS30048_ses-d0983_run-02
# ./Data/Images\sub-OAS30048_ses-d0983_run-03
# ./Data/Images\sub-OAS30048_ses-d2292_run-01
# ./Data/Images\sub-OAS30048_ses-d2292_run-02
# ./Data/Images\sub-OAS30048_ses-d3367
# ./Data/Images\sub-OAS30048_ses-d3375_run-01
# ./Data/Images\sub-OAS30048_ses-d3375_run-02
# ./Data/Images\sub-OAS30048_ses-d3731
# ./Data/Images\sub-OAS30048_ses-d4459
# ./Data/Images\sub-OAS30049_ses-d0013_run-01
# ./Data/Images\sub-OAS30049_ses-d0013_run-02
# ./Data/Images\sub-OAS30049_ses-d1633
# ./Data/Images\sub-OAS30050_ses-d0110
# ./Data/Images\sub-OAS30050_ses-d1530
# ./Data/Images\sub-OAS30051_ses-d0200_run-01
# ./Data/Images\sub-OAS30051_ses-d0200_run-02
# ./Data/Images\sub-OAS30051_ses-d1286
# ./Data/Images\sub-OAS30052_ses-d0693_run-01
# ./Data/Images\sub-OAS30052_ses-d0693_run-02
# ./Data/Images\sub-OAS30052_ses-d1296_run-01
# ./Data/Images\sub-OAS30052_ses-d1296_run-02
# ./Data/Images\sub-OAS30052_ses-d2709
# ./Data/Images\sub-OAS30052_ses-d2737_run-01
# ./Data/Images\sub-OAS30052_ses-d2737_run-02
# ./Data/Images\sub-OAS30053_ses-d0428_run-01
# ./Data/Images\sub-OAS30053_ses-d0428_run-02
# ./Data/Images\sub-OAS30056_ses-d3491
# ./Data/Images\sub-OAS30057_ses-d0075
# ./Data/Images\sub-OAS30058_ses-d1316_run-01
# ./Data/Images\sub-OAS30058_ses-d1316_run-02
# ./Data/Images\sub-OAS30058_ses-d2236
# ./Data/Images\sub-OAS30058_ses-d3235
# ./Data/Images\sub-OAS30059_ses-d0230_run-01
# ./Data/Images\sub-OAS30059_ses-d0230_run-02
# ./Data/Images\sub-OAS30059_ses-d0230_run-03
# ./Data/Images\sub-OAS30059_ses-d0230_run-04
# ./Data/Images\sub-OAS30059_ses-d1188
# ./Data/Images\sub-OAS30060_ses-d0074_run-01
# ./Data/Images\sub-OAS30060_ses-d0074_run-02
# ./Data/Images\sub-OAS30061_ses-d0035
# ./Data/Images\sub-OAS30062_ses-d0087_run-01
# ./Data/Images\sub-OAS30062_ses-d0087_run-02
# ./Data/Images\sub-OAS30062_ses-d0087_run-03
# ./Data/Images\sub-OAS30062_ses-d1134_run-01
# ./Data/Images\sub-OAS30062_ses-d1134_run-02
# ./Data/Images\sub-OAS30062_ses-d1745_run-01
# ./Data/Images\sub-OAS30062_ses-d1745_run-02
# ./Data/Images\sub-OAS30062_ses-d3432
# ./Data/Images\sub-OAS30062_ses-d3469
# ./Data/Images\sub-OAS30063_ses-d0160_run-01
# ./Data/Images\sub-OAS30063_ses-d0160_run-02
# ./Data/Images\sub-OAS30064_ses-d0687_run-01
# ./Data/Images\sub-OAS30064_ses-d0687_run-02
# ./Data/Images\sub-OAS30065_ses-d0548
# ./Data/Images\sub-OAS30065_ses-d2009
# ./Data/Images\sub-OAS30066_ses-d0524
# ./Data/Images\sub-OAS30066_ses-d2006
# ./Data/Images\sub-OAS30067_ses-d0057
# ./Data/Images\sub-OAS30068_ses-d0076
# ./Data/Images\sub-OAS30070_ses-d0070
# ./Data/Images\sub-OAS30071_ses-d0018
# ./Data/Images\sub-OAS30071_ses-d0055
# ./Data/Images\sub-OAS30072_ses-d0218_run-01
# ./Data/Images\sub-OAS30072_ses-d0218_run-02
# ./Data/Images\sub-OAS30072_ses-d0218_run-03
# ./Data/Images\sub-OAS30072_ses-d1379_run-01
# ./Data/Images\sub-OAS30072_ses-d1379_run-02
# ./Data/Images\sub-OAS30072_ses-d2219
# ./Data/Images\sub-OAS30073_ses-d0033_run-01
# ./Data/Images\sub-OAS30073_ses-d0033_run-02
# ./Data/Images\sub-OAS30073_ses-d0033_run-03
# ./Data/Images\sub-OAS30073_ses-d0033_run-04
# ./Data/Images\sub-OAS30073_ses-d1587_run-01
# ./Data/Images\sub-OAS30073_ses-d1587_run-02
# ./Data/Images\sub-OAS30073_ses-d2042_run-01
# ./Data/Images\sub-OAS30073_ses-d2042_run-02
# ./Data/Images\sub-OAS30073_ses-d2851
# ./Data/Images\sub-OAS30073_ses-d3670
# ./Data/Images\sub-OAS30073_ses-d4456
# ./Data/Images\sub-OAS30074_ses-d0049_run-01
# ./Data/Images\sub-OAS30074_ses-d0049_run-02
# ./Data/Images\sub-OAS30074_ses-d1871
# ./Data/Images\sub-OAS30074_ses-d2812
# ./Data/Images\sub-OAS30075_ses-d0143
# ./Data/Images\sub-OAS30075_ses-d0148_run-01
# ./Data/Images\sub-OAS30075_ses-d0148_run-02
# ./Data/Images\sub-OAS30075_ses-d0442
# ./Data/Images\sub-OAS30075_ses-d0967
# ./Data/Images\sub-OAS30076_ses-d0534_run-01
# ./Data/Images\sub-OAS30076_ses-d0534_run-02
# ./Data/Images\sub-OAS30076_ses-d1735
# ./Data/Images\sub-OAS30077_ses-d0944
# ./Data/Images\sub-OAS30078_ses-d0210_run-01
# ./Data/Images\sub-OAS30078_ses-d0210_run-02
# ./Data/Images\sub-OAS30079_ses-d0019_run-01
# ./Data/Images\sub-OAS30079_ses-d0019_run-02
# ./Data/Images\sub-OAS30079_ses-d1833
# ./Data/Images\sub-OAS30079_ses-d2668
# ./Data/Images\sub-OAS30080_ses-d0048
# ./Data/Images\sub-OAS30080_ses-d1318
# ./Data/Images\sub-OAS30082_ses-d1700_run-01
# ./Data/Images\sub-OAS30082_ses-d1700_run-02
# ./Data/Images\sub-OAS30083_ses-d0465_run-01
# ./Data/Images\sub-OAS30083_ses-d0465_run-02
# ./Data/Images\sub-OAS30083_ses-d2882
# ./Data/Images\sub-OAS30083_ses-d3827
# ./Data/Images\sub-OAS30084_ses-d0470_run-01
# ./Data/Images\sub-OAS30084_ses-d0470_run-02
# ./Data/Images\sub-OAS30084_ses-d1360
# ./Data/Images\sub-OAS30085_ses-d1566
# ./Data/Images\sub-OAS30086_ses-d0000_run-01
# ./Data/Images\sub-OAS30086_ses-d0000_run-02
# ./Data/Images\sub-OAS30087_ses-d0260_run-01
# ./Data/Images\sub-OAS30087_ses-d0260_run-02
# ./Data/Images\sub-OAS30088_ses-d0093_run-01
# ./Data/Images\sub-OAS30088_ses-d0093_run-02
# ./Data/Images\sub-OAS30089_ses-d0001
# ./Data/Images\sub-OAS30090_ses-d0118
# ./Data/Images\sub-OAS30090_ses-d1294
# ./Data/Images\sub-OAS30091_ses-d0092_run-01
# ./Data/Images\sub-OAS30091_ses-d0092_run-02
# ./Data/Images\sub-OAS30092_ses-d0636
# ./Data/Images\sub-OAS30092_ses-d3727
# ./Data/Images\sub-OAS30093_ses-d0056
# ./Data/Images\sub-OAS30093_ses-d0070
# ./Data/Images\sub-OAS30093_ses-d1192
# ./Data/Images\sub-OAS30094_ses-d0140_run-01
# ./Data/Images\sub-OAS30094_ses-d0140_run-02
# ./Data/Images\sub-OAS30094_ses-d0140_run-03
# ./Data/Images\sub-OAS30094_ses-d0679_run-01
# ./Data/Images\sub-OAS30094_ses-d0679_run-02
# ./Data/Images\sub-OAS30094_ses-d0679_run-03
# ./Data/Images\sub-OAS30095_ses-d0033
# ./Data/Images\sub-OAS30096_ses-d0024_run-01
# ./Data/Images\sub-OAS30096_ses-d0024_run-02
# ./Data/Images\sub-OAS30097_ses-d0504_run-01
# ./Data/Images\sub-OAS30097_ses-d0504_run-02
# ./Data/Images\sub-OAS30097_ses-d2551
# ./Data/Images\sub-OAS30098_ses-d0036
# ./Data/Images\sub-OAS30099_ses-d0032
# ./Data/Images\sub-OAS30100_ses-d0158
# ./Data/Images\sub-OAS30101_ses-d0101_run-01
# ./Data/Images\sub-OAS30101_ses-d0101_run-02
# ./Data/Images\sub-OAS30101_ses-d0919_run-01
# ./Data/Images\sub-OAS30101_ses-d0919_run-02
# ./Data/Images\sub-OAS30101_ses-d2650
# ./Data/Images\sub-OAS30102_ses-d0024
# ./Data/Images\sub-OAS30103_ses-d3306_run-01
# ./Data/Images\sub-OAS30103_ses-d3306_run-02
# ./Data/Images\sub-OAS30103_ses-d3306_run-03
# ./Data/Images\sub-OAS30103_ses-d4255_run-01
# ./Data/Images\sub-OAS30103_ses-d4255_run-02
# ./Data/Images\sub-OAS30104_ses-d0328_run-01
# ./Data/Images\sub-OAS30104_ses-d0328_run-02
# ./Data/Images\sub-OAS30105_ses-d0056
# ./Data/Images\sub-OAS30106_ses-d2982_run-01
# ./Data/Images\sub-OAS30106_ses-d2982_run-02
# ./Data/Images\sub-OAS30106_ses-d2982_run-03
# ./Data/Images\sub-OAS30106_ses-d4675
# ./Data/Images\sub-OAS30107_ses-d0387_run-01
# ./Data/Images\sub-OAS30107_ses-d0387_run-02
# ./Data/Images\sub-OAS30107_ses-d0940_run-01
# ./Data/Images\sub-OAS30107_ses-d0940_run-02
# ./Data/Images\sub-OAS30107_ses-d2765
# ./Data/Images\sub-OAS30108_ses-d0168_run-01
# ./Data/Images\sub-OAS30108_ses-d0168_run-02
# ./Data/Images\sub-OAS30108_ses-d1062
# ./Data/Images\sub-OAS30108_ses-d2066
# ./Data/Images\sub-OAS30109_ses-d0270
# ./Data/Images\sub-OAS30109_ses-d0432_run-01
# ./Data/Images\sub-OAS30109_ses-d0432_run-02
# ./Data/Images\sub-OAS30109_ses-d0997_run-01
# ./Data/Images\sub-OAS30109_ses-d0997_run-02
# ./Data/Images\sub-OAS30109_ses-d2310
# ./Data/Images\sub-OAS30109_ses-d2320
# ./Data/Images\sub-OAS30110_ses-d0155_run-01
# ./Data/Images\sub-OAS30110_ses-d0155_run-02
# ./Data/Images\sub-OAS30111_ses-d0385_run-01
# ./Data/Images\sub-OAS30111_ses-d0385_run-02
# ./Data/Images\sub-OAS30112_ses-d0091
# ./Data/Images\sub-OAS30112_ses-d0098
# ./Data/Images\sub-OAS30112_ses-d0259
# ./Data/Images\sub-OAS30112_ses-d1196
# ./Data/Images\sub-OAS30113_ses-d0894
# ./Data/Images\sub-OAS30113_ses-d1301_run-01
# ./Data/Images\sub-OAS30113_ses-d1301_run-02
# ./Data/Images\sub-OAS30113_ses-d2280_run-01
# ./Data/Images\sub-OAS30113_ses-d2280_run-02
# ./Data/Images\sub-OAS30113_ses-d3502
# ./Data/Images\sub-OAS30113_ses-d4047
# ./Data/Images\sub-OAS30113_ses-d4437
# ./Data/Images\sub-OAS30114_ses-d0086
# ./Data/Images\sub-OAS30115_ses-d0138
# ./Data/Images\sub-OAS30116_ses-d0017_run-01
# ./Data/Images\sub-OAS30116_ses-d0017_run-02
# ./Data/Images\sub-OAS30117_ses-d2034_run-01
# ./Data/Images\sub-OAS30117_ses-d2034_run-02
# ./Data/Images\sub-OAS30117_ses-d4155
# ./Data/Images\sub-OAS30118_ses-d0000_run-01
# ./Data/Images\sub-OAS30118_ses-d0000_run-02
# ./Data/Images\sub-OAS30118_ses-d0000_run-03
# ./Data/Images\sub-OAS30118_ses-d1663_run-01
# ./Data/Images\sub-OAS30118_ses-d1663_run-02
# ./Data/Images\sub-OAS30119_ses-d1209_run-01
# ./Data/Images\sub-OAS30119_ses-d1209_run-02
# ./Data/Images\sub-OAS30119_ses-d1209_run-03
# ./Data/Images\sub-OAS30119_ses-d2415_run-01
# ./Data/Images\sub-OAS30119_ses-d2415_run-02
# ./Data/Images\sub-OAS30119_ses-d3260_run-01
# ./Data/Images\sub-OAS30119_ses-d3260_run-02
# ./Data/Images\sub-OAS30119_ses-d3722
# ./Data/Images\sub-OAS30120_ses-d0784_run-01
# ./Data/Images\sub-OAS30120_ses-d0784_run-02
# ./Data/Images\sub-OAS30120_ses-d0784_run-03
# ./Data/Images\sub-OAS30120_ses-d0784_run-04
# ./Data/Images\sub-OAS30121_ses-d0768_run-01
# ./Data/Images\sub-OAS30121_ses-d0768_run-02
# ./Data/Images\sub-OAS30121_ses-d0768_run-03
# ./Data/Images\sub-OAS30121_ses-d0768_run-04
# ./Data/Images\sub-OAS30121_ses-d2392_run-01
# ./Data/Images\sub-OAS30121_ses-d2392_run-02
# ./Data/Images\sub-OAS30122_ses-d0136
# ./Data/Images\sub-OAS30123_ses-d0122
# ./Data/Images\sub-OAS30124_ses-d0046_run-01
# ./Data/Images\sub-OAS30124_ses-d0046_run-02
# ./Data/Images\sub-OAS30125_ses-d0201_run-01
# ./Data/Images\sub-OAS30125_ses-d0201_run-02
# ./Data/Images\sub-OAS30126_ses-d1105_run-01
# ./Data/Images\sub-OAS30126_ses-d1105_run-02
# ./Data/Images\sub-OAS30126_ses-d2361
# ./Data/Images\sub-OAS30126_ses-d2849
# ./Data/Images\sub-OAS30126_ses-d3465
# ./Data/Images\sub-OAS30127_ses-d0098
# ./Data/Images\sub-OAS30127_ses-d0110
# ./Data/Images\sub-OAS30127_ses-d0837
# ./Data/Images\sub-OAS30128_ses-d0044
# ./Data/Images\sub-OAS30129_ses-d0055
# ./Data/Images\sub-OAS30130_ses-d0025_run-01
# ./Data/Images\sub-OAS30130_ses-d0025_run-02
# ./Data/Images\sub-OAS30131_ses-d0086_run-01
# ./Data/Images\sub-OAS30131_ses-d0086_run-02
# ./Data/Images\sub-OAS30131_ses-d0086_run-03
# ./Data/Images\sub-OAS30131_ses-d0632_run-01
# ./Data/Images\sub-OAS30131_ses-d0632_run-02
# ./Data/Images\sub-OAS30131_ses-d0632_run-03
# ./Data/Images\sub-OAS30131_ses-d1901_run-01
# ./Data/Images\sub-OAS30131_ses-d1901_run-02
# ./Data/Images\sub-OAS30132_ses-d0063_run-01
# ./Data/Images\sub-OAS30132_ses-d0063_run-02
# ./Data/Images\sub-OAS30132_ses-d1392
# ./Data/Images\sub-OAS30132_ses-d2288
# ./Data/Images\sub-OAS30133_ses-d0505
# ./Data/Images\sub-OAS30134_ses-d0080_run-01
# ./Data/Images\sub-OAS30134_ses-d0080_run-02
# ./Data/Images\sub-OAS30134_ses-d1642
# ./Data/Images\sub-OAS30135_ses-d0190
# ./Data/Images\sub-OAS30135_ses-d0341_run-01
# ./Data/Images\sub-OAS30135_ses-d0341_run-02
# ./Data/Images\sub-OAS30135_ses-d1000_run-01
# ./Data/Images\sub-OAS30135_ses-d1000_run-02
# ./Data/Images\sub-OAS30135_ses-d2357
# ./Data/Images\sub-OAS30135_ses-d2367
# ./Data/Images\sub-OAS30135_ses-d2799
# ./Data/Images\sub-OAS30135_ses-d2931
# ./Data/Images\sub-OAS30136_ses-d0063
# ./Data/Images\sub-OAS30137_ses-d3165
# ./Data/Images\sub-OAS30137_ses-d3907
# ./Data/Images\sub-OAS30137_ses-d4208
# ./Data/Images\sub-OAS30137_ses-d4525
# ./Data/Images\sub-OAS30139_ses-d0101
# ./Data/Images\sub-OAS30139_ses-d1702
# ./Data/Images\sub-OAS30140_ses-d0172_run-01
# ./Data/Images\sub-OAS30140_ses-d0172_run-02
# ./Data/Images\sub-OAS30141_ses-d0544
# ./Data/Images\sub-OAS30141_ses-d1306
# ./Data/Images\sub-OAS30142_ses-d0075_run-01
# ./Data/Images\sub-OAS30142_ses-d0075_run-02
# ./Data/Images\sub-OAS30142_ses-d1279
# ./Data/Images\sub-OAS30143_ses-d2235_run-01
# ./Data/Images\sub-OAS30143_ses-d2235_run-02
# ./Data/Images\sub-OAS30143_ses-d3507
# ./Data/Images\sub-OAS30143_ses-d3509
# ./Data/Images\sub-OAS30143_ses-d3856
# ./Data/Images\sub-OAS30143_ses-d4041
# ./Data/Images\sub-OAS30144_ses-d1204_run-01
# ./Data/Images\sub-OAS30144_ses-d1204_run-02
# ./Data/Images\sub-OAS30144_ses-d1204_run-03
# ./Data/Images\sub-OAS30145_ses-d3506_run-01
# ./Data/Images\sub-OAS30145_ses-d3506_run-02
# ./Data/Images\sub-OAS30145_ses-d4247_run-01
# ./Data/Images\sub-OAS30145_ses-d4247_run-02
# ./Data/Images\sub-OAS30146_ses-d0272_run-01
# ./Data/Images\sub-OAS30146_ses-d0272_run-02
# ./Data/Images\sub-OAS30146_ses-d1042_run-01
# ./Data/Images\sub-OAS30146_ses-d1042_run-02
# ./Data/Images\sub-OAS30146_ses-d2309
# ./Data/Images\sub-OAS30146_ses-d3322
# ./Data/Images\sub-OAS30147_ses-d0048
# ./Data/Images\sub-OAS30149_ses-d0051
# ./Data/Images\sub-OAS30149_ses-d1240
# ./Data/Images\sub-OAS30150_ses-d0100_run-01
# ./Data/Images\sub-OAS30150_ses-d0100_run-02
# ./Data/Images\sub-OAS30151_ses-d0064
# ./Data/Images\sub-OAS30152_ses-d0111_run-01
# ./Data/Images\sub-OAS30152_ses-d0111_run-02
# ./Data/Images\sub-OAS30153_ses-d2220_run-01
# ./Data/Images\sub-OAS30153_ses-d2220_run-02
# ./Data/Images\sub-OAS30153_ses-d2220_run-03
# ./Data/Images\sub-OAS30153_ses-d2220_run-04
# ./Data/Images\sub-OAS30153_ses-d3877_run-01
# ./Data/Images\sub-OAS30153_ses-d3877_run-02
# ./Data/Images\sub-OAS30154_ses-d0244
# ./Data/Images\sub-OAS30155_ses-d0785
# ./Data/Images\sub-OAS30156_ses-d0000_run-01
# ./Data/Images\sub-OAS30156_ses-d0000_run-02
# ./Data/Images\sub-OAS30156_ses-d0000_run-03
# ./Data/Images\sub-OAS30156_ses-d0503_run-01
# ./Data/Images\sub-OAS30156_ses-d0503_run-02
# ./Data/Images\sub-OAS30157_ses-d0889_run-01
# ./Data/Images\sub-OAS30157_ses-d0889_run-02
# ./Data/Images\sub-OAS30157_ses-d0889_run-03
# ./Data/Images\sub-OAS30157_ses-d1428_run-01
# ./Data/Images\sub-OAS30157_ses-d1428_run-02
# ./Data/Images\sub-OAS30157_ses-d1428_run-03
# ./Data/Images\sub-OAS30157_ses-d2674_run-01
# ./Data/Images\sub-OAS30157_ses-d2674_run-02
# ./Data/Images\sub-OAS30158_ses-d2467_run-01
# ./Data/Images\sub-OAS30158_ses-d2467_run-02
# ./Data/Images\sub-OAS30159_ses-d0110
# ./Data/Images\sub-OAS30160_ses-d0099_run-01
# ./Data/Images\sub-OAS30160_ses-d0099_run-02
# ./Data/Images\sub-OAS30160_ses-d0751_run-01
# ./Data/Images\sub-OAS30160_ses-d0751_run-02
# ./Data/Images\sub-OAS30160_ses-d2392
# ./Data/Images\sub-OAS30161_ses-d0297_run-01
# ./Data/Images\sub-OAS30161_ses-d0297_run-02
# ./Data/Images\sub-OAS30161_ses-d2517
# ./Data/Images\sub-OAS30163_ses-d0091_run-01
# ./Data/Images\sub-OAS30163_ses-d0091_run-02
# ./Data/Images\sub-OAS30164_ses-d0233_run-01
# ./Data/Images\sub-OAS30164_ses-d0233_run-02
# ./Data/Images\sub-OAS30164_ses-d0975_run-01
# ./Data/Images\sub-OAS30164_ses-d0975_run-02
# ./Data/Images\sub-OAS30164_ses-d2416
# ./Data/Images\sub-OAS30165_ses-d0563_run-01
# ./Data/Images\sub-OAS30165_ses-d0563_run-02
# ./Data/Images\sub-OAS30165_ses-d1763
# ./Data/Images\sub-OAS30167_ses-d0111
# ./Data/Images\sub-OAS30167_ses-d1340
# ./Data/Images\sub-OAS30168_ses-d0059_run-01
# ./Data/Images\sub-OAS30168_ses-d0059_run-02
# ./Data/Images\sub-OAS30168_ses-d1268
# ./Data/Images\sub-OAS30169_ses-d0282_run-01
# ./Data/Images\sub-OAS30169_ses-d0282_run-02
# ./Data/Images\sub-OAS30170_ses-d0005
# ./Data/Images\sub-OAS30171_ses-d0139_run-01
# ./Data/Images\sub-OAS30171_ses-d0139_run-02
# ./Data/Images\sub-OAS30172_ses-d0028_run-01
# ./Data/Images\sub-OAS30172_ses-d0028_run-02
# ./Data/Images\sub-OAS30173_ses-d1188_run-01
# ./Data/Images\sub-OAS30173_ses-d1188_run-02
# ./Data/Images\sub-OAS30173_ses-d3030
# ./Data/Images\sub-OAS30173_ses-d3841
# ./Data/Images\sub-OAS30174_ses-d0582_run-01
# ./Data/Images\sub-OAS30174_ses-d0582_run-02
# ./Data/Images\sub-OAS30175_ses-d0349_run-01
# ./Data/Images\sub-OAS30175_ses-d0349_run-02
# ./Data/Images\sub-OAS30175_ses-d1091_run-01
# ./Data/Images\sub-OAS30175_ses-d1091_run-02
# ./Data/Images\sub-OAS30175_ses-d3219
# ./Data/Images\sub-OAS30176_ses-d0000
# ./Data/Images\sub-OAS30178_ses-d0049
# ./Data/Images\sub-OAS30178_ses-d0516_run-01
# ./Data/Images\sub-OAS30178_ses-d0516_run-02
# ./Data/Images\sub-OAS30178_ses-d1384_run-01
# ./Data/Images\sub-OAS30178_ses-d1384_run-02
# ./Data/Images\sub-OAS30178_ses-d2443
# ./Data/Images\sub-OAS30178_ses-d2455_run-01
# ./Data/Images\sub-OAS30178_ses-d2455_run-02
# ./Data/Images\sub-OAS30178_ses-d2794
# ./Data/Images\sub-OAS30178_ses-d3500
# ./Data/Images\sub-OAS30179_ses-d0061
# ./Data/Images\sub-OAS30180_ses-d0051_run-01
# ./Data/Images\sub-OAS30180_ses-d0051_run-02
# ./Data/Images\sub-OAS30181_ses-d0058
# ./Data/Images\sub-OAS30182_ses-d0094
# ./Data/Images\sub-OAS30182_ses-d0101
# ./Data/Images\sub-OAS30182_ses-d1397
# ./Data/Images\sub-OAS30183_ses-d0082_run-01
# ./Data/Images\sub-OAS30183_ses-d0082_run-02
# ./Data/Images\sub-OAS30184_ses-d0169_run-01
# ./Data/Images\sub-OAS30184_ses-d0169_run-02
# ./Data/Images\sub-OAS30184_ses-d0876_run-01
# ./Data/Images\sub-OAS30184_ses-d0876_run-02
# ./Data/Images\sub-OAS30184_ses-d3157
# ./Data/Images\sub-OAS30185_ses-d3787
# ./Data/Images\sub-OAS30185_ses-d4551
# ./Data/Images\sub-OAS30187_ses-d0070
# ./Data/Images\sub-OAS30188_ses-d0246_run-01
# ./Data/Images\sub-OAS30188_ses-d0246_run-02
# ./Data/Images\sub-OAS30188_ses-d0246_run-03
# ./Data/Images\sub-OAS30188_ses-d1788_run-01
# ./Data/Images\sub-OAS30188_ses-d1788_run-02
# ./Data/Images\sub-OAS30188_ses-d3844
# ./Data/Images\sub-OAS30189_ses-d0072
# ./Data/Images\sub-OAS30190_ses-d0082_run-01
# ./Data/Images\sub-OAS30190_ses-d0082_run-02
# ./Data/Images\sub-OAS30191_ses-d1136
# ./Data/Images\sub-OAS30191_ses-d2352
# ./Data/Images\sub-OAS30192_ses-d0293_run-01
# ./Data/Images\sub-OAS30192_ses-d0293_run-02
# ./Data/Images\sub-OAS30192_ses-d0293_run-03
# ./Data/Images\sub-OAS30192_ses-d1409_run-01
# ./Data/Images\sub-OAS30192_ses-d1409_run-02
# ./Data/Images\sub-OAS30193_ses-d0043_run-01
# ./Data/Images\sub-OAS30193_ses-d0043_run-02
# ./Data/Images\sub-OAS30193_ses-d1611
# ./Data/Images\sub-OAS30194_ses-d5837_run-01
# ./Data/Images\sub-OAS30194_ses-d5837_run-02
# ./Data/Images\sub-OAS30194_ses-d5837_run-03
# ./Data/Images\sub-OAS30194_ses-d6419_run-01
# ./Data/Images\sub-OAS30194_ses-d6419_run-02
# ./Data/Images\sub-OAS30194_ses-d6419_run-03
# ./Data/Images\sub-OAS30194_ses-d6605_run-01
# ./Data/Images\sub-OAS30194_ses-d6605_run-02
# ./Data/Images\sub-OAS30194_ses-d7432_run-01
# ./Data/Images\sub-OAS30194_ses-d7432_run-02
# ./Data/Images\sub-OAS30194_ses-d7432_run-03
# ./Data/Images\sub-OAS30194_ses-d8874
# ./Data/Images\sub-OAS30194_ses-d8881
# ./Data/Images\sub-OAS30194_ses-d9317
# ./Data/Images\sub-OAS30194_ses-d9443
# ./Data/Images\sub-OAS30194_ses-d9874
# ./Data/Images\sub-OAS30195_ses-d0193
# ./Data/Images\sub-OAS30197_ses-d0115
# ./Data/Images\sub-OAS30198_ses-d0083
# ./Data/Images\sub-OAS30199_ses-d0024
# ./Data/Images\sub-OAS30200_ses-d0075_run-01
# ./Data/Images\sub-OAS30200_ses-d0075_run-02
# ./Data/Images\sub-OAS30202_ses-d0175_run-01
# ./Data/Images\sub-OAS30202_ses-d0175_run-02
# ./Data/Images\sub-OAS30203_ses-d0203_run-01
# ./Data/Images\sub-OAS30203_ses-d0203_run-02
# ./Data/Images\sub-OAS30203_ses-d0203_run-03
# ./Data/Images\sub-OAS30203_ses-d0802_run-01
# ./Data/Images\sub-OAS30203_ses-d0802_run-02
# ./Data/Images\sub-OAS30203_ses-d0802_run-03
# ./Data/Images\sub-OAS30203_ses-d0802_run-04
# ./Data/Images\sub-OAS30203_ses-d0802_run-05
# ./Data/Images\sub-OAS30203_ses-d2881
# ./Data/Images\sub-OAS30204_ses-d0020
# ./Data/Images\sub-OAS30204_ses-d0033_run-01
# ./Data/Images\sub-OAS30204_ses-d0033_run-02
# ./Data/Images\sub-OAS30205_ses-d0061
# ./Data/Images\sub-OAS30206_ses-d0306_run-01
# ./Data/Images\sub-OAS30206_ses-d0306_run-02
# ./Data/Images\sub-OAS30206_ses-d1036_run-01
# ./Data/Images\sub-OAS30206_ses-d1036_run-02
# ./Data/Images\sub-OAS30206_ses-d2303
# ./Data/Images\sub-OAS30206_ses-d3024
# ./Data/Images\sub-OAS30207_ses-d0346_run-01
# ./Data/Images\sub-OAS30207_ses-d0346_run-02
# ./Data/Images\sub-OAS30208_ses-d0436
# ./Data/Images\sub-OAS30208_ses-d1703
# ./Data/Images\sub-OAS30209_ses-d0609_run-01
# ./Data/Images\sub-OAS30209_ses-d0609_run-02
# ./Data/Images\sub-OAS30209_ses-d1976
# ./Data/Images\sub-OAS30210_ses-d0047
# ./Data/Images\sub-OAS30211_ses-d0046
# ./Data/Images\sub-OAS30211_ses-d1239
# ./Data/Images\sub-OAS30212_ses-d0091_run-01
# ./Data/Images\sub-OAS30212_ses-d0091_run-02
# ./Data/Images\sub-OAS30212_ses-d0753_run-01
# ./Data/Images\sub-OAS30212_ses-d0753_run-02
# ./Data/Images\sub-OAS30212_ses-d3043
# ./Data/Images\sub-OAS30213_ses-d0041
# ./Data/Images\sub-OAS30214_ses-d4464
# ./Data/Images\sub-OAS30215_ses-d0098
# ./Data/Images\sub-OAS30216_ses-d2849_run-01
# ./Data/Images\sub-OAS30216_ses-d2849_run-02
# ./Data/Images\sub-OAS30216_ses-d2849_run-03
# ./Data/Images\sub-OAS30216_ses-d3830_run-01
# ./Data/Images\sub-OAS30216_ses-d3830_run-02
# ./Data/Images\sub-OAS30217_ses-d0077
# ./Data/Images\sub-OAS30218_ses-d0092_run-01
# ./Data/Images\sub-OAS30218_ses-d0092_run-02
# ./Data/Images\sub-OAS30218_ses-d0841
# ./Data/Images\sub-OAS30219_ses-d0064
# ./Data/Images\sub-OAS30219_ses-d1184
# ./Data/Images\sub-OAS30220_ses-d0104
# ./Data/Images\sub-OAS30220_ses-d1165
# ./Data/Images\sub-OAS30221_ses-d0079
# ./Data/Images\sub-OAS30221_ses-d1143
# ./Data/Images\sub-OAS30222_ses-d1000_run-01
# ./Data/Images\sub-OAS30222_ses-d1000_run-02
# ./Data/Images\sub-OAS30223_ses-d0455_run-01
# ./Data/Images\sub-OAS30223_ses-d0455_run-02
# ./Data/Images\sub-OAS30223_ses-d1235_run-01
# ./Data/Images\sub-OAS30223_ses-d1235_run-02
# ./Data/Images\sub-OAS30224_ses-d0556_run-01
# ./Data/Images\sub-OAS30224_ses-d0556_run-02
# ./Data/Images\sub-OAS30225_ses-d0482
# ./Data/Images\sub-OAS30226_ses-d0183_run-01
# ./Data/Images\sub-OAS30226_ses-d0183_run-02
# ./Data/Images\sub-OAS30227_ses-d0000_run-01
# ./Data/Images\sub-OAS30227_ses-d0000_run-02
# ./Data/Images\sub-OAS30228_ses-d0090
# ./Data/Images\sub-OAS30229_ses-d0101
# ./Data/Images\sub-OAS30230_ses-d3855
# ./Data/Images\sub-OAS30231_ses-d1469
# ./Data/Images\sub-OAS30231_ses-d2510_run-01
# ./Data/Images\sub-OAS30231_ses-d2510_run-02
# ./Data/Images\sub-OAS30231_ses-d3617
# ./Data/Images\sub-OAS30231_ses-d3630
# ./Data/Images\sub-OAS30232_ses-d0120_run-01
# ./Data/Images\sub-OAS30232_ses-d0120_run-02
# ./Data/Images\sub-OAS30232_ses-d0695_run-01
# ./Data/Images\sub-OAS30232_ses-d0695_run-02
# ./Data/Images\sub-OAS30232_ses-d2324
# ./Data/Images\sub-OAS30233_ses-d3867
# ./Data/Images\sub-OAS30233_ses-d5295
# ./Data/Images\sub-OAS30234_ses-d1119_run-01
# ./Data/Images\sub-OAS30234_ses-d1119_run-02
# ./Data/Images\sub-OAS30234_ses-d1119_run-03
# ./Data/Images\sub-OAS30234_ses-d2098_run-01
# ./Data/Images\sub-OAS30234_ses-d2098_run-02
# ./Data/Images\sub-OAS30235_ses-d0139
# ./Data/Images\sub-OAS30236_ses-d0088
# ./Data/Images\sub-OAS30237_ses-d1353_run-01
# ./Data/Images\sub-OAS30237_ses-d1353_run-02
# ./Data/Images\sub-OAS30237_ses-d1353_run-03
# ./Data/Images\sub-OAS30237_ses-d2478_run-01
# ./Data/Images\sub-OAS30237_ses-d2478_run-02
# ./Data/Images\sub-OAS30237_ses-d3368
# ./Data/Images\sub-OAS30238_ses-d0037
# ./Data/Images\sub-OAS30239_ses-d0175_run-01
# ./Data/Images\sub-OAS30239_ses-d0175_run-02
# ./Data/Images\sub-OAS30240_ses-d0865_run-01
# ./Data/Images\sub-OAS30240_ses-d0865_run-02
# ./Data/Images\sub-OAS30240_ses-d0865_run-03
# ./Data/Images\sub-OAS30240_ses-d1871_run-01
# ./Data/Images\sub-OAS30240_ses-d1871_run-02
# ./Data/Images\sub-OAS30240_ses-d3483
# ./Data/Images\sub-OAS30240_ses-d3487
# ./Data/Images\sub-OAS30240_ses-d3843
# ./Data/Images\sub-OAS30240_ses-d4197
# ./Data/Images\sub-OAS30241_ses-d0170_run-01
# ./Data/Images\sub-OAS30241_ses-d0170_run-02
# ./Data/Images\sub-OAS30241_ses-d0170_run-03
# ./Data/Images\sub-OAS30241_ses-d1203_run-01
# ./Data/Images\sub-OAS30241_ses-d1203_run-02
# ./Data/Images\sub-OAS30241_ses-d1706_run-01
# ./Data/Images\sub-OAS30241_ses-d1706_run-02
# ./Data/Images\sub-OAS30241_ses-d3605
# ./Data/Images\sub-OAS30242_ses-d0137
# ./Data/Images\sub-OAS30243_ses-d0034_run-01
# ./Data/Images\sub-OAS30243_ses-d0034_run-02
# ./Data/Images\sub-OAS30244_ses-d0104
# ./Data/Images\sub-OAS30244_ses-d1526
# ./Data/Images\sub-OAS30245_ses-d0058
# ./Data/Images\sub-OAS30245_ses-d0506_run-01
# ./Data/Images\sub-OAS30245_ses-d0506_run-02
# ./Data/Images\sub-OAS30246_ses-d0119_run-01
# ./Data/Images\sub-OAS30246_ses-d0119_run-02
# ./Data/Images\sub-OAS30246_ses-d0746_run-01
# ./Data/Images\sub-OAS30246_ses-d0746_run-02
# ./Data/Images\sub-OAS30246_ses-d1591
# ./Data/Images\sub-OAS30246_ses-d2354
# ./Data/Images\sub-OAS30247_ses-d0168_run-01
# ./Data/Images\sub-OAS30247_ses-d0168_run-02
# ./Data/Images\sub-OAS30247_ses-d0844_run-01
# ./Data/Images\sub-OAS30247_ses-d0844_run-02
# ./Data/Images\sub-OAS30247_ses-d2643
# ./Data/Images\sub-OAS30248_ses-d0078
# ./Data/Images\sub-OAS30248_ses-d1191
# ./Data/Images\sub-OAS30249_ses-d0091_run-01
# ./Data/Images\sub-OAS30249_ses-d0091_run-02
# ./Data/Images\sub-OAS30249_ses-d0091_run-03
# ./Data/Images\sub-OAS30249_ses-d0749
# ./Data/Images\sub-OAS30249_ses-d1238_run-01
# ./Data/Images\sub-OAS30249_ses-d1238_run-02
# ./Data/Images\sub-OAS30249_ses-d1952_run-01
# ./Data/Images\sub-OAS30249_ses-d1952_run-02
# ./Data/Images\sub-OAS30249_ses-d3431
# ./Data/Images\sub-OAS30249_ses-d4416
# ./Data/Images\sub-OAS30250_ses-d0389_run-01
# ./Data/Images\sub-OAS30250_ses-d0389_run-02
# ./Data/Images\sub-OAS30250_ses-d1233
# ./Data/Images\sub-OAS30250_ses-d1722_run-01
# ./Data/Images\sub-OAS30250_ses-d1722_run-02
# ./Data/Images\sub-OAS30251_ses-d0220_run-01
# ./Data/Images\sub-OAS30251_ses-d0220_run-02
# ./Data/Images\sub-OAS30251_ses-d2067
# ./Data/Images\sub-OAS30251_ses-d2954
# ./Data/Images\sub-OAS30253_ses-d1288
# ./Data/Images\sub-OAS30253_ses-d2541_run-01
# ./Data/Images\sub-OAS30253_ses-d2541_run-02
# ./Data/Images\sub-OAS30253_ses-d3490
# ./Data/Images\sub-OAS30253_ses-d3948
# ./Data/Images\sub-OAS30253_ses-d4746
# ./Data/Images\sub-OAS30254_ses-d0057_run-01
# ./Data/Images\sub-OAS30254_ses-d0057_run-02
# ./Data/Images\sub-OAS30255_ses-d0019_run-01
# ./Data/Images\sub-OAS30255_ses-d0019_run-02
# ./Data/Images\sub-OAS30256_ses-d0000_run-01
# ./Data/Images\sub-OAS30256_ses-d0000_run-02
# ./Data/Images\sub-OAS30256_ses-d0000_run-03
# ./Data/Images\sub-OAS30256_ses-d1284_run-01
# ./Data/Images\sub-OAS30256_ses-d1284_run-02
# ./Data/Images\sub-OAS30256_ses-d2368
# ./Data/Images\sub-OAS30256_ses-d3588
# ./Data/Images\sub-OAS30257_ses-d0610_run-01
# ./Data/Images\sub-OAS30257_ses-d0610_run-02
# ./Data/Images\sub-OAS30257_ses-d1938
# ./Data/Images\sub-OAS30257_ses-d3773
# ./Data/Images\sub-OAS30258_ses-d0487_run-01
# ./Data/Images\sub-OAS30258_ses-d0487_run-02
# ./Data/Images\sub-OAS30258_ses-d1225
# ./Data/Images\sub-OAS30259_ses-d0000_run-01
# ./Data/Images\sub-OAS30259_ses-d0000_run-02
# ./Data/Images\sub-OAS30259_ses-d0000_run-03
# ./Data/Images\sub-OAS30259_ses-d0679_run-01
# ./Data/Images\sub-OAS30259_ses-d0679_run-02
# ./Data/Images\sub-OAS30259_ses-d0679_run-03
# ./Data/Images\sub-OAS30261_ses-d0785_run-01
# ./Data/Images\sub-OAS30261_ses-d0785_run-02
# ./Data/Images\sub-OAS30261_ses-d1892
# ./Data/Images\sub-OAS30262_ses-d0037
# ./Data/Images\sub-OAS30262_ses-d0839
# ./Data/Images\sub-OAS30263_ses-d0129_run-01
# ./Data/Images\sub-OAS30263_ses-d0129_run-02
# ./Data/Images\sub-OAS30263_ses-d0970_run-01
# ./Data/Images\sub-OAS30263_ses-d0970_run-02
# ./Data/Images\sub-OAS30263_ses-d2477
# ./Data/Images\sub-OAS30263_ses-d2483
# ./Data/Images\sub-OAS30264_ses-d0466
# ./Data/Images\sub-OAS30265_ses-d0192_run-01
# ./Data/Images\sub-OAS30265_ses-d0192_run-02
# ./Data/Images\sub-OAS30266_ses-d0486
# ./Data/Images\sub-OAS30267_ses-d0043_run-01
# ./Data/Images\sub-OAS30267_ses-d0043_run-02
# ./Data/Images\sub-OAS30268_ses-d0096_run-01
# ./Data/Images\sub-OAS30268_ses-d0096_run-02
# ./Data/Images\sub-OAS30269_ses-d0052_run-01
# ./Data/Images\sub-OAS30269_ses-d0052_run-02
# ./Data/Images\sub-OAS30270_ses-d0070
# ./Data/Images\sub-OAS30271_ses-d0004_run-01
# ./Data/Images\sub-OAS30271_ses-d0004_run-02
# ./Data/Images\sub-OAS30272_ses-d0057_run-01
# ./Data/Images\sub-OAS30272_ses-d0057_run-02
# ./Data/Images\sub-OAS30272_ses-d2456
# ./Data/Images\sub-OAS30272_ses-d3087
# ./Data/Images\sub-OAS30273_ses-d0077
# ./Data/Images\sub-OAS30273_ses-d0461_run-01
# ./Data/Images\sub-OAS30273_ses-d0461_run-02
# ./Data/Images\sub-OAS30273_ses-d2304
# ./Data/Images\sub-OAS30274_ses-d0605_run-01
# ./Data/Images\sub-OAS30274_ses-d0605_run-02
# ./Data/Images\sub-OAS30274_ses-d3332
# ./Data/Images\sub-OAS30275_ses-d0280_run-01
# ./Data/Images\sub-OAS30275_ses-d0280_run-02
# ./Data/Images\sub-OAS30275_ses-d1006_run-01
# ./Data/Images\sub-OAS30275_ses-d1006_run-02
# ./Data/Images\sub-OAS30276_ses-d0138
# ./Data/Images\sub-OAS30276_ses-d1200_run-01
# ./Data/Images\sub-OAS30276_ses-d1200_run-02
# ./Data/Images\sub-OAS30276_ses-d2405
# ./Data/Images\sub-OAS30276_ses-d2408
# ./Data/Images\sub-OAS30276_ses-d3217
# ./Data/Images\sub-OAS30277_ses-d0198
# ./Data/Images\sub-OAS30278_ses-d0028_run-01
# ./Data/Images\sub-OAS30278_ses-d0028_run-02
# ./Data/Images\sub-OAS30278_ses-d0028_run-03
# ./Data/Images\sub-OAS30278_ses-d0028_run-04
# ./Data/Images\sub-OAS30278_ses-d1325_run-01
# ./Data/Images\sub-OAS30278_ses-d1325_run-02
# ./Data/Images\sub-OAS30279_ses-d0136
# ./Data/Images\sub-OAS30280_ses-d0085_run-01
# ./Data/Images\sub-OAS30280_ses-d0085_run-02
# ./Data/Images\sub-OAS30280_ses-d0667_run-01
# ./Data/Images\sub-OAS30280_ses-d0667_run-02
# ./Data/Images\sub-OAS30280_ses-d1647
# ./Data/Images\sub-OAS30281_ses-d0042
# ./Data/Images\sub-OAS30282_ses-d0040
# ./Data/Images\sub-OAS30283_ses-d0064_run-01
# ./Data/Images\sub-OAS30283_ses-d0064_run-02
# ./Data/Images\sub-OAS30283_ses-d0797
# ./Data/Images\sub-OAS30284_ses-d0094_run-01
# ./Data/Images\sub-OAS30284_ses-d0094_run-02
# ./Data/Images\sub-OAS30284_ses-d0094_run-03
# ./Data/Images\sub-OAS30284_ses-d1633_run-01
# ./Data/Images\sub-OAS30284_ses-d1633_run-02
# ./Data/Images\sub-OAS30284_ses-d3510
# ./Data/Images\sub-OAS30285_ses-d0055_run-01
# ./Data/Images\sub-OAS30285_ses-d0055_run-02
# ./Data/Images\sub-OAS30286_ses-d0047
# ./Data/Images\sub-OAS30287_ses-d0890
# ./Data/Images\sub-OAS30288_ses-d0897_run-01
# ./Data/Images\sub-OAS30288_ses-d0897_run-02
# ./Data/Images\sub-OAS30288_ses-d0897_run-03
# ./Data/Images\sub-OAS30288_ses-d4509
# ./Data/Images\sub-OAS30289_ses-d0160
# ./Data/Images\sub-OAS30290_ses-d0000
# ./Data/Images\sub-OAS30291_ses-d0078_run-01
# ./Data/Images\sub-OAS30291_ses-d0078_run-02
# ./Data/Images\sub-OAS30291_ses-d1979
# ./Data/Images\sub-OAS30292_ses-d0165_run-01
# ./Data/Images\sub-OAS30292_ses-d0165_run-02
# ./Data/Images\sub-OAS30293_ses-d0056
# ./Data/Images\sub-OAS30293_ses-d1221
# ./Data/Images\sub-OAS30294_ses-d0462_run-01
# ./Data/Images\sub-OAS30294_ses-d0462_run-02
# ./Data/Images\sub-OAS30295_ses-d0611_run-01
# ./Data/Images\sub-OAS30295_ses-d0611_run-02
# ./Data/Images\sub-OAS30295_ses-d0967_run-01
# ./Data/Images\sub-OAS30295_ses-d0967_run-02
# ./Data/Images\sub-OAS30296_ses-d0069
# ./Data/Images\sub-OAS30297_ses-d0105_run-01
# ./Data/Images\sub-OAS30297_ses-d0105_run-02
# ./Data/Images\sub-OAS30297_ses-d0105_run-03
# ./Data/Images\sub-OAS30297_ses-d1712_run-01
# ./Data/Images\sub-OAS30297_ses-d1712_run-02
# ./Data/Images\sub-OAS30298_ses-d0292_run-01
# ./Data/Images\sub-OAS30298_ses-d0292_run-02
# ./Data/Images\sub-OAS30299_ses-d0119_run-01
# ./Data/Images\sub-OAS30299_ses-d0119_run-02
# ./Data/Images\sub-OAS30300_ses-d0100
# ./Data/Images\sub-OAS30302_ses-d0262_run-01
# ./Data/Images\sub-OAS30302_ses-d0262_run-02
# ./Data/Images\sub-OAS30302_ses-d1456_run-01
# ./Data/Images\sub-OAS30302_ses-d1456_run-02
# ./Data/Images\sub-OAS30302_ses-d1456_run-03
# ./Data/Images\sub-OAS30303_ses-d0910_run-01
# ./Data/Images\sub-OAS30303_ses-d0910_run-02
# ./Data/Images\sub-OAS30303_ses-d0910_run-03
# ./Data/Images\sub-OAS30303_ses-d1948_run-01
# ./Data/Images\sub-OAS30303_ses-d1948_run-02
# ./Data/Images\sub-OAS30303_ses-d2650_run-01
# ./Data/Images\sub-OAS30303_ses-d2650_run-02
# ./Data/Images\sub-OAS30304_ses-d0027
# ./Data/Images\sub-OAS30305_ses-d0245_run-01
# ./Data/Images\sub-OAS30305_ses-d0245_run-02
# ./Data/Images\sub-OAS30306_ses-d0028
# ./Data/Images\sub-OAS30306_ses-d0473
# ./Data/Images\sub-OAS30307_ses-d0032_run-01
# ./Data/Images\sub-OAS30307_ses-d0032_run-02
# ./Data/Images\sub-OAS30307_ses-d2362
# ./Data/Images\sub-OAS30308_ses-d0004_run-01
# ./Data/Images\sub-OAS30308_ses-d0004_run-02
# ./Data/Images\sub-OAS30308_ses-d0423_run-01
# ./Data/Images\sub-OAS30308_ses-d0423_run-02
# ./Data/Images\sub-OAS30309_ses-d0094
# ./Data/Images\sub-OAS30310_ses-d0191
# ./Data/Images\sub-OAS30311_ses-d0127
# ./Data/Images\sub-OAS30312_ses-d0068
# ./Data/Images\sub-OAS30313_ses-d0048
# ./Data/Images\sub-OAS30314_ses-d6379_run-01
# ./Data/Images\sub-OAS30314_ses-d6379_run-02
# ./Data/Images\sub-OAS30314_ses-d6379_run-03
# ./Data/Images\sub-OAS30314_ses-d6827_run-01
# ./Data/Images\sub-OAS30314_ses-d6827_run-02
# ./Data/Images\sub-OAS30314_ses-d6827_run-03
# ./Data/Images\sub-OAS30314_ses-d7000_run-01
# ./Data/Images\sub-OAS30314_ses-d7000_run-02
# ./Data/Images\sub-OAS30314_ses-d7814_run-01
# ./Data/Images\sub-OAS30314_ses-d7814_run-02
# ./Data/Images\sub-OAS30315_ses-d0124
# ./Data/Images\sub-OAS30316_ses-d0018
# ./Data/Images\sub-OAS30317_ses-d0088
# ./Data/Images\sub-OAS30318_ses-d2975
# ./Data/Images\sub-OAS30318_ses-d3298
# ./Data/Images\sub-OAS30319_ses-d0043_run-01
# ./Data/Images\sub-OAS30319_ses-d0043_run-02
# ./Data/Images\sub-OAS30320_ses-d0136_run-01
# ./Data/Images\sub-OAS30320_ses-d0136_run-02
# ./Data/Images\sub-OAS30320_ses-d1740
# ./Data/Images\sub-OAS30321_ses-d0075_run-01
# ./Data/Images\sub-OAS30321_ses-d0075_run-02
# ./Data/Images\sub-OAS30321_ses-d1988
# ./Data/Images\sub-OAS30322_ses-d0173_run-01
# ./Data/Images\sub-OAS30322_ses-d0173_run-02
# ./Data/Images\sub-OAS30322_ses-d0173_run-03
# ./Data/Images\sub-OAS30322_ses-d0173_run-04
# ./Data/Images\sub-OAS30322_ses-d0173_run-05
# ./Data/Images\sub-OAS30322_ses-d0645_run-01
# ./Data/Images\sub-OAS30322_ses-d0645_run-02
# ./Data/Images\sub-OAS30322_ses-d0645_run-03
# ./Data/Images\sub-OAS30322_ses-d1630_run-01
# ./Data/Images\sub-OAS30322_ses-d1630_run-02
# ./Data/Images\sub-OAS30322_ses-d3851
# ./Data/Images\sub-OAS30323_ses-d0836
# ./Data/Images\sub-OAS30324_ses-d0119
# ./Data/Images\sub-OAS30324_ses-d0959
# ./Data/Images\sub-OAS30325_ses-d0032
# ./Data/Images\sub-OAS30326_ses-d0189_run-01
# ./Data/Images\sub-OAS30326_ses-d0189_run-02
# ./Data/Images\sub-OAS30327_ses-d0281_run-01
# ./Data/Images\sub-OAS30327_ses-d0281_run-02
# ./Data/Images\sub-OAS30328_ses-d0105
# ./Data/Images\sub-OAS30328_ses-d0470
# ./Data/Images\sub-OAS30329_ses-d0376
# ./Data/Images\sub-OAS30330_ses-d0000_run-01
# ./Data/Images\sub-OAS30330_ses-d0000_run-02
# ./Data/Images\sub-OAS30331_ses-d2229_run-01
# ./Data/Images\sub-OAS30331_ses-d2229_run-02
# ./Data/Images\sub-OAS30331_ses-d2229_run-03
# ./Data/Images\sub-OAS30331_ses-d2824_run-01
# ./Data/Images\sub-OAS30331_ses-d2824_run-02
# ./Data/Images\sub-OAS30331_ses-d3478_run-01
# ./Data/Images\sub-OAS30331_ses-d3478_run-02
# ./Data/Images\sub-OAS30331_ses-d4694
# ./Data/Images\sub-OAS30332_ses-d0091
# ./Data/Images\sub-OAS30333_ses-d0093_run-01
# ./Data/Images\sub-OAS30333_ses-d0093_run-02
# ./Data/Images\sub-OAS30333_ses-d2005
# ./Data/Images\sub-OAS30333_ses-d2008
# ./Data/Images\sub-OAS30333_ses-d2457
# ./Data/Images\sub-OAS30333_ses-d2891
# ./Data/Images\sub-OAS30333_ses-d2985
# ./Data/Images\sub-OAS30334_ses-d0000_run-01
# ./Data/Images\sub-OAS30334_ses-d0000_run-02
# ./Data/Images\sub-OAS30334_ses-d0889
# ./Data/Images\sub-OAS30335_ses-d0109
# ./Data/Images\sub-OAS30335_ses-d0693_run-01
# ./Data/Images\sub-OAS30335_ses-d0693_run-02
# ./Data/Images\sub-OAS30335_ses-d1482_run-01
# ./Data/Images\sub-OAS30335_ses-d1482_run-02
# ./Data/Images\sub-OAS30335_ses-d2770
# ./Data/Images\sub-OAS30335_ses-d2783
# ./Data/Images\sub-OAS30335_ses-d3812
# ./Data/Images\sub-OAS30336_ses-d0012
# ./Data/Images\sub-OAS30336_ses-d0244
# ./Data/Images\sub-OAS30336_ses-d1264
# ./Data/Images\sub-OAS30337_ses-d0064
# ./Data/Images\sub-OAS30339_ses-d0066_run-01
# ./Data/Images\sub-OAS30339_ses-d0066_run-02
# ./Data/Images\sub-OAS30341_ses-d0025
# ./Data/Images\sub-OAS30342_ses-d0001
# ./Data/Images\sub-OAS30342_ses-d0429
# ./Data/Images\sub-OAS30343_ses-d2141_run-01
# ./Data/Images\sub-OAS30343_ses-d2141_run-02
# ./Data/Images\sub-OAS30343_ses-d2141_run-03
# ./Data/Images\sub-OAS30343_ses-d2141_run-04
# ./Data/Images\sub-OAS30343_ses-d2820_run-01
# ./Data/Images\sub-OAS30343_ses-d2820_run-02
# ./Data/Images\sub-OAS30343_ses-d2820_run-03
# ./Data/Images\sub-OAS30343_ses-d4178_run-01
# ./Data/Images\sub-OAS30343_ses-d4178_run-02
# ./Data/Images\sub-OAS30343_ses-d4900
# ./Data/Images\sub-OAS30344_ses-d0049_run-01
# ./Data/Images\sub-OAS30344_ses-d0049_run-02
# ./Data/Images\sub-OAS30344_ses-d1052_run-01
# ./Data/Images\sub-OAS30344_ses-d1052_run-02
# ./Data/Images\sub-OAS30344_ses-d2375
# ./Data/Images\sub-OAS30345_ses-d0087_run-01
# ./Data/Images\sub-OAS30345_ses-d0087_run-02
# ./Data/Images\sub-OAS30346_ses-d0083_run-01
# ./Data/Images\sub-OAS30346_ses-d0083_run-02
# ./Data/Images\sub-OAS30346_ses-d0083_run-03
# ./Data/Images\sub-OAS30346_ses-d1685
# ./Data/Images\sub-OAS30347_ses-d2615_run-01
# ./Data/Images\sub-OAS30347_ses-d2615_run-02
# ./Data/Images\sub-OAS30347_ses-d2615_run-03
# ./Data/Images\sub-OAS30347_ses-d3101_run-01
# ./Data/Images\sub-OAS30347_ses-d3101_run-02
# ./Data/Images\sub-OAS30347_ses-d3101_run-03
# ./Data/Images\sub-OAS30348_ses-d0077
# ./Data/Images\sub-OAS30349_ses-d0699_run-01
# ./Data/Images\sub-OAS30349_ses-d0699_run-02
# ./Data/Images\sub-OAS30349_ses-d3241
# ./Data/Images\sub-OAS30350_ses-d0018_run-01
# ./Data/Images\sub-OAS30350_ses-d0018_run-02
# ./Data/Images\sub-OAS30350_ses-d0509
# ./Data/Images\sub-OAS30350_ses-d1201
# ./Data/Images\sub-OAS30351_ses-d0037
# ./Data/Images\sub-OAS30352_ses-d0099
# ./Data/Images\sub-OAS30353_ses-d0963_run-01
# ./Data/Images\sub-OAS30353_ses-d0963_run-02
# ./Data/Images\sub-OAS30353_ses-d2635
# ./Data/Images\sub-OAS30353_ses-d3421
# ./Data/Images\sub-OAS30354_ses-d0056_run-01
# ./Data/Images\sub-OAS30354_ses-d0056_run-02
# ./Data/Images\sub-OAS30355_ses-d0048
# ./Data/Images\sub-OAS30355_ses-d0861
# ./Data/Images\sub-OAS30356_ses-d0714_run-01
# ./Data/Images\sub-OAS30356_ses-d0714_run-02
# ./Data/Images\sub-OAS30357_ses-d0521
# ./Data/Images\sub-OAS30357_ses-d0535_run-01
# ./Data/Images\sub-OAS30357_ses-d0535_run-02
# ./Data/Images\sub-OAS30357_ses-d1195
# ./Data/Images\sub-OAS30358_ses-d0367_run-01
# ./Data/Images\sub-OAS30358_ses-d0367_run-02
# ./Data/Images\sub-OAS30358_ses-d0367_run-03
# ./Data/Images\sub-OAS30359_ses-d0069_run-01
# ./Data/Images\sub-OAS30359_ses-d0069_run-02
# ./Data/Images\sub-OAS30360_ses-d0118
# ./Data/Images\sub-OAS30361_ses-d1457_run-01
# ./Data/Images\sub-OAS30361_ses-d1457_run-02
# ./Data/Images\sub-OAS30361_ses-d2151_run-01
# ./Data/Images\sub-OAS30361_ses-d2151_run-02
# ./Data/Images\sub-OAS30361_ses-d3275
# ./Data/Images\sub-OAS30362_ses-d0032
# ./Data/Images\sub-OAS30363_ses-d0087_run-01
# ./Data/Images\sub-OAS30363_ses-d0087_run-02
# ./Data/Images\sub-OAS30363_ses-d0880_run-01
# ./Data/Images\sub-OAS30363_ses-d0880_run-02
# ./Data/Images\sub-OAS30363_ses-d2626
# ./Data/Images\sub-OAS30363_ses-d2701
# ./Data/Images\sub-OAS30364_ses-d0110
# ./Data/Images\sub-OAS30365_ses-d5600_run-01
# ./Data/Images\sub-OAS30365_ses-d5600_run-02
# ./Data/Images\sub-OAS30365_ses-d5600_run-03
# ./Data/Images\sub-OAS30365_ses-d6199_run-01
# ./Data/Images\sub-OAS30365_ses-d6199_run-02
# ./Data/Images\sub-OAS30365_ses-d6199_run-03
# ./Data/Images\sub-OAS30367_ses-d0055_run-01
# ./Data/Images\sub-OAS30367_ses-d0055_run-02
# ./Data/Images\sub-OAS30367_ses-d0055_run-03
# ./Data/Images\sub-OAS30367_ses-d1540_run-01
# ./Data/Images\sub-OAS30367_ses-d1540_run-02
# ./Data/Images\sub-OAS30367_ses-d2009_run-01
# ./Data/Images\sub-OAS30367_ses-d2009_run-02
# ./Data/Images\sub-OAS30367_ses-d3394
# ./Data/Images\sub-OAS30367_ses-d3396
# ./Data/Images\sub-OAS30367_ses-d4337
# ./Data/Images\sub-OAS30368_ses-d0056_run-01
# ./Data/Images\sub-OAS30368_ses-d0056_run-02
# ./Data/Images\sub-OAS30368_ses-d2379
# ./Data/Images\sub-OAS30368_ses-d2750
# ./Data/Images\sub-OAS30369_ses-d2819_run-01
# ./Data/Images\sub-OAS30369_ses-d2819_run-02
# ./Data/Images\sub-OAS30369_ses-d2819_run-03
# ./Data/Images\sub-OAS30369_ses-d4058_run-01
# ./Data/Images\sub-OAS30369_ses-d4058_run-02
# ./Data/Images\sub-OAS30369_ses-d4921
# ./Data/Images\sub-OAS30369_ses-d5872
# ./Data/Images\sub-OAS30369_ses-d5880
# ./Data/Images\sub-OAS30369_ses-d6215
# ./Data/Images\sub-OAS30369_ses-d6992
# ./Data/Images\sub-OAS30370_ses-d0141_run-01
# ./Data/Images\sub-OAS30370_ses-d0141_run-02
# ./Data/Images\sub-OAS30371_ses-d0338_run-01
# ./Data/Images\sub-OAS30371_ses-d0338_run-02
# ./Data/Images\sub-OAS30371_ses-d0981
# ./Data/Images\sub-OAS30371_ses-d1400
# ./Data/Images\sub-OAS30372_ses-d3464
# ./Data/Images\sub-OAS30372_ses-d4514
# ./Data/Images\sub-OAS30373_ses-d0048_run-01
# ./Data/Images\sub-OAS30373_ses-d0048_run-02
# ./Data/Images\sub-OAS30373_ses-d1211
# ./Data/Images\sub-OAS30374_ses-d0084
# ./Data/Images\sub-OAS30375_ses-d5792_run-01
# ./Data/Images\sub-OAS30375_ses-d5792_run-02
# ./Data/Images\sub-OAS30375_ses-d6879
# ./Data/Images\sub-OAS30376_ses-d0082
# ./Data/Images\sub-OAS30377_ses-d0048
# ./Data/Images\sub-OAS30378_ses-d0204_run-01
# ./Data/Images\sub-OAS30378_ses-d0204_run-02
# ./Data/Images\sub-OAS30379_ses-d1169_run-01
# ./Data/Images\sub-OAS30379_ses-d1169_run-02
# ./Data/Images\sub-OAS30379_ses-d1169_run-03
# ./Data/Images\sub-OAS30379_ses-d2106_run-01
# ./Data/Images\sub-OAS30379_ses-d2106_run-02
# ./Data/Images\sub-OAS30380_ses-d3446_run-01
# ./Data/Images\sub-OAS30380_ses-d3446_run-02
# ./Data/Images\sub-OAS30381_ses-d1158_run-01
# ./Data/Images\sub-OAS30381_ses-d1158_run-02
# ./Data/Images\sub-OAS30381_ses-d1158_run-03
# ./Data/Images\sub-OAS30382_ses-d0051_run-01
# ./Data/Images\sub-OAS30382_ses-d0051_run-02
# ./Data/Images\sub-OAS30382_ses-d1199
# ./Data/Images\sub-OAS30383_ses-d0134_run-01
# ./Data/Images\sub-OAS30383_ses-d0134_run-02
# ./Data/Images\sub-OAS30384_ses-d0108
# ./Data/Images\sub-OAS30385_ses-d0112
# ./Data/Images\sub-OAS30386_ses-d0055
# ./Data/Images\sub-OAS30387_ses-d0616_run-01
# ./Data/Images\sub-OAS30387_ses-d0616_run-02
# ./Data/Images\sub-OAS30387_ses-d1832
# ./Data/Images\sub-OAS30387_ses-d3401
# ./Data/Images\sub-OAS30388_ses-d0073_run-01
# ./Data/Images\sub-OAS30388_ses-d0073_run-02
# ./Data/Images\sub-OAS30390_ses-d0346_run-01
# ./Data/Images\sub-OAS30390_ses-d0346_run-02
# ./Data/Images\sub-OAS30390_ses-d2428
# ./Data/Images\sub-OAS30391_ses-d0192
# ./Data/Images\sub-OAS30391_ses-d1547
# ./Data/Images\sub-OAS30392_ses-d0730_run-01
# ./Data/Images\sub-OAS30392_ses-d0730_run-02
# ./Data/Images\sub-OAS30392_ses-d1682_run-01
# ./Data/Images\sub-OAS30392_ses-d1682_run-02
# ./Data/Images\sub-OAS30392_ses-d3145
# ./Data/Images\sub-OAS30393_ses-d6201_run-01
# ./Data/Images\sub-OAS30393_ses-d6201_run-02
# ./Data/Images\sub-OAS30393_ses-d6201_run-03
# ./Data/Images\sub-OAS30393_ses-d6201_run-04
# ./Data/Images\sub-OAS30393_ses-d6803_run-01
# ./Data/Images\sub-OAS30393_ses-d6803_run-02
# ./Data/Images\sub-OAS30393_ses-d6803_run-03
# ./Data/Images\sub-OAS30393_ses-d7726_run-01
# ./Data/Images\sub-OAS30393_ses-d7726_run-02
# ./Data/Images\sub-OAS30393_ses-d8651
# ./Data/Images\sub-OAS30394_ses-d0039
# ./Data/Images\sub-OAS30395_ses-d0002
# ./Data/Images\sub-OAS30395_ses-d1241
# ./Data/Images\sub-OAS30396_ses-d0037_run-01
# ./Data/Images\sub-OAS30396_ses-d0037_run-02
# ./Data/Images\sub-OAS30397_ses-d0043
# ./Data/Images\sub-OAS30398_ses-d0051
# ./Data/Images\sub-OAS30399_ses-d0380_run-01
# ./Data/Images\sub-OAS30399_ses-d0380_run-02
# ./Data/Images\sub-OAS30399_ses-d1220_run-01
# ./Data/Images\sub-OAS30399_ses-d1220_run-02
# ./Data/Images\sub-OAS30399_ses-d2293
# ./Data/Images\sub-OAS30400_ses-d0070
# ./Data/Images\sub-OAS30401_ses-d0106_run-01
# ./Data/Images\sub-OAS30401_ses-d0106_run-02
# ./Data/Images\sub-OAS30402_ses-d0015
# ./Data/Images\sub-OAS30402_ses-d1085
# ./Data/Images\sub-OAS30403_ses-d0091
# ./Data/Images\sub-OAS30403_ses-d1232_run-01
# ./Data/Images\sub-OAS30403_ses-d1232_run-02
# ./Data/Images\sub-OAS30403_ses-d2378
# ./Data/Images\sub-OAS30403_ses-d2379
# ./Data/Images\sub-OAS30403_ses-d2758
# ./Data/Images\sub-OAS30403_ses-d2868
# ./Data/Images\sub-OAS30403_ses-d3669
# ./Data/Images\sub-OAS30404_ses-d0104
# ./Data/Images\sub-OAS30405_ses-d0079_run-01
# ./Data/Images\sub-OAS30405_ses-d0079_run-02
# ./Data/Images\sub-OAS30405_ses-d0079_run-03
# ./Data/Images\sub-OAS30405_ses-d1883
# ./Data/Images\sub-OAS30406_ses-d0084_run-01
# ./Data/Images\sub-OAS30406_ses-d0084_run-02
# ./Data/Images\sub-OAS30407_ses-d0061_run-01
# ./Data/Images\sub-OAS30407_ses-d0061_run-02
# ./Data/Images\sub-OAS30407_ses-d1267
# ./Data/Images\sub-OAS30407_ses-d2862
# ./Data/Images\sub-OAS30408_ses-d1193_run-01
# ./Data/Images\sub-OAS30408_ses-d1193_run-02
# ./Data/Images\sub-OAS30408_ses-d1193_run-03
# ./Data/Images\sub-OAS30410_ses-d0034
# ./Data/Images\sub-OAS30411_ses-d0183_run-01
# ./Data/Images\sub-OAS30411_ses-d0183_run-02
# ./Data/Images\sub-OAS30411_ses-d0183_run-03
# ./Data/Images\sub-OAS30411_ses-d1227_run-01
# ./Data/Images\sub-OAS30411_ses-d1227_run-02
# ./Data/Images\sub-OAS30411_ses-d3011
# ./Data/Images\sub-OAS30411_ses-d3025
# ./Data/Images\sub-OAS30411_ses-d4368
# ./Data/Images\sub-OAS30412_ses-d6024_run-01
# ./Data/Images\sub-OAS30412_ses-d6024_run-02
# ./Data/Images\sub-OAS30412_ses-d6024_run-03
# ./Data/Images\sub-OAS30413_ses-d0044
# ./Data/Images\sub-OAS30413_ses-d0561_run-01
# ./Data/Images\sub-OAS30413_ses-d0561_run-02
# ./Data/Images\sub-OAS30413_ses-d1533_run-01
# ./Data/Images\sub-OAS30413_ses-d1533_run-02
# ./Data/Images\sub-OAS30414_ses-d0030_run-01
# ./Data/Images\sub-OAS30414_ses-d0030_run-02
# ./Data/Images\sub-OAS30414_ses-d0037
# ./Data/Images\sub-OAS30414_ses-d0363
# ./Data/Images\sub-OAS30414_ses-d1175_run-01
# ./Data/Images\sub-OAS30414_ses-d1175_run-02
# ./Data/Images\sub-OAS30415_ses-d0784
# ./Data/Images\sub-OAS30416_ses-d0044
# ./Data/Images\sub-OAS30417_ses-d0093
# ./Data/Images\sub-OAS30417_ses-d0107
# ./Data/Images\sub-OAS30418_ses-d0069_run-01
# ./Data/Images\sub-OAS30418_ses-d0069_run-02
# ./Data/Images\sub-OAS30418_ses-d0803
# ./Data/Images\sub-OAS30419_ses-d0621_run-01
# ./Data/Images\sub-OAS30419_ses-d0621_run-02
# ./Data/Images\sub-OAS30419_ses-d1139_run-01
# ./Data/Images\sub-OAS30419_ses-d1139_run-02
# ./Data/Images\sub-OAS30419_ses-d2360
# ./Data/Images\sub-OAS30419_ses-d3307
# ./Data/Images\sub-OAS30420_ses-d2792_run-01
# ./Data/Images\sub-OAS30420_ses-d2792_run-02
# ./Data/Images\sub-OAS30420_ses-d2792_run-03
# ./Data/Images\sub-OAS30420_ses-d3746_run-01
# ./Data/Images\sub-OAS30420_ses-d3746_run-02
# ./Data/Images\sub-OAS30421_ses-d2605_run-01
# ./Data/Images\sub-OAS30421_ses-d2605_run-02
# ./Data/Images\sub-OAS30422_ses-d0104
# ./Data/Images\sub-OAS30423_ses-d0067_run-01
# ./Data/Images\sub-OAS30423_ses-d0067_run-02
# ./Data/Images\sub-OAS30423_ses-d1267
# ./Data/Images\sub-OAS30423_ses-d2099
# ./Data/Images\sub-OAS30424_ses-d0095_run-01
# ./Data/Images\sub-OAS30424_ses-d0095_run-02
# ./Data/Images\sub-OAS30427_ses-d4348
# ./Data/Images\sub-OAS30428_ses-d0133
# ./Data/Images\sub-OAS30429_ses-d0055
# ./Data/Images\sub-OAS30430_ses-d0055_run-01
# ./Data/Images\sub-OAS30430_ses-d0055_run-02
# ./Data/Images\sub-OAS30430_ses-d0909
# ./Data/Images\sub-OAS30431_ses-d0113
# ./Data/Images\sub-OAS30432_ses-d0100
# ./Data/Images\sub-OAS30433_ses-d1954_run-01
# ./Data/Images\sub-OAS30433_ses-d1954_run-02
# ./Data/Images\sub-OAS30434_ses-d0054
# ./Data/Images\sub-OAS30436_ses-d0388_run-01
# ./Data/Images\sub-OAS30436_ses-d0388_run-02
# ./Data/Images\sub-OAS30438_ses-d0064_run-01
# ./Data/Images\sub-OAS30438_ses-d0064_run-02
# ./Data/Images\sub-OAS30438_ses-d0897
# ./Data/Images\sub-OAS30438_ses-d2358
# ./Data/Images\sub-OAS30440_ses-d0163
# ./Data/Images\sub-OAS30441_ses-d0053
# ./Data/Images\sub-OAS30442_ses-d0903
# ./Data/Images\sub-OAS30443_ses-d0162
# ./Data/Images\sub-OAS30443_ses-d1480
# ./Data/Images\sub-OAS30443_ses-d2432
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-2e7e9feb2154> in <module>
#      18         if (100 <= img_num < 199):
#      19             img_slice = cv2.imread(os.path.join(run_dir, filename), cv2.IMREAD_GRAYSCALE)
# ---> 20             img_slice = img_slice/256
#      21             run_imgs.append(img_slice)
#      22
#
# TypeError: unsupported operand type(s) for /: 'NoneType' and 'int'

# %%
imgs

# %%
# Models to choose from [resnet, alexnet, vgg, squeezenet, densenet, inception]
model_name = "densenet"

# Number of classes in the dataset
num_classes = 2

# Batch size for training (change depending on how much memory you have)
batch_size = 16

# Number of epochs to train for
num_epochs = 15

# Flag for feature extracting. When False, we finetune the whole model,
#   when True we only update the reshaped layer params
feature_extract = True

# %%
class T1Dataset(Dataset):
    def __init__(self, data, target, transform=None):
        self.data = torch.from_numpy(data).float()
        self.target = torch.from_numpy(target).long()
        self.transform = transform

    def __getitem__(self, index):
        x = self.data[index]
        y = self.target[index]

        if self.transform:
            x = self.transform(x)

        return x, y

    def __len__(self):
        return len(self.data)

# %%
ad_imgs, ad_labels = [], []

for idx, ad in enumerate(labels):
    if ad:
        ad_imgs.append(imgs[idx])
        ad_labels.append(1)

ad_imgs = np.array(ad_imgs)
ad_labels = np.array(ad_labels)
imgs = np.array(imgs)

normal_ratio = imgs.shape[0] // ad_imgs.shape[0]

new_imgs = np.concatenate((imgs, np.repeat(ad_imgs, normal_ratio, axis=0)), axis=0)
new_labels = np.concatenate((labels, np.repeat(ad_labels, normal_ratio, axis=0)), axis=0)

# new_imgs = imgs
# new_labels = labels

# %%
full_dataset = T1Dataset(new_imgs, new_labels)
train_size = int(0.6 * len(full_dataset))
val_size = int(0.2 * len(full_dataset))
test_size = len(full_dataset) - train_size - val_size
train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(full_dataset, [train_size, val_size, test_size])

# %%
image_datasets = {'train': train_dataset, 'val': val_dataset, 'test': test_dataset}
dataloaders_dict = {x: torch.utils.data.DataLoader(image_datasets[x], 
                                                   batch_size=batch_size,
                                                   pin_memory=True,
                                                   shuffle=True, num_workers=0) for x in ['train', 'val', 'test']}

# %%
def train_model(model, dataloaders, criterion, optimizer, num_epochs=25, is_inception=False):
    since = time.time()

    val_acc_history = []

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    # Get model outputs and calculate loss
                    # Special case for inception because in training it has an auxiliary output. In train
                    #   mode we calculate the loss by summing the final output and the auxiliary output
                    #   but in testing we only consider the final output.
                    if is_inception and phase == 'train':
                        # From https://discuss.pytorch.org/t/how-to-optimize-inception-model-with-auxiliary-classifiers/7958
                        outputs, aux_outputs = model(inputs)
                        loss1 = criterion(outputs, labels)
                        loss2 = criterion(aux_outputs, labels)
                        loss = loss1 + 0.4*loss2
                    else:
                        outputs = model(inputs)
                        loss = criterion(outputs, labels)

                    _, preds = torch.max(outputs, 1)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            if phase == 'val':
                val_acc_history.append(epoch_acc)

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, val_acc_history

# %%
def set_parameter_requires_grad(model, feature_extracting):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False

# %%
def initialize_model(model_name, num_classes, feature_extract, use_pretrained=True):
    # Initialize these variables which will be set in this if statement. Each of these
    #   variables is model specific.
    model_ft = None
    input_size = 0

    if model_name == "resnet":
        """ Resnet18
        """
        model_ft = models.resnet18(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.fc.in_features
        model_ft.fc = nn.Linear(num_ftrs, num_classes)
        input_size = 256

    elif model_name == "alexnet":
        """ Alexnet
        """
        model_ft = models.alexnet(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.classifier[6].in_features
        model_ft.classifier[6] = nn.Linear(num_ftrs,num_classes)
        input_size = 256

    elif model_name == "vgg":
        """ VGG11_bn
        """
        model_ft = models.vgg11_bn(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.classifier[6].in_features
        model_ft.classifier[6] = nn.Linear(num_ftrs,num_classes)
        input_size = 256

    elif model_name == "squeezenet":
        """ Squeezenet
        """
        model_ft = models.squeezenet1_0(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        model_ft.classifier[1] = nn.Conv2d(512, num_classes, kernel_size=(1,1), stride=(1,1))
        model_ft.num_classes = num_classes
        input_size = 256

    elif model_name == "densenet":
        """ Densenet
        """
        model_ft = models.densenet121(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.classifier.in_features
        model_ft.classifier = nn.Linear(num_ftrs, num_classes)
        input_size = 256

    elif model_name == "inception":
        """ Inception v3
        Be careful, expects (299,299) sized images and has auxiliary output
        """
        model_ft = models.inception_v3(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        # Handle the auxilary net
        num_ftrs = model_ft.AuxLogits.fc.in_features
        model_ft.AuxLogits.fc = nn.Linear(num_ftrs, num_classes)
        # Handle the primary net
        num_ftrs = model_ft.fc.in_features
        model_ft.fc = nn.Linear(num_ftrs,num_classes)
        input_size = 299

    else:
        print("Invalid model name, exiting...")
        exit()

    return model_ft, input_size

# Initialize the model for this run
model_ft, input_size = initialize_model(model_name, num_classes, feature_extract, use_pretrained=True)

# Print the model we just instantiated
print(model_ft)

# %%
# Send the model to GPU
model_ft = model_ft.to(device)

# Gather the parameters to be optimized/updated in this run. If we are
#  finetuning we will be updating all parameters. However, if we are
#  doing feature extract method, we will only update the parameters
#  that we have just initialized, i.e. the parameters with requires_grad
#  is True.
params_to_update = model_ft.parameters()
print("Params to learn:")
if feature_extract:
    params_to_update = []
    for name,param in model_ft.named_parameters():
        if param.requires_grad == True:
            params_to_update.append(param)
            print("\t",name)
else:
    for name,param in model_ft.named_parameters():
        if param.requires_grad == True:
            print("\t",name)

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(params_to_update, lr=0.001, momentum=0.9)

# %%
# Setup the loss fxn
criterion = nn.CrossEntropyLoss()

# Train and evaluate
model_ft, hist = train_model(model_ft, dataloaders_dict, criterion, optimizer_ft, num_epochs=num_epochs, is_inception=(model_name=="inception"))

# %%
# Initialize the non-pretrained version of the model used for this run
scratch_model,_ = initialize_model(model_name, num_classes, feature_extract=False, use_pretrained=True)
scratch_model = scratch_model.to(device)

params_to_update = scratch_model.parameters()
print("Params to learn:")
if feature_extract:
    params_to_update = []
    for name,param in model_ft.named_parameters():
        if param.requires_grad == True:
            params_to_update.append(param)
            print("\t",name)
else:
    for name,param in model_ft.named_parameters():
        if param.requires_grad == True:
            print("\t",name)

scratch_optimizer = optim.SGD(scratch_model.parameters(), lr=0.001, momentum=0.9)
scratch_criterion = nn.CrossEntropyLoss()
_,scratch_hist = train_model(scratch_model, dataloaders_dict, scratch_criterion, scratch_optimizer, num_epochs=num_epochs, is_inception=(model_name=="inception"))

# Plot the training curves of validation accuracy vs. number
#  of training epochs for the transfer learning method and
#  the model trained from scratch
ohist = []
shist = []

ohist = [h.cpu().numpy() for h in hist]
shist = [h.cpu().numpy() for h in scratch_hist]

plt.title("Validation Accuracy vs. Number of Training Epochs")
plt.xlabel("Training Epochs")
plt.ylabel("Validation Accuracy")
plt.plot(range(1,num_epochs+1),ohist,label="Pretrained")
plt.plot(range(1,num_epochs+1),shist,label="Scratch")
plt.ylim((0,1.))
plt.xticks(np.arange(1, num_epochs+1, 1.0))
plt.legend()
plt.show()
