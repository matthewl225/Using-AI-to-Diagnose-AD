# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cv2
import os

# %%
# CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
print(device)
torch.backends.cudnn.benchmark = True
# Out:
# cuda:0

# %%
runs_list = next(os.walk('./Data/Images'))[1]

# %%
path = "./Data/Labels.csv"
header = ['Run','AD']
Labelsdf = pd.read_csv(path, names=header, usecols=[1,2], skiprows=1, index_col=False)

# %%
labels_dict = dict(zip(Labelsdf.Run, Labelsdf.AD))

# %%
import re

# BASELINE RGB
img_dir = "./Data/Images"
low_bound = 100
high_bound = 200
img_scale = 1
depth_scale = 33
#list of tuples (image data, AD)
train_data, valid_data, test_data = [], [], []
for run in runs_list:
    print(run)
    run_dir = os.path.join(img_dir, run)
    run_imgs = []
    for filename in os.listdir(run_dir):
        img_num = int(filename[-7:-4])
        if (100 <= img_num < 199):
            img_slice = cv2.imread(os.path.join(run_dir, filename), cv2.IMREAD_GRAYSCALE)
            #print(img_slice)
            #img_slice = cv2.resize(img_slice, (0,0), fx=1/img_scale, fy=1/img_scale, interpolation=cv2.INTER_AREA)
            #img_slice = img_slice[40:216,:]
            img_slice = img_slice/256
            run_imgs.append(img_slice)

    temp_arr = np.array(run_imgs)
    
    if temp_arr.size == 0 or temp_arr.shape[1] != 256 or temp_arr.shape[2] != 176:
#         print(run)
#         print(temp_arr.shape)
        continue
    
    # add black bars on the left/right
#     i = 0
    temp_imgs = []
    for img_slice in temp_arr:
#         print(i)
#         i += 1
        final_slice = np.zeros([256,256])
        final_slice[:, 40:216] = img_slice
#         plt.imshow(final_slice)
#         plt.show()
        temp_imgs.append(final_slice)
    
    temp_arr = np.array(temp_imgs)
    
    final_slices = []
    #print(temp_arr.shape[2])
    
    for y in range(temp_arr.shape[2]):
        xz_pane = temp_arr[:, :, y]
        scaled_xz = cv2.resize(xz_pane, (0, 0), fy=1/depth_scale, fx=1, interpolation=cv2.INTER_AREA)
        final_slices.append(scaled_xz)
    
    if not len(final_slices[0]) == 3:
        continue
    
    final_array = torch.from_numpy(np.dstack(final_slices)).float()
    #print(final_array.shape)
    run_tuple = (final_array, labels_dict[run])
    
    subject_regex = re.compile("OAS(?P<order>[0-9]+)")
    subject = subject_regex.search(run).group(1)
    
    if int(subject[-2]) < 6:
        train_data.append(run_tuple)
    elif 6 <= int(subject[-2]) <=7:
        valid_data.append(run_tuple)
    elif 8 <= int(subject[-2]) <= 9:
        test_data.append(run_tuple)
    
    
print("Number of data points in train dataset: {}".format(len(train_data)))
print("Number of data points in valid dataset: {}".format(len(valid_data)))
print("Number of data points in test dataset: {}".format(len(test_data)))
# Out:
# sub-OAS30001_ses-d0129_run-01
# sub-OAS30001_ses-d0129_run-02
# sub-OAS30001_ses-d0757_run-01
# sub-OAS30001_ses-d0757_run-02
# sub-OAS30001_ses-d2430
# sub-OAS30001_ses-d3132
# sub-OAS30002_ses-d0371
# sub-OAS30002_ses-d0653_run-01
# sub-OAS30002_ses-d0653_run-02
# sub-OAS30002_ses-d2340_run-01
# sub-OAS30002_ses-d2340_run-02
# sub-OAS30002_ses-d2345
# sub-OAS30003_ses-d0558_run-01
# sub-OAS30003_ses-d0558_run-02
# sub-OAS30003_ses-d1631_run-01
# sub-OAS30003_ses-d1631_run-02
# sub-OAS30003_ses-d2669
# sub-OAS30003_ses-d2682
# sub-OAS30003_ses-d3320
# sub-OAS30003_ses-d3731
# sub-OAS30004_ses-d1101_run-01
# sub-OAS30004_ses-d1101_run-02
# sub-OAS30004_ses-d2229_run-01
# sub-OAS30004_ses-d2229_run-02
# sub-OAS30004_ses-d2232_run-01
# sub-OAS30004_ses-d2232_run-02
# sub-OAS30004_ses-d3457
# sub-OAS30005_ses-d0143
# sub-OAS30005_ses-d0581_run-01
# sub-OAS30005_ses-d0581_run-02
# sub-OAS30005_ses-d1274_run-01
# sub-OAS30005_ses-d1274_run-02
# sub-OAS30005_ses-d2377
# sub-OAS30005_ses-d2384
# sub-OAS30005_ses-d3453
# sub-OAS30006_ses-d0166
# sub-OAS30006_ses-d0373_run-01
# sub-OAS30006_ses-d0373_run-02
# sub-OAS30006_ses-d2341
# sub-OAS30006_ses-d2342
# sub-OAS30006_ses-d3386
# sub-OAS30007_ses-d0061_run-01
# sub-OAS30007_ses-d0061_run-02
# sub-OAS30007_ses-d1636
# sub-OAS30007_ses-d1641
# sub-OAS30007_ses-d1981
# sub-OAS30007_ses-d2722
# sub-OAS30008_ses-d0061_run-01
# sub-OAS30008_ses-d0061_run-02
# sub-OAS30008_ses-d1313
# sub-OAS30008_ses-d1327
# sub-OAS30008_ses-d2035
# sub-OAS30009_ses-d0148_run-01
# sub-OAS30009_ses-d0148_run-02
# sub-OAS30009_ses-d1210
# sub-OAS30009_ses-d2457
# sub-OAS30010_ses-d0068
# sub-OAS30011_ses-d0055
# sub-OAS30011_ses-d1671
# sub-OAS30012_ses-d0124_run-01
# sub-OAS30012_ses-d0124_run-02
# sub-OAS30012_ses-d0124_run-03
# sub-OAS30012_ses-d0581_run-01
# sub-OAS30012_ses-d0581_run-02
# sub-OAS30012_ses-d0581_run-03
# sub-OAS30013_ses-d0102
# sub-OAS30014_ses-d0196_run-01
# sub-OAS30014_ses-d0196_run-02
# sub-OAS30014_ses-d1176_run-01
# sub-OAS30014_ses-d1176_run-02
# sub-OAS30015_ses-d0116_run-01
# sub-OAS30015_ses-d0116_run-02
# sub-OAS30015_ses-d0788_run-01
# sub-OAS30015_ses-d0788_run-02
# sub-OAS30015_ses-d1374_run-01
# sub-OAS30015_ses-d1374_run-02
# sub-OAS30015_ses-d2004
# sub-OAS30016_ses-d0021
# sub-OAS30017_ses-d0054_run-01
# sub-OAS30017_ses-d0054_run-02
# sub-OAS30018_ses-d0070_run-01
# sub-OAS30018_ses-d0070_run-02
# sub-OAS30018_ses-d0893
# sub-OAS30019_ses-d0376
# sub-OAS30020_ses-d0092_run-01
# sub-OAS30020_ses-d0092_run-02
# sub-OAS30020_ses-d0092_run-03
# sub-OAS30020_ses-d0092_run-04
# sub-OAS30020_ses-d0911_run-01
# sub-OAS30020_ses-d0911_run-02
# sub-OAS30020_ses-d0911_run-03
# sub-OAS30021_ses-d0071
# sub-OAS30022_ses-d1324_run-01
# sub-OAS30022_ses-d1324_run-02
# sub-OAS30022_ses-d1324_run-03
# sub-OAS30024_ses-d0084
# sub-OAS30025_ses-d0210_run-01
# sub-OAS30025_ses-d0210_run-02
# sub-OAS30025_ses-d2298
# sub-OAS30026_ses-d0048
# sub-OAS30026_ses-d0129
# sub-OAS30026_ses-d0696
# sub-OAS30027_ses-d0433_run-01
# sub-OAS30027_ses-d0433_run-02
# sub-OAS30027_ses-d0433_run-03
# sub-OAS30027_ses-d1300_run-01
# sub-OAS30027_ses-d1300_run-02
# sub-OAS30027_ses-d2394
# sub-OAS30028_ses-d0043_run-01
# sub-OAS30028_ses-d0043_run-02
# sub-OAS30028_ses-d1260
# sub-OAS30028_ses-d1847
# sub-OAS30029_ses-d0131
# sub-OAS30029_ses-d0893
# sub-OAS30030_ses-d0170
# sub-OAS30031_ses-d0427_run-01
# sub-OAS30031_ses-d0427_run-02
# sub-OAS30032_ses-d0262_run-01
# sub-OAS30032_ses-d0262_run-02
# sub-OAS30032_ses-d0262_run-03
# sub-OAS30032_ses-d1661_run-01
# sub-OAS30032_ses-d1661_run-02
# sub-OAS30032_ses-d3499
# sub-OAS30033_ses-d0133_run-01
# sub-OAS30033_ses-d0133_run-02
# sub-OAS30033_ses-d1267
# sub-OAS30034_ses-d0044
# sub-OAS30035_ses-d2218_run-01
# sub-OAS30035_ses-d2218_run-02
# sub-OAS30035_ses-d3850
# sub-OAS30036_ses-d0059
# sub-OAS30037_ses-d0154
# sub-OAS30038_ses-d1214_run-01
# sub-OAS30038_ses-d1214_run-02
# sub-OAS30038_ses-d1214_run-03
# sub-OAS30038_ses-d2242_run-01
# sub-OAS30038_ses-d2242_run-02
# sub-OAS30038_ses-d3376
# sub-OAS30038_ses-d4495
# sub-OAS30039_ses-d0103
# sub-OAS30040_ses-d2899_run-01
# sub-OAS30040_ses-d2899_run-02
# sub-OAS30040_ses-d2899_run-03
# sub-OAS30040_ses-d4230_run-01
# sub-OAS30040_ses-d4230_run-02
# sub-OAS30040_ses-d5108
# sub-OAS30041_ses-d6548_run-01
# sub-OAS30041_ses-d6548_run-02
# sub-OAS30041_ses-d6548_run-03
# sub-OAS30041_ses-d6548_run-04
# sub-OAS30041_ses-d6548_run-05
# sub-OAS30042_ses-d0067
# sub-OAS30043_ses-d0145
# sub-OAS30044_ses-d0054
# sub-OAS30044_ses-d0061_run-01
# sub-OAS30044_ses-d0061_run-02
# sub-OAS30044_ses-d1319
# sub-OAS30046_ses-d0072_run-01
# sub-OAS30046_ses-d0072_run-02
# sub-OAS30046_ses-d0848
# sub-OAS30046_ses-d1968
# sub-OAS30048_ses-d0983_run-01
# sub-OAS30048_ses-d0983_run-02
# sub-OAS30048_ses-d0983_run-03
# sub-OAS30048_ses-d2292_run-01
# sub-OAS30048_ses-d2292_run-02
# sub-OAS30048_ses-d3367
# sub-OAS30048_ses-d3375_run-01
# sub-OAS30048_ses-d3375_run-02
# sub-OAS30048_ses-d3731
# sub-OAS30048_ses-d4459
# sub-OAS30049_ses-d0013_run-01
# sub-OAS30049_ses-d0013_run-02
# sub-OAS30049_ses-d1633
# sub-OAS30050_ses-d0110
# sub-OAS30050_ses-d1530
# sub-OAS30051_ses-d0200_run-01
# sub-OAS30051_ses-d0200_run-02
# sub-OAS30051_ses-d1286
# sub-OAS30052_ses-d0693_run-01
# sub-OAS30052_ses-d0693_run-02
# sub-OAS30052_ses-d1296_run-01
# sub-OAS30052_ses-d1296_run-02
# sub-OAS30052_ses-d2709
# sub-OAS30052_ses-d2737_run-01
# sub-OAS30052_ses-d2737_run-02
# sub-OAS30053_ses-d0428_run-01
# sub-OAS30053_ses-d0428_run-02
# sub-OAS30056_ses-d3491
# sub-OAS30057_ses-d0075
# sub-OAS30058_ses-d1316_run-01
# sub-OAS30058_ses-d1316_run-02
# sub-OAS30058_ses-d2236
# sub-OAS30058_ses-d3235
# sub-OAS30059_ses-d0230_run-01
# sub-OAS30059_ses-d0230_run-02
# sub-OAS30059_ses-d0230_run-03
# sub-OAS30059_ses-d0230_run-04
# sub-OAS30059_ses-d1188
# sub-OAS30060_ses-d0074_run-01
# sub-OAS30060_ses-d0074_run-02
# sub-OAS30061_ses-d0035
# sub-OAS30062_ses-d0087_run-01
# sub-OAS30062_ses-d0087_run-02
# sub-OAS30062_ses-d0087_run-03
# sub-OAS30062_ses-d1134_run-01
# sub-OAS30062_ses-d1134_run-02
# sub-OAS30062_ses-d1745_run-01
# sub-OAS30062_ses-d1745_run-02
# sub-OAS30062_ses-d3432
# sub-OAS30062_ses-d3469
# sub-OAS30063_ses-d0160_run-01
# sub-OAS30063_ses-d0160_run-02
# sub-OAS30064_ses-d0687_run-01
# sub-OAS30064_ses-d0687_run-02
# sub-OAS30065_ses-d0548
# sub-OAS30065_ses-d2009
# sub-OAS30066_ses-d0524
# sub-OAS30066_ses-d2006
# sub-OAS30067_ses-d0057
# sub-OAS30068_ses-d0076
# sub-OAS30070_ses-d0070
# sub-OAS30071_ses-d0018
# sub-OAS30071_ses-d0055
# sub-OAS30072_ses-d0218_run-01
# sub-OAS30072_ses-d0218_run-02
# sub-OAS30072_ses-d0218_run-03
# sub-OAS30072_ses-d1379_run-01
# sub-OAS30072_ses-d1379_run-02
# sub-OAS30072_ses-d2219
# sub-OAS30073_ses-d0033_run-01
# sub-OAS30073_ses-d0033_run-02
# sub-OAS30073_ses-d0033_run-03
# sub-OAS30073_ses-d0033_run-04
# sub-OAS30073_ses-d1587_run-01
# sub-OAS30073_ses-d1587_run-02
# sub-OAS30073_ses-d2042_run-01
# sub-OAS30073_ses-d2042_run-02
# sub-OAS30073_ses-d2851
# sub-OAS30073_ses-d3670
# sub-OAS30073_ses-d4456
# sub-OAS30074_ses-d0049_run-01
# sub-OAS30074_ses-d0049_run-02
# sub-OAS30074_ses-d1871
# sub-OAS30074_ses-d2812
# sub-OAS30075_ses-d0143
# sub-OAS30075_ses-d0148_run-01
# sub-OAS30075_ses-d0148_run-02
# sub-OAS30075_ses-d0442
# sub-OAS30075_ses-d0967
# sub-OAS30076_ses-d0534_run-01
# sub-OAS30076_ses-d0534_run-02
# sub-OAS30076_ses-d1735
# sub-OAS30077_ses-d0944
# sub-OAS30078_ses-d0210_run-01
# sub-OAS30078_ses-d0210_run-02
# sub-OAS30079_ses-d0019_run-01
# sub-OAS30079_ses-d0019_run-02
# sub-OAS30079_ses-d1833
# sub-OAS30079_ses-d2668
# sub-OAS30080_ses-d0048
# sub-OAS30080_ses-d1318
# sub-OAS30082_ses-d1700_run-01
# sub-OAS30082_ses-d1700_run-02
# sub-OAS30083_ses-d0465_run-01
# sub-OAS30083_ses-d0465_run-02
# sub-OAS30083_ses-d2882
# sub-OAS30083_ses-d3827
# sub-OAS30084_ses-d0470_run-01
# sub-OAS30084_ses-d0470_run-02
# sub-OAS30084_ses-d1360
# sub-OAS30085_ses-d1566
# sub-OAS30086_ses-d0000_run-01
# sub-OAS30086_ses-d0000_run-02
# sub-OAS30087_ses-d0260_run-01
# sub-OAS30087_ses-d0260_run-02
# sub-OAS30088_ses-d0093_run-01
# sub-OAS30088_ses-d0093_run-02
# sub-OAS30089_ses-d0001
# sub-OAS30090_ses-d0118
# sub-OAS30090_ses-d1294
# sub-OAS30091_ses-d0092_run-01
# sub-OAS30091_ses-d0092_run-02
# sub-OAS30092_ses-d0636
# sub-OAS30092_ses-d3727
# sub-OAS30093_ses-d0056
# sub-OAS30093_ses-d0070
# sub-OAS30093_ses-d1192
# sub-OAS30094_ses-d0140_run-01
# sub-OAS30094_ses-d0140_run-02
# sub-OAS30094_ses-d0140_run-03
# sub-OAS30094_ses-d0679_run-01
# sub-OAS30094_ses-d0679_run-02
# sub-OAS30094_ses-d0679_run-03
# sub-OAS30095_ses-d0033
# sub-OAS30096_ses-d0024_run-01
# sub-OAS30096_ses-d0024_run-02
# sub-OAS30097_ses-d0504_run-01
# sub-OAS30097_ses-d0504_run-02
# sub-OAS30097_ses-d2551
# sub-OAS30098_ses-d0036
# sub-OAS30099_ses-d0032
# sub-OAS30100_ses-d0158
# sub-OAS30101_ses-d0101_run-01
# sub-OAS30101_ses-d0101_run-02
# sub-OAS30101_ses-d0919_run-01
# sub-OAS30101_ses-d0919_run-02
# sub-OAS30101_ses-d2650
# sub-OAS30102_ses-d0024
# sub-OAS30103_ses-d3306_run-01
# sub-OAS30103_ses-d3306_run-02
# sub-OAS30103_ses-d3306_run-03
# sub-OAS30103_ses-d4255_run-01
# sub-OAS30103_ses-d4255_run-02
# sub-OAS30104_ses-d0328_run-01
# sub-OAS30104_ses-d0328_run-02
# sub-OAS30105_ses-d0056
# sub-OAS30106_ses-d2982_run-01
# sub-OAS30106_ses-d2982_run-02
# sub-OAS30106_ses-d2982_run-03
# sub-OAS30106_ses-d4675
# sub-OAS30107_ses-d0387_run-01
# sub-OAS30107_ses-d0387_run-02
# sub-OAS30107_ses-d0940_run-01
# sub-OAS30107_ses-d0940_run-02
# sub-OAS30107_ses-d2765
# sub-OAS30108_ses-d0168_run-01
# sub-OAS30108_ses-d0168_run-02
# sub-OAS30108_ses-d1062
# sub-OAS30108_ses-d2066
# sub-OAS30109_ses-d0270
# sub-OAS30109_ses-d0432_run-01
# sub-OAS30109_ses-d0432_run-02
# sub-OAS30109_ses-d0997_run-01
# sub-OAS30109_ses-d0997_run-02
# sub-OAS30109_ses-d2310
# sub-OAS30109_ses-d2320
# sub-OAS30110_ses-d0155_run-01
# sub-OAS30110_ses-d0155_run-02
# sub-OAS30111_ses-d0385_run-01
# sub-OAS30111_ses-d0385_run-02
# sub-OAS30112_ses-d0091
# sub-OAS30112_ses-d0098
# sub-OAS30112_ses-d0259
# sub-OAS30112_ses-d1196
# sub-OAS30113_ses-d0894
# sub-OAS30113_ses-d1301_run-01
# sub-OAS30113_ses-d1301_run-02
# sub-OAS30113_ses-d2280_run-01
# sub-OAS30113_ses-d2280_run-02
# sub-OAS30113_ses-d3502
# sub-OAS30113_ses-d4047
# sub-OAS30113_ses-d4437
# sub-OAS30114_ses-d0086
# sub-OAS30115_ses-d0138
# sub-OAS30116_ses-d0017_run-01
# sub-OAS30116_ses-d0017_run-02
# sub-OAS30117_ses-d2034_run-01
# sub-OAS30117_ses-d2034_run-02
# sub-OAS30117_ses-d4155
# sub-OAS30118_ses-d0000_run-01
# sub-OAS30118_ses-d0000_run-02
# sub-OAS30118_ses-d0000_run-03
# sub-OAS30118_ses-d1663_run-01
# sub-OAS30118_ses-d1663_run-02
# sub-OAS30119_ses-d1209_run-01
# sub-OAS30119_ses-d1209_run-02
# sub-OAS30119_ses-d1209_run-03
# sub-OAS30119_ses-d2415_run-01
# sub-OAS30119_ses-d2415_run-02
# sub-OAS30119_ses-d3260_run-01
# sub-OAS30119_ses-d3260_run-02
# sub-OAS30119_ses-d3722
# sub-OAS30120_ses-d0784_run-01
# sub-OAS30120_ses-d0784_run-02
# sub-OAS30120_ses-d0784_run-03
# sub-OAS30120_ses-d0784_run-04
# sub-OAS30121_ses-d0768_run-01
# sub-OAS30121_ses-d0768_run-02
# sub-OAS30121_ses-d0768_run-03
# sub-OAS30121_ses-d0768_run-04
# sub-OAS30121_ses-d2392_run-01
# sub-OAS30121_ses-d2392_run-02
# sub-OAS30122_ses-d0136
# sub-OAS30123_ses-d0122
# sub-OAS30124_ses-d0046_run-01
# sub-OAS30124_ses-d0046_run-02
# sub-OAS30125_ses-d0201_run-01
# sub-OAS30125_ses-d0201_run-02
# sub-OAS30126_ses-d1105_run-01
# sub-OAS30126_ses-d1105_run-02
# sub-OAS30126_ses-d2361
# sub-OAS30126_ses-d2849
# sub-OAS30126_ses-d3465
# sub-OAS30127_ses-d0098
# sub-OAS30127_ses-d0110
# sub-OAS30127_ses-d0837
# sub-OAS30128_ses-d0044
# sub-OAS30129_ses-d0055
# sub-OAS30130_ses-d0025_run-01
# sub-OAS30130_ses-d0025_run-02
# sub-OAS30131_ses-d0086_run-01
# sub-OAS30131_ses-d0086_run-02
# sub-OAS30131_ses-d0086_run-03
# sub-OAS30131_ses-d0632_run-01
# sub-OAS30131_ses-d0632_run-02
# sub-OAS30131_ses-d0632_run-03
# sub-OAS30131_ses-d1901_run-01
# sub-OAS30131_ses-d1901_run-02
# sub-OAS30132_ses-d0063_run-01
# sub-OAS30132_ses-d0063_run-02
# sub-OAS30132_ses-d1392
# sub-OAS30132_ses-d2288
# sub-OAS30133_ses-d0505
# sub-OAS30134_ses-d0080_run-01
# sub-OAS30134_ses-d0080_run-02
# sub-OAS30134_ses-d1642
# sub-OAS30135_ses-d0190
# sub-OAS30135_ses-d0341_run-01
# sub-OAS30135_ses-d0341_run-02
# sub-OAS30135_ses-d1000_run-01
# sub-OAS30135_ses-d1000_run-02
# sub-OAS30135_ses-d2357
# sub-OAS30135_ses-d2367
# sub-OAS30135_ses-d2799
# sub-OAS30135_ses-d2931
# sub-OAS30136_ses-d0063
# sub-OAS30137_ses-d3165
# sub-OAS30137_ses-d3907
# sub-OAS30137_ses-d4208
# sub-OAS30137_ses-d4525
# sub-OAS30139_ses-d0101
# sub-OAS30139_ses-d1702
# sub-OAS30140_ses-d0172_run-01
# sub-OAS30140_ses-d0172_run-02
# sub-OAS30141_ses-d0544
# sub-OAS30141_ses-d1306
# sub-OAS30142_ses-d0075_run-01
# sub-OAS30142_ses-d0075_run-02
# sub-OAS30142_ses-d1279
# sub-OAS30143_ses-d2235_run-01
# sub-OAS30143_ses-d2235_run-02
# sub-OAS30143_ses-d3507
# sub-OAS30143_ses-d3509
# sub-OAS30143_ses-d3856
# sub-OAS30143_ses-d4041
# sub-OAS30144_ses-d1204_run-01
# sub-OAS30144_ses-d1204_run-02
# sub-OAS30144_ses-d1204_run-03
# sub-OAS30145_ses-d3506_run-01
# sub-OAS30145_ses-d3506_run-02
# sub-OAS30145_ses-d4247_run-01
# sub-OAS30145_ses-d4247_run-02
# sub-OAS30146_ses-d0272_run-01
# sub-OAS30146_ses-d0272_run-02
# sub-OAS30146_ses-d1042_run-01
# sub-OAS30146_ses-d1042_run-02
# sub-OAS30146_ses-d2309
# sub-OAS30146_ses-d3322
# sub-OAS30147_ses-d0048
# sub-OAS30149_ses-d0051
# sub-OAS30149_ses-d1240
# sub-OAS30150_ses-d0100_run-01
# sub-OAS30150_ses-d0100_run-02
# sub-OAS30151_ses-d0064
# sub-OAS30152_ses-d0111_run-01
# sub-OAS30152_ses-d0111_run-02
# sub-OAS30153_ses-d2220_run-01
# sub-OAS30153_ses-d2220_run-02
# sub-OAS30153_ses-d2220_run-03
# sub-OAS30153_ses-d2220_run-04
# sub-OAS30153_ses-d3877_run-01
# sub-OAS30153_ses-d3877_run-02
# sub-OAS30154_ses-d0244
# sub-OAS30155_ses-d0785
# sub-OAS30156_ses-d0000_run-01
# sub-OAS30156_ses-d0000_run-02
# sub-OAS30156_ses-d0000_run-03
# sub-OAS30156_ses-d0503_run-01
# sub-OAS30156_ses-d0503_run-02
# sub-OAS30157_ses-d0889_run-01
# sub-OAS30157_ses-d0889_run-02
# sub-OAS30157_ses-d0889_run-03
# sub-OAS30157_ses-d1428_run-01
# sub-OAS30157_ses-d1428_run-02
# sub-OAS30157_ses-d1428_run-03
# sub-OAS30157_ses-d2674_run-01
# sub-OAS30157_ses-d2674_run-02
# sub-OAS30158_ses-d2467_run-01
# sub-OAS30158_ses-d2467_run-02
# sub-OAS30159_ses-d0110
# sub-OAS30160_ses-d0099_run-01
# sub-OAS30160_ses-d0099_run-02
# sub-OAS30160_ses-d0751_run-01
# sub-OAS30160_ses-d0751_run-02
# sub-OAS30160_ses-d2392
# sub-OAS30161_ses-d0297_run-01
# sub-OAS30161_ses-d0297_run-02
# sub-OAS30161_ses-d2517
# sub-OAS30163_ses-d0091_run-01
# sub-OAS30163_ses-d0091_run-02
# sub-OAS30164_ses-d0233_run-01
# sub-OAS30164_ses-d0233_run-02
# sub-OAS30164_ses-d0975_run-01
# sub-OAS30164_ses-d0975_run-02
# sub-OAS30164_ses-d2416
# sub-OAS30165_ses-d0563_run-01
# sub-OAS30165_ses-d0563_run-02
# sub-OAS30165_ses-d1763
# sub-OAS30167_ses-d0111
# sub-OAS30167_ses-d1340
# sub-OAS30168_ses-d0059_run-01
# sub-OAS30168_ses-d0059_run-02
# sub-OAS30168_ses-d1268
# sub-OAS30169_ses-d0282_run-01
# sub-OAS30169_ses-d0282_run-02
# sub-OAS30170_ses-d0005
# sub-OAS30171_ses-d0139_run-01
# sub-OAS30171_ses-d0139_run-02
# sub-OAS30172_ses-d0028_run-01
# sub-OAS30172_ses-d0028_run-02
# sub-OAS30173_ses-d1188_run-01
# sub-OAS30173_ses-d1188_run-02
# sub-OAS30173_ses-d3030
# sub-OAS30173_ses-d3841
# sub-OAS30174_ses-d0582_run-01
# sub-OAS30174_ses-d0582_run-02
# sub-OAS30175_ses-d0349_run-01
# sub-OAS30175_ses-d0349_run-02
# sub-OAS30175_ses-d1091_run-01
# sub-OAS30175_ses-d1091_run-02
# sub-OAS30175_ses-d3219
# sub-OAS30176_ses-d0000
# sub-OAS30178_ses-d0049
# sub-OAS30178_ses-d0516_run-01
# sub-OAS30178_ses-d0516_run-02
# sub-OAS30178_ses-d1384_run-01
# sub-OAS30178_ses-d1384_run-02
# sub-OAS30178_ses-d2443
# sub-OAS30178_ses-d2455_run-01
# sub-OAS30178_ses-d2455_run-02
# sub-OAS30178_ses-d2794
# sub-OAS30178_ses-d3500
# sub-OAS30179_ses-d0061
# sub-OAS30180_ses-d0051_run-01
# sub-OAS30180_ses-d0051_run-02
# sub-OAS30181_ses-d0058
# sub-OAS30182_ses-d0094
# sub-OAS30182_ses-d0101
# sub-OAS30182_ses-d1397
# sub-OAS30183_ses-d0082_run-01
# sub-OAS30183_ses-d0082_run-02
# sub-OAS30184_ses-d0169_run-01
# sub-OAS30184_ses-d0169_run-02
# sub-OAS30184_ses-d0876_run-01
# sub-OAS30184_ses-d0876_run-02
# sub-OAS30184_ses-d3157
# sub-OAS30185_ses-d3787
# sub-OAS30185_ses-d4551
# sub-OAS30187_ses-d0070
# sub-OAS30188_ses-d0246_run-01
# sub-OAS30188_ses-d0246_run-02
# sub-OAS30188_ses-d0246_run-03
# sub-OAS30188_ses-d1788_run-01
# sub-OAS30188_ses-d1788_run-02
# sub-OAS30188_ses-d3844
# sub-OAS30189_ses-d0072
# sub-OAS30190_ses-d0082_run-01
# sub-OAS30190_ses-d0082_run-02
# sub-OAS30191_ses-d1136
# sub-OAS30191_ses-d2352
# sub-OAS30192_ses-d0293_run-01
# sub-OAS30192_ses-d0293_run-02
# sub-OAS30192_ses-d0293_run-03
# sub-OAS30192_ses-d1409_run-01
# sub-OAS30192_ses-d1409_run-02
# sub-OAS30193_ses-d0043_run-01
# sub-OAS30193_ses-d0043_run-02
# sub-OAS30193_ses-d1611
# sub-OAS30194_ses-d5837_run-01
# sub-OAS30194_ses-d5837_run-02
# sub-OAS30194_ses-d5837_run-03
# sub-OAS30194_ses-d6419_run-01
# sub-OAS30194_ses-d6419_run-02
# sub-OAS30194_ses-d6419_run-03
# sub-OAS30194_ses-d6605_run-01
# sub-OAS30194_ses-d6605_run-02
# sub-OAS30194_ses-d7432_run-01
# sub-OAS30194_ses-d7432_run-02
# sub-OAS30194_ses-d7432_run-03
# sub-OAS30194_ses-d8874
# sub-OAS30194_ses-d8881
# sub-OAS30194_ses-d9317
# sub-OAS30194_ses-d9443
# sub-OAS30194_ses-d9874
# sub-OAS30195_ses-d0193
# sub-OAS30197_ses-d0115
# sub-OAS30198_ses-d0083
# sub-OAS30199_ses-d0024
# sub-OAS30200_ses-d0075_run-01
# sub-OAS30200_ses-d0075_run-02
# sub-OAS30202_ses-d0175_run-01
# sub-OAS30202_ses-d0175_run-02
# sub-OAS30203_ses-d0203_run-01
# sub-OAS30203_ses-d0203_run-02
# sub-OAS30203_ses-d0203_run-03
# sub-OAS30203_ses-d0802_run-01
# sub-OAS30203_ses-d0802_run-02
# sub-OAS30203_ses-d0802_run-03
# sub-OAS30203_ses-d0802_run-04
# sub-OAS30203_ses-d0802_run-05
# sub-OAS30203_ses-d2881
# sub-OAS30204_ses-d0020
# sub-OAS30204_ses-d0033_run-01
# sub-OAS30204_ses-d0033_run-02
# sub-OAS30205_ses-d0061
# sub-OAS30206_ses-d0306_run-01
# sub-OAS30206_ses-d0306_run-02
# sub-OAS30206_ses-d1036_run-01
# sub-OAS30206_ses-d1036_run-02
# sub-OAS30206_ses-d2303
# sub-OAS30206_ses-d3024
# sub-OAS30207_ses-d0346_run-01
# sub-OAS30207_ses-d0346_run-02
# sub-OAS30208_ses-d0436
# sub-OAS30208_ses-d1703
# sub-OAS30209_ses-d0609_run-01
# sub-OAS30209_ses-d0609_run-02
# sub-OAS30209_ses-d1976
# sub-OAS30210_ses-d0047
# sub-OAS30211_ses-d0046
# sub-OAS30211_ses-d1239
# sub-OAS30212_ses-d0091_run-01
# sub-OAS30212_ses-d0091_run-02
# sub-OAS30212_ses-d0753_run-01
# sub-OAS30212_ses-d0753_run-02
# sub-OAS30212_ses-d3043
# sub-OAS30213_ses-d0041
# sub-OAS30214_ses-d4464
# sub-OAS30215_ses-d0098
# sub-OAS30216_ses-d2849_run-01
# sub-OAS30216_ses-d2849_run-02
# sub-OAS30216_ses-d2849_run-03
# sub-OAS30216_ses-d3830_run-01
# sub-OAS30216_ses-d3830_run-02
# sub-OAS30217_ses-d0077
# sub-OAS30218_ses-d0092_run-01
# sub-OAS30218_ses-d0092_run-02
# sub-OAS30218_ses-d0841
# sub-OAS30219_ses-d0064
# sub-OAS30219_ses-d1184
# sub-OAS30220_ses-d0104
# sub-OAS30220_ses-d1165
# sub-OAS30221_ses-d0079
# sub-OAS30221_ses-d1143
# sub-OAS30222_ses-d1000_run-01
# sub-OAS30222_ses-d1000_run-02
# sub-OAS30223_ses-d0455_run-01
# sub-OAS30223_ses-d0455_run-02
# sub-OAS30223_ses-d1235_run-01
# sub-OAS30223_ses-d1235_run-02
# sub-OAS30224_ses-d0556_run-01
# sub-OAS30224_ses-d0556_run-02
# sub-OAS30225_ses-d0482
# sub-OAS30226_ses-d0183_run-01
# sub-OAS30226_ses-d0183_run-02
# sub-OAS30227_ses-d0000_run-01
# sub-OAS30227_ses-d0000_run-02
# sub-OAS30228_ses-d0090
# sub-OAS30229_ses-d0101
# sub-OAS30230_ses-d3855
# sub-OAS30231_ses-d1469
# sub-OAS30231_ses-d2510_run-01
# sub-OAS30231_ses-d2510_run-02
# sub-OAS30231_ses-d3617
# sub-OAS30231_ses-d3630
# sub-OAS30232_ses-d0120_run-01
# sub-OAS30232_ses-d0120_run-02
# sub-OAS30232_ses-d0695_run-01
# sub-OAS30232_ses-d0695_run-02
# sub-OAS30232_ses-d2324
# sub-OAS30233_ses-d3867
# sub-OAS30233_ses-d5295
# sub-OAS30234_ses-d1119_run-01
# sub-OAS30234_ses-d1119_run-02
# sub-OAS30234_ses-d1119_run-03
# sub-OAS30234_ses-d2098_run-01
# sub-OAS30234_ses-d2098_run-02
# sub-OAS30235_ses-d0139
# sub-OAS30236_ses-d0088
# sub-OAS30237_ses-d1353_run-01
# sub-OAS30237_ses-d1353_run-02
# sub-OAS30237_ses-d1353_run-03
# sub-OAS30237_ses-d2478_run-01
# sub-OAS30237_ses-d2478_run-02
# sub-OAS30237_ses-d3368
# sub-OAS30238_ses-d0037
# sub-OAS30239_ses-d0175_run-01
# sub-OAS30239_ses-d0175_run-02
# sub-OAS30240_ses-d0865_run-01
# sub-OAS30240_ses-d0865_run-02
# sub-OAS30240_ses-d0865_run-03
# sub-OAS30240_ses-d1871_run-01
# sub-OAS30240_ses-d1871_run-02
# sub-OAS30240_ses-d3483
# sub-OAS30240_ses-d3487
# sub-OAS30240_ses-d3843
# sub-OAS30240_ses-d4197
# sub-OAS30241_ses-d0170_run-01
# sub-OAS30241_ses-d0170_run-02
# sub-OAS30241_ses-d0170_run-03
# sub-OAS30241_ses-d1203_run-01
# sub-OAS30241_ses-d1203_run-02
# sub-OAS30241_ses-d1706_run-01
# sub-OAS30241_ses-d1706_run-02
# sub-OAS30241_ses-d3605
# sub-OAS30242_ses-d0137
# sub-OAS30243_ses-d0034_run-01
# sub-OAS30243_ses-d0034_run-02
# sub-OAS30244_ses-d0104
# sub-OAS30244_ses-d1526
# sub-OAS30245_ses-d0058
# sub-OAS30245_ses-d0506_run-01
# sub-OAS30245_ses-d0506_run-02
# sub-OAS30246_ses-d0119_run-01
# sub-OAS30246_ses-d0119_run-02
# sub-OAS30246_ses-d0746_run-01
# sub-OAS30246_ses-d0746_run-02
# sub-OAS30246_ses-d1591
# sub-OAS30246_ses-d2354
# sub-OAS30247_ses-d0168_run-01
# sub-OAS30247_ses-d0168_run-02
# sub-OAS30247_ses-d0844_run-01
# sub-OAS30247_ses-d0844_run-02
# sub-OAS30247_ses-d2643
# sub-OAS30248_ses-d0078
# sub-OAS30248_ses-d1191
# sub-OAS30249_ses-d0091_run-01
# sub-OAS30249_ses-d0091_run-02
# sub-OAS30249_ses-d0091_run-03
# sub-OAS30249_ses-d0749
# sub-OAS30249_ses-d1238_run-01
# sub-OAS30249_ses-d1238_run-02
# sub-OAS30249_ses-d1952_run-01
# sub-OAS30249_ses-d1952_run-02
# sub-OAS30249_ses-d3431
# sub-OAS30249_ses-d4416
# sub-OAS30250_ses-d0389_run-01
# sub-OAS30250_ses-d0389_run-02
# sub-OAS30250_ses-d1233
# sub-OAS30250_ses-d1722_run-01
# sub-OAS30250_ses-d1722_run-02
# sub-OAS30251_ses-d0220_run-01
# sub-OAS30251_ses-d0220_run-02
# sub-OAS30251_ses-d2067
# sub-OAS30251_ses-d2954
# sub-OAS30253_ses-d1288
# sub-OAS30253_ses-d2541_run-01
# sub-OAS30253_ses-d2541_run-02
# sub-OAS30253_ses-d3490
# sub-OAS30253_ses-d3948
# sub-OAS30253_ses-d4746
# sub-OAS30254_ses-d0057_run-01
# sub-OAS30254_ses-d0057_run-02
# sub-OAS30255_ses-d0019_run-01
# sub-OAS30255_ses-d0019_run-02
# sub-OAS30256_ses-d0000_run-01
# sub-OAS30256_ses-d0000_run-02
# sub-OAS30256_ses-d0000_run-03
# sub-OAS30256_ses-d1284_run-01
# sub-OAS30256_ses-d1284_run-02
# sub-OAS30256_ses-d2368
# sub-OAS30256_ses-d3588
# sub-OAS30257_ses-d0610_run-01
# sub-OAS30257_ses-d0610_run-02
# sub-OAS30257_ses-d1938
# sub-OAS30257_ses-d3773
# sub-OAS30258_ses-d0487_run-01
# sub-OAS30258_ses-d0487_run-02
# sub-OAS30258_ses-d1225
# sub-OAS30259_ses-d0000_run-01
# sub-OAS30259_ses-d0000_run-02
# sub-OAS30259_ses-d0000_run-03
# sub-OAS30259_ses-d0679_run-01
# sub-OAS30259_ses-d0679_run-02
# sub-OAS30259_ses-d0679_run-03
# sub-OAS30261_ses-d0785_run-01
# sub-OAS30261_ses-d0785_run-02
# sub-OAS30261_ses-d1892
# sub-OAS30262_ses-d0037
# sub-OAS30262_ses-d0839
# sub-OAS30263_ses-d0129_run-01
# sub-OAS30263_ses-d0129_run-02
# sub-OAS30263_ses-d0970_run-01
# sub-OAS30263_ses-d0970_run-02
# sub-OAS30263_ses-d2477
# sub-OAS30263_ses-d2483
# sub-OAS30264_ses-d0466
# sub-OAS30265_ses-d0192_run-01
# sub-OAS30265_ses-d0192_run-02
# sub-OAS30266_ses-d0486
# sub-OAS30267_ses-d0043_run-01
# sub-OAS30267_ses-d0043_run-02
# sub-OAS30268_ses-d0096_run-01
# sub-OAS30268_ses-d0096_run-02
# sub-OAS30269_ses-d0052_run-01
# sub-OAS30269_ses-d0052_run-02
# sub-OAS30270_ses-d0070
# sub-OAS30271_ses-d0004_run-01
# sub-OAS30271_ses-d0004_run-02
# sub-OAS30272_ses-d0057_run-01
# sub-OAS30272_ses-d0057_run-02
# sub-OAS30272_ses-d2456
# sub-OAS30272_ses-d3087
# sub-OAS30273_ses-d0077
# sub-OAS30273_ses-d0461_run-01
# sub-OAS30273_ses-d0461_run-02
# sub-OAS30273_ses-d2304
# sub-OAS30274_ses-d0605_run-01
# sub-OAS30274_ses-d0605_run-02
# sub-OAS30274_ses-d3332
# sub-OAS30275_ses-d0280_run-01
# sub-OAS30275_ses-d0280_run-02
# sub-OAS30275_ses-d1006_run-01
# sub-OAS30275_ses-d1006_run-02
# sub-OAS30276_ses-d0138
# sub-OAS30276_ses-d1200_run-01
# sub-OAS30276_ses-d1200_run-02
# sub-OAS30276_ses-d2405
# sub-OAS30276_ses-d2408
# sub-OAS30276_ses-d3217
# sub-OAS30277_ses-d0198
# sub-OAS30278_ses-d0028_run-01
# sub-OAS30278_ses-d0028_run-02
# sub-OAS30278_ses-d0028_run-03
# sub-OAS30278_ses-d0028_run-04
# sub-OAS30278_ses-d1325_run-01
# sub-OAS30278_ses-d1325_run-02
# sub-OAS30279_ses-d0136
# sub-OAS30280_ses-d0085_run-01
# sub-OAS30280_ses-d0085_run-02
# sub-OAS30280_ses-d0667_run-01
# sub-OAS30280_ses-d0667_run-02
# sub-OAS30280_ses-d1647
# sub-OAS30281_ses-d0042
# sub-OAS30282_ses-d0040
# sub-OAS30283_ses-d0064_run-01
# sub-OAS30283_ses-d0064_run-02
# sub-OAS30283_ses-d0797
# sub-OAS30284_ses-d0094_run-01
# sub-OAS30284_ses-d0094_run-02
# sub-OAS30284_ses-d0094_run-03
# sub-OAS30284_ses-d1633_run-01
# sub-OAS30284_ses-d1633_run-02
# sub-OAS30284_ses-d3510
# sub-OAS30285_ses-d0055_run-01
# sub-OAS30285_ses-d0055_run-02
# sub-OAS30286_ses-d0047
# sub-OAS30287_ses-d0890
# sub-OAS30288_ses-d0897_run-01
# sub-OAS30288_ses-d0897_run-02
# sub-OAS30288_ses-d0897_run-03
# sub-OAS30288_ses-d4509
# sub-OAS30289_ses-d0160
# sub-OAS30290_ses-d0000
# sub-OAS30291_ses-d0078_run-01
# sub-OAS30291_ses-d0078_run-02
# sub-OAS30291_ses-d1979
# sub-OAS30292_ses-d0165_run-01
# sub-OAS30292_ses-d0165_run-02
# sub-OAS30293_ses-d0056
# sub-OAS30293_ses-d1221
# sub-OAS30294_ses-d0462_run-01
# sub-OAS30294_ses-d0462_run-02
# sub-OAS30295_ses-d0611_run-01
# sub-OAS30295_ses-d0611_run-02
# sub-OAS30295_ses-d0967_run-01
# sub-OAS30295_ses-d0967_run-02
# sub-OAS30296_ses-d0069
# sub-OAS30297_ses-d0105_run-01
# sub-OAS30297_ses-d0105_run-02
# sub-OAS30297_ses-d0105_run-03
# sub-OAS30297_ses-d1712_run-01
# sub-OAS30297_ses-d1712_run-02
# sub-OAS30298_ses-d0292_run-01
# sub-OAS30298_ses-d0292_run-02
# sub-OAS30299_ses-d0119_run-01
# sub-OAS30299_ses-d0119_run-02
# sub-OAS30300_ses-d0100
# sub-OAS30302_ses-d0262_run-01
# sub-OAS30302_ses-d0262_run-02
# sub-OAS30302_ses-d1456_run-01
# sub-OAS30302_ses-d1456_run-02
# sub-OAS30302_ses-d1456_run-03
# sub-OAS30303_ses-d0910_run-01
# sub-OAS30303_ses-d0910_run-02
# sub-OAS30303_ses-d0910_run-03
# sub-OAS30303_ses-d1948_run-01
# sub-OAS30303_ses-d1948_run-02
# sub-OAS30303_ses-d2650_run-01
# sub-OAS30303_ses-d2650_run-02
# sub-OAS30304_ses-d0027
# sub-OAS30305_ses-d0245_run-01
# sub-OAS30305_ses-d0245_run-02
# sub-OAS30306_ses-d0028
# sub-OAS30306_ses-d0473
# sub-OAS30307_ses-d0032_run-01
# sub-OAS30307_ses-d0032_run-02
# sub-OAS30307_ses-d2362
# sub-OAS30308_ses-d0004_run-01
# sub-OAS30308_ses-d0004_run-02
# sub-OAS30308_ses-d0423_run-01
# sub-OAS30308_ses-d0423_run-02
# sub-OAS30309_ses-d0094
# sub-OAS30310_ses-d0191
# sub-OAS30311_ses-d0127
# sub-OAS30312_ses-d0068
# sub-OAS30313_ses-d0048
# sub-OAS30314_ses-d6379_run-01
# sub-OAS30314_ses-d6379_run-02
# sub-OAS30314_ses-d6379_run-03
# sub-OAS30314_ses-d6827_run-01
# sub-OAS30314_ses-d6827_run-02
# sub-OAS30314_ses-d6827_run-03
# sub-OAS30314_ses-d7000_run-01
# sub-OAS30314_ses-d7000_run-02
# sub-OAS30314_ses-d7814_run-01
# sub-OAS30314_ses-d7814_run-02
# sub-OAS30315_ses-d0124
# sub-OAS30316_ses-d0018
# sub-OAS30317_ses-d0088
# sub-OAS30318_ses-d2975
# sub-OAS30318_ses-d3298
# sub-OAS30319_ses-d0043_run-01
# sub-OAS30319_ses-d0043_run-02
# sub-OAS30320_ses-d0136_run-01
# sub-OAS30320_ses-d0136_run-02
# sub-OAS30320_ses-d1740
# sub-OAS30321_ses-d0075_run-01
# sub-OAS30321_ses-d0075_run-02
# sub-OAS30321_ses-d1988
# sub-OAS30322_ses-d0173_run-01
# sub-OAS30322_ses-d0173_run-02
# sub-OAS30322_ses-d0173_run-03
# sub-OAS30322_ses-d0173_run-04
# sub-OAS30322_ses-d0173_run-05
# sub-OAS30322_ses-d0645_run-01
# sub-OAS30322_ses-d0645_run-02
# sub-OAS30322_ses-d0645_run-03
# sub-OAS30322_ses-d1630_run-01
# sub-OAS30322_ses-d1630_run-02
# sub-OAS30322_ses-d3851
# sub-OAS30323_ses-d0836
# sub-OAS30324_ses-d0119
# sub-OAS30324_ses-d0959
# sub-OAS30325_ses-d0032
# sub-OAS30326_ses-d0189_run-01
# sub-OAS30326_ses-d0189_run-02
# sub-OAS30327_ses-d0281_run-01
# sub-OAS30327_ses-d0281_run-02
# sub-OAS30328_ses-d0105
# sub-OAS30328_ses-d0470
# sub-OAS30329_ses-d0376
# sub-OAS30330_ses-d0000_run-01
# sub-OAS30330_ses-d0000_run-02
# sub-OAS30331_ses-d2229_run-01
# sub-OAS30331_ses-d2229_run-02
# sub-OAS30331_ses-d2229_run-03
# sub-OAS30331_ses-d2824_run-01
# sub-OAS30331_ses-d2824_run-02
# sub-OAS30331_ses-d3478_run-01
# sub-OAS30331_ses-d3478_run-02
# sub-OAS30331_ses-d4694
# sub-OAS30332_ses-d0091
# sub-OAS30333_ses-d0093_run-01
# sub-OAS30333_ses-d0093_run-02
# sub-OAS30333_ses-d2005
# sub-OAS30333_ses-d2008
# sub-OAS30333_ses-d2457
# sub-OAS30333_ses-d2891
# sub-OAS30333_ses-d2985
# sub-OAS30334_ses-d0000_run-01
# sub-OAS30334_ses-d0000_run-02
# sub-OAS30334_ses-d0889
# sub-OAS30335_ses-d0109
# sub-OAS30335_ses-d0693_run-01
# sub-OAS30335_ses-d0693_run-02
# sub-OAS30335_ses-d1482_run-01
# sub-OAS30335_ses-d1482_run-02
# sub-OAS30335_ses-d2770
# sub-OAS30335_ses-d2783
# sub-OAS30335_ses-d3812
# sub-OAS30336_ses-d0012
# sub-OAS30336_ses-d0244
# sub-OAS30336_ses-d1264
# sub-OAS30337_ses-d0064
# sub-OAS30339_ses-d0066_run-01
# sub-OAS30339_ses-d0066_run-02
# sub-OAS30341_ses-d0025
# sub-OAS30342_ses-d0001
# sub-OAS30342_ses-d0429
# sub-OAS30343_ses-d2141_run-01
# sub-OAS30343_ses-d2141_run-02
# sub-OAS30343_ses-d2141_run-03
# sub-OAS30343_ses-d2141_run-04
# sub-OAS30343_ses-d2820_run-01
# sub-OAS30343_ses-d2820_run-02
# sub-OAS30343_ses-d2820_run-03
# sub-OAS30343_ses-d4178_run-01
# sub-OAS30343_ses-d4178_run-02
# sub-OAS30343_ses-d4900
# sub-OAS30344_ses-d0049_run-01
# sub-OAS30344_ses-d0049_run-02
# sub-OAS30344_ses-d1052_run-01
# sub-OAS30344_ses-d1052_run-02
# sub-OAS30344_ses-d2375
# sub-OAS30345_ses-d0087_run-01
# sub-OAS30345_ses-d0087_run-02
# sub-OAS30346_ses-d0083_run-01
# sub-OAS30346_ses-d0083_run-02
# sub-OAS30346_ses-d0083_run-03
# sub-OAS30346_ses-d1685
# sub-OAS30347_ses-d2615_run-01
# sub-OAS30347_ses-d2615_run-02
# sub-OAS30347_ses-d2615_run-03
# sub-OAS30347_ses-d3101_run-01
# sub-OAS30347_ses-d3101_run-02
# sub-OAS30347_ses-d3101_run-03
# sub-OAS30348_ses-d0077
# sub-OAS30349_ses-d0699_run-01
# sub-OAS30349_ses-d0699_run-02
# sub-OAS30349_ses-d3241
# sub-OAS30350_ses-d0018_run-01
# sub-OAS30350_ses-d0018_run-02
# sub-OAS30350_ses-d0509
# sub-OAS30350_ses-d1201
# sub-OAS30351_ses-d0037
# sub-OAS30352_ses-d0099
# sub-OAS30353_ses-d0963_run-01
# sub-OAS30353_ses-d0963_run-02
# sub-OAS30353_ses-d2635
# sub-OAS30353_ses-d3421
# sub-OAS30354_ses-d0056_run-01
# sub-OAS30354_ses-d0056_run-02
# sub-OAS30355_ses-d0048
# sub-OAS30355_ses-d0861
# sub-OAS30356_ses-d0714_run-01
# sub-OAS30356_ses-d0714_run-02
# sub-OAS30357_ses-d0521
# sub-OAS30357_ses-d0535_run-01
# sub-OAS30357_ses-d0535_run-02
# sub-OAS30357_ses-d1195
# sub-OAS30358_ses-d0367_run-01
# sub-OAS30358_ses-d0367_run-02
# sub-OAS30358_ses-d0367_run-03
# sub-OAS30359_ses-d0069_run-01
# sub-OAS30359_ses-d0069_run-02
# sub-OAS30360_ses-d0118
# sub-OAS30361_ses-d1457_run-01
# sub-OAS30361_ses-d1457_run-02
# sub-OAS30361_ses-d2151_run-01
# sub-OAS30361_ses-d2151_run-02
# sub-OAS30361_ses-d3275
# sub-OAS30362_ses-d0032
# sub-OAS30363_ses-d0087_run-01
# sub-OAS30363_ses-d0087_run-02
# sub-OAS30363_ses-d0880_run-01
# sub-OAS30363_ses-d0880_run-02
# sub-OAS30363_ses-d2626
# sub-OAS30363_ses-d2701
# sub-OAS30364_ses-d0110
# sub-OAS30365_ses-d5600_run-01
# sub-OAS30365_ses-d5600_run-02
# sub-OAS30365_ses-d5600_run-03
# sub-OAS30365_ses-d6199_run-01
# sub-OAS30365_ses-d6199_run-02
# sub-OAS30365_ses-d6199_run-03
# sub-OAS30367_ses-d0055_run-01
# sub-OAS30367_ses-d0055_run-02
# sub-OAS30367_ses-d0055_run-03
# sub-OAS30367_ses-d1540_run-01
# sub-OAS30367_ses-d1540_run-02
# sub-OAS30367_ses-d2009_run-01
# sub-OAS30367_ses-d2009_run-02
# sub-OAS30367_ses-d3394
# sub-OAS30367_ses-d3396
# sub-OAS30367_ses-d4337
# sub-OAS30368_ses-d0056_run-01
# sub-OAS30368_ses-d0056_run-02
# sub-OAS30368_ses-d2379
# sub-OAS30368_ses-d2750
# sub-OAS30369_ses-d2819_run-01
# sub-OAS30369_ses-d2819_run-02
# sub-OAS30369_ses-d2819_run-03
# sub-OAS30369_ses-d4058_run-01
# sub-OAS30369_ses-d4058_run-02
# sub-OAS30369_ses-d4921
# sub-OAS30369_ses-d5872
# sub-OAS30369_ses-d5880
# sub-OAS30369_ses-d6215
# sub-OAS30369_ses-d6992
# sub-OAS30370_ses-d0141_run-01
# sub-OAS30370_ses-d0141_run-02
# sub-OAS30371_ses-d0338_run-01
# sub-OAS30371_ses-d0338_run-02
# sub-OAS30371_ses-d0981
# sub-OAS30371_ses-d1400
# sub-OAS30372_ses-d3464
# sub-OAS30372_ses-d4514
# sub-OAS30373_ses-d0048_run-01
# sub-OAS30373_ses-d0048_run-02
# sub-OAS30373_ses-d1211
# sub-OAS30374_ses-d0084
# sub-OAS30375_ses-d5792_run-01
# sub-OAS30375_ses-d5792_run-02
# sub-OAS30375_ses-d6879
# sub-OAS30376_ses-d0082
# sub-OAS30377_ses-d0048
# sub-OAS30378_ses-d0204_run-01
# sub-OAS30378_ses-d0204_run-02
# sub-OAS30379_ses-d1169_run-01
# sub-OAS30379_ses-d1169_run-02
# sub-OAS30379_ses-d1169_run-03
# sub-OAS30379_ses-d2106_run-01
# sub-OAS30379_ses-d2106_run-02
# sub-OAS30380_ses-d3446_run-01
# sub-OAS30380_ses-d3446_run-02
# sub-OAS30381_ses-d1158_run-01
# sub-OAS30381_ses-d1158_run-02
# sub-OAS30381_ses-d1158_run-03
# sub-OAS30382_ses-d0051_run-01
# sub-OAS30382_ses-d0051_run-02
# sub-OAS30382_ses-d1199
# sub-OAS30383_ses-d0134_run-01
# sub-OAS30383_ses-d0134_run-02
# sub-OAS30384_ses-d0108
# sub-OAS30385_ses-d0112
# sub-OAS30386_ses-d0055
# sub-OAS30387_ses-d0616_run-01
# sub-OAS30387_ses-d0616_run-02
# sub-OAS30387_ses-d1832
# sub-OAS30387_ses-d3401
# sub-OAS30388_ses-d0073_run-01
# sub-OAS30388_ses-d0073_run-02
# sub-OAS30390_ses-d0346_run-01
# sub-OAS30390_ses-d0346_run-02
# sub-OAS30390_ses-d2428
# sub-OAS30391_ses-d0192
# sub-OAS30391_ses-d1547
# sub-OAS30392_ses-d0730_run-01
# sub-OAS30392_ses-d0730_run-02
# sub-OAS30392_ses-d1682_run-01
# sub-OAS30392_ses-d1682_run-02
# sub-OAS30392_ses-d3145
# sub-OAS30393_ses-d6201_run-01
# sub-OAS30393_ses-d6201_run-02
# sub-OAS30393_ses-d6201_run-03
# sub-OAS30393_ses-d6201_run-04
# sub-OAS30393_ses-d6803_run-01
# sub-OAS30393_ses-d6803_run-02
# sub-OAS30393_ses-d6803_run-03
# sub-OAS30393_ses-d7726_run-01
# sub-OAS30393_ses-d7726_run-02
# sub-OAS30393_ses-d8651
# sub-OAS30394_ses-d0039
# sub-OAS30395_ses-d0002
# sub-OAS30395_ses-d1241
# sub-OAS30396_ses-d0037_run-01
# sub-OAS30396_ses-d0037_run-02
# sub-OAS30397_ses-d0043
# sub-OAS30398_ses-d0051
# sub-OAS30399_ses-d0380_run-01
# sub-OAS30399_ses-d0380_run-02
# sub-OAS30399_ses-d1220_run-01
# sub-OAS30399_ses-d1220_run-02
# sub-OAS30399_ses-d2293
# sub-OAS30400_ses-d0070
# sub-OAS30401_ses-d0106_run-01
# sub-OAS30401_ses-d0106_run-02
# sub-OAS30402_ses-d0015
# sub-OAS30402_ses-d1085
# sub-OAS30403_ses-d0091
# sub-OAS30403_ses-d1232_run-01
# sub-OAS30403_ses-d1232_run-02
# sub-OAS30403_ses-d2378
# sub-OAS30403_ses-d2379
# sub-OAS30403_ses-d2758
# sub-OAS30403_ses-d2868
# sub-OAS30403_ses-d3669
# sub-OAS30404_ses-d0104
# sub-OAS30405_ses-d0079_run-01
# sub-OAS30405_ses-d0079_run-02
# sub-OAS30405_ses-d0079_run-03
# sub-OAS30405_ses-d1883
# sub-OAS30406_ses-d0084_run-01
# sub-OAS30406_ses-d0084_run-02
# sub-OAS30407_ses-d0061_run-01
# sub-OAS30407_ses-d0061_run-02
# sub-OAS30407_ses-d1267
# sub-OAS30407_ses-d2862
# sub-OAS30408_ses-d1193_run-01
# sub-OAS30408_ses-d1193_run-02
# sub-OAS30408_ses-d1193_run-03
# sub-OAS30410_ses-d0034
# sub-OAS30411_ses-d0183_run-01
# sub-OAS30411_ses-d0183_run-02
# sub-OAS30411_ses-d0183_run-03
# sub-OAS30411_ses-d1227_run-01
# sub-OAS30411_ses-d1227_run-02
# sub-OAS30411_ses-d3011
# sub-OAS30411_ses-d3025
# sub-OAS30411_ses-d4368
# sub-OAS30412_ses-d6024_run-01
# sub-OAS30412_ses-d6024_run-02
# sub-OAS30412_ses-d6024_run-03
# sub-OAS30413_ses-d0044
# sub-OAS30413_ses-d0561_run-01
# sub-OAS30413_ses-d0561_run-02
# sub-OAS30413_ses-d1533_run-01
# sub-OAS30413_ses-d1533_run-02
# sub-OAS30414_ses-d0030_run-01
# sub-OAS30414_ses-d0030_run-02
# sub-OAS30414_ses-d0037
# sub-OAS30414_ses-d0363
# sub-OAS30414_ses-d1175_run-01
# sub-OAS30414_ses-d1175_run-02
# sub-OAS30415_ses-d0784
# sub-OAS30416_ses-d0044
# sub-OAS30417_ses-d0093
# sub-OAS30417_ses-d0107
# sub-OAS30418_ses-d0069_run-01
# sub-OAS30418_ses-d0069_run-02
# sub-OAS30418_ses-d0803
# sub-OAS30419_ses-d0621_run-01
# sub-OAS30419_ses-d0621_run-02
# sub-OAS30419_ses-d1139_run-01
# sub-OAS30419_ses-d1139_run-02
# sub-OAS30419_ses-d2360
# sub-OAS30419_ses-d3307
# sub-OAS30420_ses-d2792_run-01
# sub-OAS30420_ses-d2792_run-02
# sub-OAS30420_ses-d2792_run-03
# sub-OAS30420_ses-d3746_run-01
# sub-OAS30420_ses-d3746_run-02
# sub-OAS30421_ses-d2605_run-01
# sub-OAS30421_ses-d2605_run-02
# sub-OAS30422_ses-d0104
# sub-OAS30423_ses-d0067_run-01
# sub-OAS30423_ses-d0067_run-02
# sub-OAS30423_ses-d1267
# sub-OAS30423_ses-d2099
# sub-OAS30424_ses-d0095_run-01
# sub-OAS30424_ses-d0095_run-02
# sub-OAS30427_ses-d4348
# sub-OAS30428_ses-d0133
# sub-OAS30429_ses-d0055
# sub-OAS30430_ses-d0055_run-01
# sub-OAS30430_ses-d0055_run-02
# sub-OAS30430_ses-d0909
# sub-OAS30431_ses-d0113
# sub-OAS30432_ses-d0100
# sub-OAS30433_ses-d1954_run-01
# sub-OAS30433_ses-d1954_run-02
# sub-OAS30434_ses-d0054
# sub-OAS30436_ses-d0388_run-01
# sub-OAS30436_ses-d0388_run-02
# sub-OAS30438_ses-d0064_run-01
# sub-OAS30438_ses-d0064_run-02
# sub-OAS30438_ses-d0897
# sub-OAS30438_ses-d2358
# sub-OAS30440_ses-d0163
# sub-OAS30441_ses-d0053
# sub-OAS30442_ses-d0903
# sub-OAS30443_ses-d0162
# sub-OAS30443_ses-d1480
# sub-OAS30443_ses-d2432
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-bd4c99566385> in <module>
#      20             #img_slice = cv2.resize(img_slice, (0,0), fx=1/img_scale, fy=1/img_scale, interpolation=cv2.INTER_AREA)
#      21             #img_slice = img_slice[40:216,:]
# ---> 22             img_slice = img_slice/256
#      23             run_imgs.append(img_slice)
#      24
#
# TypeError: unsupported operand type(s) for /: 'NoneType' and 'int'

# %%
plt.imshow(valid_data[0][0][1])

# %%
from collections import Counter

counts = Counter(x[1] for x in train_data)
print("Number of non-AD scans in train dataset: {}".format(counts[0]))
print("Number of AD scan in train datasets: {}".format(counts[1]))
print("\n")

counts = Counter(x[1] for x in valid_data)
print("Number of non-AD scans in valid dataset: {}".format(counts[0]))
print("Number of AD scan in valid datasets: {}".format(counts[1]))
print("\n")

counts = Counter(x[1] for x in test_data)
print("Number of non-AD scans in test dataset: {}".format(counts[0]))
print("Number of AD scan in test datasets: {}".format(counts[1]))
print("\n")
# Out:
# Number of non-AD scans in train dataset: 458
# Number of AD scan in train datasets: 74
#
#
# Number of non-AD scans in valid dataset: 148
# Number of AD scan in valid datasets: 23
#
#
# Number of non-AD scans in test dataset: 107
# Number of AD scan in test datasets: 20

# %%
old_train_data = train_data
train_AD = []
for item in train_data:
    if item[1] == 1:
        train_AD.append(item)
train_data = old_train_data + train_AD * 4

print("Number of data points in new train dataset: {}".format(len(train_data)))
counts = Counter(x[1] for x in train_data)
print("Number of non-AD scans in new train dataset: {}".format(counts[0]))
print("Number of AD scan in new train dataset: {}".format(counts[1]))
# Out:
# Number of data points in new train dataset: 828
# Number of non-AD scans in new train dataset: 458
# Number of AD scan in new train dataset: 370

# %%
from torch.utils.data import Dataset, DataLoader

class T1Dataset(Dataset):
    def __init__(self, data, transform=None):
        # list of tuples (3d image arrays, AD label)
        self.data = data
        # labels.csv
        #self.target = torch.from_numpy(target).long()
        #self.transform = transforms.Compose([transforms.ToTensor()])
        self.transform = transform
        
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, index):
        #scan = torch.from_numpy(self.data[index][0]).float()
        scan = self.data[index][0]
        y = self.data[index][1]
        return scan, y

# %%
train_dataset = T1Dataset(train_data, None)
valid_dataset = T1Dataset(valid_data, None)
test_dataset = T1Dataset(test_data, None)

# %%
import torchvision.models

alexnet = torchvision.models.alexnet(pretrained=True)
alexnet.cuda()

train_dataset_list = list(train_dataset)
imgs, train_labels = next(iter(torch.utils.data.DataLoader(train_dataset_list, batch_size=256, shuffle=True)))
imgs = imgs.float()
imgs = imgs.to(device)
train_features = alexnet.features(imgs)

valid_dataset_list = list(valid_dataset)
imgs, valid_labels = next(iter(torch.utils.data.DataLoader(valid_dataset_list, batch_size=256, shuffle=True)))
imgs = imgs.float()
imgs = imgs.to(device)
valid_features = alexnet.features(imgs)

test_dataset_list = list(test_dataset)
imgs, test_labels = next(iter(torch.utils.data.DataLoader(test_dataset_list, batch_size=256, shuffle=True)))
imgs = imgs.float()
imgs = imgs.to(device)
test_features = alexnet.features(imgs)

print(imgs.shape)
print(len(test_dataset_list))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-19-ae42c56aa434> in <module>
#      14 imgs = imgs.float()
#      15 imgs = imgs.to(device)
# ---> 16 valid_features = alexnet.features(imgs)
#      17
#      18 test_dataset_list = list(test_dataset)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\pooling.py in forward(self, input)
#     144         return F.max_pool2d(input, self.kernel_size, self.stride,
#     145                             self.padding, self.dilation, self.ceil_mode,
# --> 146                             self.return_indices)
#     147
#     148
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\_jit_internal.py in fn(*args, **kwargs)
#     131             return if_true(*args, **kwargs)
#     132         else:
# --> 133             return if_false(*args, **kwargs)
#     134
#     135     if if_true.__doc__ is None and if_false.__doc__ is not None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py in _max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode, return_indices)
#     492         stride = torch.jit.annotate(List[int], [])
#     493     return torch.max_pool2d(
# --> 494         input, kernel_size, stride, padding, dilation, ceil_mode)
#     495
#     496 max_pool2d = torch._jit_internal.boolean_dispatch(
#
# RuntimeError: CUDA out of memory. Tried to allocate 58.00 MiB (GPU 0; 6.00 GiB total capacity; 1.91 GiB already allocated; 2.74 MiB free; 27.07 MiB cached)

# %%
torch.max(imgs[0])

# %%
train_features_list = []
for i in range(train_features.shape[0]):
    train_features_list.append((train_features[i], train_labels[i]))
    
valid_features_list = []
for i in range(valid_features.shape[0]):
    valid_features_list.append((valid_features[i], valid_labels[i]))
    
test_features_list = []
for i in range(test_features.shape[0]):
    test_features_list.append((test_features[i], test_labels[i]))

# %%
def get_model_name(name, batch_size, learning_rate, epoch):
    path = "model_{0}_bs{1}_lr{2}_epoch{3}".format(name,
                                                   batch_size,
                                                   learning_rate,
                                                   epoch)
    return path

def get_loss(model, train=False):
    if train:
        data = train_features_list
    else:
        data = test_features_list
        
    loader = torch.utils.data.DataLoader(data, batch_size=len(data), shuffle=True)
    criterion = nn.BCEWithLogitsLoss()
    imgs, labels = next(iter(loader))
    imgs, labels = imgs.to(device), labels.to(device)
    out = model(imgs)             # forward pass
    loss = criterion(out, labels.float()) # compute the total loss
    return loss.item()

def get_accuracy(model, train=False):
    if train:
        data = train_features_list
    else:
        #data_acc_loader = torch.utils.data.DataLoader(data_val, batch_size=diff)
        data = valid_features_list

    correct = 0
    total = 0
    for imgs, labels in torch.utils.data.DataLoader(data, batch_size=32, shuffle=True):
        imgs, labels = imgs.to(device), labels.to(device)
        outputs = model(imgs) # We don't need to run F.softmax
        corr = (outputs > 0.0).squeeze().long() == labels
        correct += int(corr.sum())
        #correct += pred.eq(labels.view_as(pred)).sum().item()
        total += imgs.shape[0]
    #print(total)
    return correct / total

# %%
from torch.autograd import Variable

def train(model, features_list, num_epochs=10, batch_size=32, learning_rate=1e-4):
    criterion = nn.BCEWithLogitsLoss()
    # use Adam for CNN
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9)
    epochs, train_losses, valid_losses, train_acc, valid_acc = [], [], [], [], []
    
    train_loader = torch.utils.data.DataLoader(features_list, batch_size=batch_size, shuffle=True)
    
    loss = 0
    
    for epoch in range(num_epochs):
        for inputs, labels in iter(train_loader):
            optimizer.zero_grad()
            inputs, labels = inputs.to(device), labels.to(device)
            #print(torch.sum(inputs))
            outputs = model(inputs)
            loss = criterion(outputs, labels.float())
            loss.backward(retain_graph=True)
            optimizer.step()
            #for param in model.parameters():
            #  print(param.grad.data.sum())
    
        epochs.append(epoch)
        train_losses.append(get_loss(model, train=True))
        valid_losses.append(get_loss(model, train=False))
        train_acc.append(get_accuracy(model, train=True))
        valid_acc.append(get_accuracy(model, train=False))
        
        print("Epoch %d; Train Loss %f; Val Loss %f; Train Acc %f; Val Acc %f" % (
              epoch+1, loss, valid_losses[-1], train_acc[-1], valid_acc[-1]))
    
    plt.title("Training Curve")
    plt.plot(epochs, train_losses, label="Train")
    plt.plot(epochs, valid_losses, label="Validation")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend(loc='best')
    plt.show()

    plt.title("Training Curve")
    plt.plot(epochs, train_acc, label="Train")
    plt.plot(epochs, valid_acc, label="Validation")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend(loc='best')
    plt.show()
    
    print("Final Training Accuracy: {}".format(train_acc[-1]))
    print("Final Validation Accuracy: {}".format(valid_acc[-1]))

# %%
class CNN2(nn.Module):
    def __init__(self):
        super(CNN2, self).__init__()
        self.name = "CNN2"
        # 256x6x6
        self.fc1 = nn.Linear(256*7*7, 512)
        nn.init.xavier_uniform(self.fc1.weight)
        #self.fc1 = nn.Linear(3*224*224, 512)
        self.fc2 = nn.Linear(512, 32)
        nn.init.xavier_uniform(self.fc2.weight)
        #self.fc3 = nn.Linear(512, 64)
        #nn.init.xavier_uniform(self.fc3.weight)
        self.fc3 = nn.Linear(32, 1)
        nn.init.xavier_uniform(self.fc3.weight)
        #self.softmax = nn.Softmax()

    def forward(self, x):
        x = x.view(-1, 256*7*7)
        #x = x.view(-1, 3*224*224)
        x = F.relu(self.fc1(x))
        #print(x.shape)
        x = F.relu(self.fc2(x))
        #print(x.shape)
        x = F.relu(self.fc3(x))
        #print(x.shape)
        #x = self.fc4(x)
        #x = self.softmax(x)
        x = x.squeeze(1) # Flatten to [batch_size]
        return x

# %%
len(train_features_list)

# %%
alexnetCNN2 = CNN2()
alexnetCNN2.cuda()
train(alexnetCNN2, train_features_list, num_epochs=50, batch_size=32, learning_rate=1e-4)

# %%
for param in alexnetCNN2.parameters():
    print(param.grad.data.sum())

# %%
get_accuracy(alexnetCNN2, train=False)
